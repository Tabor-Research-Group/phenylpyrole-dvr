# %%
# Notebook for calculating the 
# vibronic spectra
# This program fits potential energy surfaces
# and sets up the necessary DVR calculations
# Notebook is annotated where the DVR calculation must
# be executed before continuing

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import random
from scipy import interpolate

# %%
import scipy

# %%
import pandas as pd

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 8)

# %%
from scipy.interpolate import interp1d

# %%
from dvr_setup_and_plotting_utils import *

# %%
# Run and collect ground state information
# Reduced mass of freqency calculation =  3.5381 AMU

# Final fitted result worked best with the following fitted mass

mass_ground = 1836*250
print(str(mass_ground/1836))

num_wavefunctions_ground = 5
grid_points = 500 # This number is N, number of points in DVR is 2N+1

# Linear fit used in production 
# Cubic fit also written 

fit_potential_spline_assume_periodic_write_to_file(raw_potential_filename='gs_scan_with_water_raw_pot_optimized.dat',num_grid_points=grid_points,
                                output_potential_filename='gs_scan_with_water_fitted.dat',shift_origin=0.0,scale_factor=1.00)


print('potential written')

setup_dvr(num_states=num_wavefunctions_ground,num_grid_points=grid_points,mass=mass_ground,
                         potential_energy_file_name='gs_scan_with_water_fitted.dat',
                        output_file_name='gs_scan_with_h2o')

print('dvr is set up')
# Out:
# 250.0
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp gs_scan_with_water_fitted.dat potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above
# User must supply their own matrix diagonalization subroutine

# %%
# Now setup and run the excited state excited state

mass_excited =  mass_ground
num_wavefunctions_excited = 200
print(str(mass_excited/1836))

fit_potential_spline_assume_periodic_write_to_file(raw_potential_filename='es_scan_with_water_raw_pot_optimized.dat',num_grid_points=grid_points,
                                output_potential_filename='es_scan_with_water_fitted.dat',shift_origin=0.0,scale_factor=1.0)

print('potential written')

setup_dvr(num_states=num_wavefunctions_excited,num_grid_points=grid_points,mass=mass_excited,
                         potential_energy_file_name='es_scan_with_water_fitted.dat',
                        output_file_name='es_scan_with_h2o')

print('dvr is set up')
# Out:
# 250.0
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp es_scan_with_water_fitted.dat potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above

# %%
# Square overlaps calculated here

# %%
wavefunction_overlaps = calculate_overlaps_multiple_vib_shifts(
                                         ground_state_file_name_root='gs_scan_with_h2o',
                                         excited_state_file_name_root='es_scan_with_h2o',
                                         max_num_ground_state_wfs=4,
                                         max_num_excited_state_wfs=100,
                                         ground_state_max_energy=300,
                                         excited_state_max_energy=1000,vib_shifts=[130.0,170.0],
                                        vib_scales=[1.0,1.0])
# Out:
# Calculating overlap for transition with energy 0.0
# Calculating overlap for transition with energy 2.291514196805956e-06
# Calculating overlap for transition with energy 1.1104600122826207
# Calculating overlap for transition with energy 1.1104621746518741
# Calculating overlap for transition with energy 80.00816097521708
# Calculating overlap for transition with energy 80.00816251441486
# Calculating overlap for transition with energy 81.54706262870168
# Calculating overlap for transition with energy 81.54706401639177
# Calculating overlap for transition with energy 161.31354853709948
# Calculating overlap for transition with energy 161.3135494116611
# Calculating overlap for transition with energy 161.71405921161494
# Calculating overlap for transition with energy 161.71406007258065
# Calculating overlap for transition with energy 238.26772190792158
# Calculating overlap for transition with energy 238.26772232166167
# Calculating overlap for transition with energy 242.43456715219077
# Calculating overlap for transition with energy 242.43456771287114
# Calculating overlap for transition with energy 309.4259682054954
# Calculating overlap for transition with energy 309.42596883451245
# Calculating overlap for transition with energy 318.9401718029203
# Calculating overlap for transition with energy 318.9401758371449
# Calculating overlap for transition with energy 368.5644782069656
# Calculating overlap for transition with energy 368.5644798732814
# Calculating overlap for transition with energy 391.44843601221135
# Calculating overlap for transition with energy 391.4484409376124
# Calculating overlap for transition with energy 430.5761710286188
# Calculating overlap for transition with energy 430.5761720126785
# Calculating overlap for transition with energy 467.4708514909939
# Calculating overlap for transition with energy 467.47085606355677
# Calculating overlap for transition with energy 507.8760093823965
# Calculating overlap for transition with energy 507.87601005838036
# Calculating overlap for transition with energy 549.8461848219754
# Calculating overlap for transition with energy 549.846187228813
# Calculating overlap for transition with energy 593.2157091157637
# Calculating overlap for transition with energy 593.2157114929475
# Calculating overlap for transition with energy 637.8804059042171
# Calculating overlap for transition with energy 637.8804071436728
# Calculating overlap for transition with energy 683.6523944562131
# Calculating overlap for transition with energy 683.6523981314983
# Calculating overlap for transition with energy 730.4060095830125
# Calculating overlap for transition with energy 730.4060097557814
# Calculating overlap for transition with energy 778.0807223235558
# Calculating overlap for transition with energy 778.0807263429894
# Calculating overlap for transition with energy 826.5644021961596
# Calculating overlap for transition with energy 826.564403026197
# Calculating overlap for transition with energy 875.8261640059937
# Calculating overlap for transition with energy 875.8261648889834
# Calculating overlap for transition with energy 925.7793199565945
# Calculating overlap for transition with energy 925.7793210767492
# Calculating overlap for transition with energy -3.634881827718813e-07
# Calculating overlap for transition with energy 1.9280260140340746e-06
# Calculating overlap for transition with energy 1.110459648794438
# Calculating overlap for transition with energy 1.1104618111636912
# Calculating overlap for transition with energy 80.0081606117289
# Calculating overlap for transition with energy 80.00816215092668
# Calculating overlap for transition with energy 81.54706226521351
# Calculating overlap for transition with energy 81.54706365290359
# Calculating overlap for transition with energy 161.3135481736113
# Calculating overlap for transition with energy 161.31354904817292
# Calculating overlap for transition with energy 161.71405884812677
# Calculating overlap for transition with energy 161.71405970909248
# Calculating overlap for transition with energy 238.26772154443339
# Calculating overlap for transition with energy 238.26772195817347
# Calculating overlap for transition with energy 242.43456678870257
# Calculating overlap for transition with energy 242.43456734938295
# Calculating overlap for transition with energy 309.4259678420072
# Calculating overlap for transition with energy 309.42596847102425
# Calculating overlap for transition with energy 318.9401714394321
# Calculating overlap for transition with energy 318.9401754736567
# Calculating overlap for transition with energy 368.5644778434774
# Calculating overlap for transition with energy 368.5644795097932
# Calculating overlap for transition with energy 391.44843564872315
# Calculating overlap for transition with energy 391.4484405741242
# Calculating overlap for transition with energy 430.57617066513063
# Calculating overlap for transition with energy 430.5761716491903
# Calculating overlap for transition with energy 467.47085112750574
# Calculating overlap for transition with energy 467.47085570006857
# Calculating overlap for transition with energy 507.87600901890835
# Calculating overlap for transition with energy 507.8760096948922
# Calculating overlap for transition with energy 549.8461844584872
# Calculating overlap for transition with energy 549.846186865325
# Calculating overlap for transition with energy 593.2157087522756
# Calculating overlap for transition with energy 593.2157111294595
# Calculating overlap for transition with energy 637.8804055407289
# Calculating overlap for transition with energy 637.8804067801846
# Calculating overlap for transition with energy 683.6523940927249
# Calculating overlap for transition with energy 683.6523977680101
# Calculating overlap for transition with energy 730.4060092195243
# Calculating overlap for transition with energy 730.4060093922933
# Calculating overlap for transition with energy 778.0807219600678
# Calculating overlap for transition with energy 778.0807259795012
# Calculating overlap for transition with energy 826.5644018326715
# Calculating overlap for transition with energy 826.5644026627089
# Calculating overlap for transition with energy 875.8261636425055
# Calculating overlap for transition with energy 875.8261645254952
# Calculating overlap for transition with energy 925.7793195931063
# Calculating overlap for transition with energy 925.7793207132609
# Calculating overlap for transition with energy -1.2301656103595584
# Calculating overlap for transition with energy -1.2301633188453616
# Calculating overlap for transition with energy -0.11970559807693759
# Calculating overlap for transition with energy -0.11970343570768434
# Calculating overlap for transition with energy 78.77799536485752
# Calculating overlap for transition with energy 78.7779969040553
# Calculating overlap for transition with energy 80.31689701834213
# Calculating overlap for transition with energy 80.31689840603221
# Calculating overlap for transition with energy 160.08338292673992
# Calculating overlap for transition with energy 160.08338380130152
# Calculating overlap for transition with energy 160.48389360125537
# Calculating overlap for transition with energy 160.48389446222112
# Calculating overlap for transition with energy 237.03755629756202
# Calculating overlap for transition with energy 237.0375567113021
# Calculating overlap for transition with energy 241.2044015418312
# Calculating overlap for transition with energy 241.20440210251155
# Calculating overlap for transition with energy 308.19580259513583
# Calculating overlap for transition with energy 308.1958032241529
# Calculating overlap for transition with energy 317.71000619256074
# Calculating overlap for transition with energy 317.71001022678536
# Calculating overlap for transition with energy 367.334312596606
# Calculating overlap for transition with energy 367.33431426292185
# Calculating overlap for transition with energy 390.2182704018518
# Calculating overlap for transition with energy 390.21827532725285
# Calculating overlap for transition with energy 429.3460054182592
# Calculating overlap for transition with energy 429.3460064023189
# Calculating overlap for transition with energy 466.2406858806343
# Calculating overlap for transition with energy 466.2406904531972
# Calculating overlap for transition with energy 506.6458437720369
# Calculating overlap for transition with energy 506.6458444480208
# Calculating overlap for transition with energy 548.6160192116158
# Calculating overlap for transition with energy 548.6160216184535
# Calculating overlap for transition with energy 591.9855435054042
# Calculating overlap for transition with energy 591.985545882588
# Calculating overlap for transition with energy 636.6502402938576
# Calculating overlap for transition with energy 636.6502415333132
# Calculating overlap for transition with energy 682.4222288458534
# Calculating overlap for transition with energy 682.4222325211388
# Calculating overlap for transition with energy 729.175843972653
# Calculating overlap for transition with energy 729.1758441454218
# Calculating overlap for transition with energy 776.8505567131963
# Calculating overlap for transition with energy 776.8505607326298
# Calculating overlap for transition with energy 825.3342365858
# Calculating overlap for transition with energy 825.3342374158374
# Calculating overlap for transition with energy 874.5959983956343
# Calculating overlap for transition with energy 874.5959992786239
# Calculating overlap for transition with energy 924.549154346235
# Calculating overlap for transition with energy 924.5491554663896
# Calculating overlap for transition with energy -1.2301658091521168
# Calculating overlap for transition with energy -1.23016351763792
# Calculating overlap for transition with energy -0.11970579686949605
# Calculating overlap for transition with energy -0.1197036345002428
# Calculating overlap for transition with energy 78.77799516606497
# Calculating overlap for transition with energy 78.77799670526275
# Calculating overlap for transition with energy 80.31689681954957
# Calculating overlap for transition with energy 80.31689820723966
# Calculating overlap for transition with energy 160.08338272794737
# Calculating overlap for transition with energy 160.083383602509
# Calculating overlap for transition with energy 160.48389340246283
# Calculating overlap for transition with energy 160.48389426342854
# Calculating overlap for transition with energy 237.03755609876947
# Calculating overlap for transition with energy 237.03755651250955
# Calculating overlap for transition with energy 241.20440134303865
# Calculating overlap for transition with energy 241.20440190371903
# Calculating overlap for transition with energy 308.1958023963433
# Calculating overlap for transition with energy 308.19580302536036
# Calculating overlap for transition with energy 317.71000599376816
# Calculating overlap for transition with energy 317.7100100279928
# Calculating overlap for transition with energy 367.3343123978135
# Calculating overlap for transition with energy 367.3343140641293
# Calculating overlap for transition with energy 390.21827020305926
# Calculating overlap for transition with energy 390.2182751284603
# Calculating overlap for transition with energy 429.3460052194667
# Calculating overlap for transition with energy 429.3460062035264
# Calculating overlap for transition with energy 466.24068568184174
# Calculating overlap for transition with energy 466.2406902544046
# Calculating overlap for transition with energy 506.64584357324435
# Calculating overlap for transition with energy 506.6458442492283
# Calculating overlap for transition with energy 548.6160190128232
# Calculating overlap for transition with energy 548.616021419661
# Calculating overlap for transition with energy 591.9855433066117
# Calculating overlap for transition with energy 591.9855456837954
# Calculating overlap for transition with energy 636.650240095065
# Calculating overlap for transition with energy 636.6502413345206
# Calculating overlap for transition with energy 682.4222286470609
# Calculating overlap for transition with energy 682.4222323223462
# Calculating overlap for transition with energy 729.1758437738604
# Calculating overlap for transition with energy 729.1758439466294
# Calculating overlap for transition with energy 776.8505565144037
# Calculating overlap for transition with energy 776.8505605338372
# Calculating overlap for transition with energy 825.3342363870074
# Calculating overlap for transition with energy 825.3342372170449
# Calculating overlap for transition with energy 874.5959981968416
# Calculating overlap for transition with energy 874.5959990798312
# Calculating overlap for transition with energy 924.5491541474423
# Calculating overlap for transition with energy 924.549155267597

# %%
#This produces a list of dictionaries
# Showing example
wavefunction_overlaps[0]
# Out:
# {'energy': 0.0,
#  'ground_state_id': 'gs_scan_with_h2o_0',
#  'excited_state_id': 'es_scan_with_h2o_0',
#  'overlap': 2.4158226989255738e-14}

# %%
# Turn list of dictionaries into a dataframe
overlap_df = pd.DataFrame(wavefunction_overlaps)

# %%
# Now, convert from a.u. to cm^-1, plot stem plot and compare to the experimental spectrum
# Use same color scheme as experimental section

# Exp files: PhPyH2O UV Spectrum.txt
# Exp file 2: PhPyH2O UV Spectrum.txt 

# Offset slightly different if ZPE effects included or not 

offset = 32780

kidwell_uv_spectrum_energy = np.loadtxt('2PhPy-H2O UV Spectrum.txt',usecols=1)
kidwell_uv_spectrum_intensity = np.loadtxt('2PhPy-H2O UV Spectrum.txt',usecols=0)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 


ax.set_xlabel('Energy cm^-1', fontsize = 12)
ax.set_ylabel('Intensity', fontsize = 12)
ax.set_xlim(32850,33600)
 
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity,label='Experiment', color='k',ls='-')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_0_for_plotting = list()
wavefunction_excited_vib_state_1_for_plotting = list()


# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited_0' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_0_for_plotting.append(wavefunction_overlap)
    elif 'vib_excited_1' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_1_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

# Might need to normalize

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_0_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_0_for_plotting)

wavefunction_excited_vib_state_1_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_1_for_plotting)


#ax.stem(vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset, 
#        vibrational_state_overlaps_df['overlap'],linefmt='g-',markerfmt=' ',label='All',
#       basefmt=" ")

ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='k-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

#print(wavefunction_ground_vib_state_for_plotting_df)

ax.stem(wavefunction_excited_vib_state_0_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_0_for_plotting_df['overlap'],linefmt='g-',markerfmt=' ',label='Torsion + Vibration 1',
       basefmt=" ")

ax.stem(wavefunction_excited_vib_state_1_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_1_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion + Vibration 2',
       basefmt=" ")


ax.legend()
plt.savefig('./theory_exp_spectrum_stick_multiple_vib.pdf')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:68: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:74: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:78: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Plot now with linewidth
# Reads in a list of frequencies and intensities
# Then produces two text files that have the right spectrum
def calc_spectrum_plot(freq_list=None,int_list=None,
                       min_freq=0.0,max_freq=0.0,width=1,resolution=0.05):
    
    num_points = int((max_freq-min_freq)/(resolution))
    
    frequencies = list()
    intensities = list()
    
    for i in range(0,num_points):
        frequency = min_freq+i*resolution
        intensity = 0.0
        
        for j in range(0,len(freq_list)):
            peak_center = freq_list[j]
            peak_height = int_list[j]
           # print(peak_center)
           # print(peak_height)
            intensity = intensity + peak_height*np.exp(-(frequency - peak_center)**2/(2*width))
    
        frequencies.append(frequency)
        intensities.append(intensity)
    
    # normalize the height of the intensities for visualization
    
    intensities = intensities/max(intensities)
    
    return frequencies,intensities

# %%
theory_frequencies,theory_intensities = calc_spectrum_plot(
                    freq_list=vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset,
                    int_list=vibrational_state_overlaps_df['overlap'],
                       min_freq=offset-50,max_freq=offset+750,width=4.0,resolution=0.5)

# %%
# Plot with both spectra on each other

# Set baseline to zero 

kidwell_uv_spectrum_energy = np.loadtxt('2PhPy-H2O UV Spectrum.txt',usecols=1)
kidwell_uv_spectrum_intensity = np.loadtxt('2PhPy-H2O UV Spectrum.txt',usecols=0)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm$^{-1}$', fontsize = 20)
ax.set_ylabel('Intensity', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=20)


ax.set_xlim(32850,33700)

max_freq = 34000
 
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity+1.1,label='Experiment', color='k',ls='-')


theory_plot_intensities = theory_intensities/max(theory_intensities)

# Plot the theory spectrum
ax.plot(theory_frequencies, theory_plot_intensities,label='Smoothed Model', color='k',ls='dashed')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_0_for_plotting = list()
wavefunction_excited_vib_state_1_for_plotting = list()


# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited_0' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_0_for_plotting.append(wavefunction_overlap)
    elif 'vib_excited_1' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_1_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

# Might need to normalize

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_0_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_0_for_plotting)

wavefunction_excited_vib_state_1_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_1_for_plotting)


#ax.stem(vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset, 
#        vibrational_state_overlaps_df['overlap'],linefmt='g-',markerfmt=' ',label='All',
#       basefmt=" ")

ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='k-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

#print(wavefunction_ground_vib_state_for_plotting_df)

ax.stem(wavefunction_excited_vib_state_0_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_0_for_plotting_df['overlap'],linefmt='g-',markerfmt=' ',label='Torsion + Vibration 1',
       basefmt=" ")

ax.stem(wavefunction_excited_vib_state_1_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_1_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion + Vibration 2',
       basefmt=" ")



ax.legend()
plt.savefig('./theory_exp_spectrum_smooth_and_stick_multiple_vib.pdf',bbox_inches='tight')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:74: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:80: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:84: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Generate plots of the wavefunctions
# or squares of the wavefunctions
ground_state_file_name_root='gs_scan_with_h2o'
excited_state_file_name_root='es_scan_with_h2o'
max_num_ground_state_wfs=4
max_num_excited_state_wfs=100

# %%
ground_state_dict = read_dvr_output(filename_root=ground_state_file_name_root,num_states=max_num_ground_state_wfs)
excited_state_dict = read_dvr_output(filename_root=excited_state_file_name_root,num_states=max_num_excited_state_wfs)

# %%
# plot the potential and square of the wavefunction 
# (avoids ambiguity on signs) of the ground state potential


wavefunction_counter = 0

max_wavefunctions = 4

prefix = "kidwell_gs_scan_with_h2o"

for i in range(0,4):
    plot_wavefunction_squared(state_dict=ground_state_dict,
                        state_num=i,prefix="gs_scan_with_h2o_",
                      plotting_potential_name="gs_scan_with_water_fitted.dat",
                     potential="Ground State PES",mass=mass_ground)
# Out:
# Examining state gs_scan_with_h2o_0
# Examining state gs_scan_with_h2o_1
# Examining state gs_scan_with_h2o_2
# Examining state gs_scan_with_h2o_3

# %%
# Excited state square plot

excited_state_plot_list = [0]

for state in excited_state_plot_list:
    plot_wavefunction_squared(state_dict=excited_state_dict,
                        state_num=state,prefix="es_scan_with_h2o_",
                      plotting_potential_name="es_scan_with_water_fitted.dat",
                     potential="Excited State PES",mass=mass_ground)
# Out:
# Examining state es_scan_with_h2o_0

# %%
# Get maximum overlaps to plot those excited state wavefunctions
overlap_df.sort_values(by=['overlap'],ascending=False).head(20)
# Out:
#        energy                 ground_state_id  \
# 31   0.003130  gs_scan_with_h2o_0_vib_excited
# 193  0.003130  gs_scan_with_h2o_1_vib_excited
# 189  0.003006  gs_scan_with_h2o_1_vib_excited
# 27   0.003006  gs_scan_with_h2o_0_vib_excited
# 417  0.006628  gs_scan_with_h2o_2_vib_excited
# 583  0.006628  gs_scan_with_h2o_3_vib_excited
# 595  0.007089  gs_scan_with_h2o_3_vib_excited
# 429  0.007089  gs_scan_with_h2o_2_vib_excited
# 431  0.007089  gs_scan_with_h2o_2_vib_excited
# 593  0.007089  gs_scan_with_h2o_3_vib_excited
# 425  0.006872  gs_scan_with_h2o_2_vib_excited
# 591  0.006872  gs_scan_with_h2o_3_vib_excited
# 589  0.006872  gs_scan_with_h2o_3_vib_excited
# 427  0.006872  gs_scan_with_h2o_2_vib_excited
# 175  0.001686  gs_scan_with_h2o_1_vib_excited
# 9    0.001686  gs_scan_with_h2o_0_vib_excited
# 575  0.006375  gs_scan_with_h2o_3_vib_excited
# 409  0.006375  gs_scan_with_h2o_2_vib_excited
# 30   0.002242              gs_scan_with_h2o_0
# 192  0.002242              gs_scan_with_h2o_1
#
#                     excited_state_id   overlap
# 31   es_scan_with_h2o_15_vib_excited  2.772036
# 193  es_scan_with_h2o_14_vib_excited  2.772026
# 189  es_scan_with_h2o_12_vib_excited  1.356843
# 27   es_scan_with_h2o_13_vib_excited  1.356833
# 417  es_scan_with_h2o_44_vib_excited  0.842094
# 583  es_scan_with_h2o_45_vib_excited  0.842094
# 595  es_scan_with_h2o_51_vib_excited  0.771024
# 429  es_scan_with_h2o_50_vib_excited  0.770633
# 431  es_scan_with_h2o_51_vib_excited  0.767902
# 593  es_scan_with_h2o_50_vib_excited  0.767511
# 425  es_scan_with_h2o_48_vib_excited  0.650645
# 591  es_scan_with_h2o_49_vib_excited  0.650592
# 589  es_scan_with_h2o_48_vib_excited  0.625843
# 427  es_scan_with_h2o_49_vib_excited  0.625791
# 175   es_scan_with_h2o_5_vib_excited  0.550356
# 9     es_scan_with_h2o_4_vib_excited  0.550356
# 575  es_scan_with_h2o_41_vib_excited  0.520370
# 409  es_scan_with_h2o_40_vib_excited  0.520370
# 30               es_scan_with_h2o_15  0.462006
# 192              es_scan_with_h2o_14  0.462004

# %%
# Export overlap to csv file

overlap_df.to_csv('./phpy_h2o_overlap_list_no_zpe.csv')

# %%
# plot potentials with energy levels

# %%
plot_potential_and_energy_levels(state_dict=ground_state_dict,
                       prefix="kidwell_gs_scan_with_h2o",
                      plotting_potential_name="gs_scan_with_water_fitted.dat",
                     potential="Ground State PES",mass=mass_ground,max_energy=70)

# %%
plot_potential_and_energy_levels(state_dict=excited_state_dict,
                       prefix="kidwell_es_scan_with_h2o",
                      plotting_potential_name="es_scan_with_water_fitted.dat",
                     potential="Excited State PES",mass=mass_ground,max_energy=450)
