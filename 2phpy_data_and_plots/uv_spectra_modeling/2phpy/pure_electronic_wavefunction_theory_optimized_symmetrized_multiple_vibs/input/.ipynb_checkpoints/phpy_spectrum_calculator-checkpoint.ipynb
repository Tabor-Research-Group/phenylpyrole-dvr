# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import random
from scipy import interpolate

# %%
import scipy

# %%
import pandas as pd

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 8)

# %%
from scipy.interpolate import interp1d

# %%
from dvr_setup_and_plotting_utils import *

# %%
# Run and collect ground state

# Reduced mass of freqency calculation =

mass_ground = 1836*100
print(str(mass_ground/1836))

num_wavefunctions_ground = 5
grid_points = 500


fit_potential_spline_assume_periodic_write_to_file(raw_potential_filename='gs_scan_no_water_raw_pot_optimized.dat',num_grid_points=grid_points,
                                output_potential_filename='gs_scan_no_water_fitted.dat',shift_origin=0.0,scale_factor=1.00)

#fit_linear_potential_assume_periodic_write_to_file(raw_potential_filename='gs_scan_no_water_raw_pot_optimized.dat',num_grid_points=grid_points,
#                                output_potential_filename='gs_scan_no_water_fitted.dat',shift_origin=0,scale_factor=1.0)


print('potential written')

setup_dvr(num_states=num_wavefunctions_ground,num_grid_points=grid_points,mass=mass_ground,
                         potential_energy_file_name='gs_scan_no_water_fitted.dat',
                        output_file_name='gs_scan_no_h2o')

print('dvr is set up')
# Now need to make the output potential the potential_file.dat and run 
# ./dvr_1d_periodic
# Out:
# 100.0
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp gs_scan_no_water_fitted.dat  potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above
# User must supply their own matrix diagonalization subroutine

# %%
# run DVR
# Now run excited state

mass_excited =   mass_ground
num_wavefunctions_excited = 200
print(str(mass_excited/1836))

fit_potential_spline_assume_periodic_write_to_file(raw_potential_filename='es_scan_no_water_raw_pot_optimized.dat',num_grid_points=grid_points,
                                output_potential_filename='es_scan_no_water_fitted.dat',shift_origin=0.0,scale_factor=1.0)

print('potential written')

setup_dvr(num_states=num_wavefunctions_excited,num_grid_points=grid_points,mass=mass_excited,
                         potential_energy_file_name='es_scan_no_water_fitted.dat',
                        output_file_name='es_scan_no_h2o')

print('dvr is set up')
# Out:
# 100.0
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp es_scan_no_water_fitted.dat potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above

# %%
# Absolute square value of overlaps is calculated here

# %%
wavefunction_overlaps = calculate_overlaps_multiple_vib_shifts(
                                         ground_state_file_name_root='gs_scan_no_h2o',
                                         excited_state_file_name_root='es_scan_no_h2o',
                                         max_num_ground_state_wfs=4,
                                         max_num_excited_state_wfs=100,
                                         ground_state_max_energy=300,
                                         excited_state_max_energy=3000,vib_shifts=[180.0,295.0],vib_scales=[1.0,1.0])
# Out:
# Calculating overlap for transition with energy 0.0
# Calculating overlap for transition with energy 0.00017945818932501464
# Calculating overlap for transition with energy 58.51587837635339
# Calculating overlap for transition with energy 58.51588467846873
# Calculating overlap for transition with energy 121.70764858089575
# Calculating overlap for transition with energy 121.70774950499882
# Calculating overlap for transition with energy 193.22185359815512
# Calculating overlap for transition with energy 193.22185465824407
# Calculating overlap for transition with energy 271.22189784093473
# Calculating overlap for transition with energy 271.2219825234333
# Calculating overlap for transition with energy 354.2501416227183
# Calculating overlap for transition with energy 354.250144050614
# Calculating overlap for transition with energy 440.8835245982321
# Calculating overlap for transition with energy 440.8836034884646
# Calculating overlap for transition with energy 530.6944647629634
# Calculating overlap for transition with energy 530.6944681753547
# Calculating overlap for transition with energy 622.9148778599562
# Calculating overlap for transition with energy 622.9149472578749
# Calculating overlap for transition with energy 717.2853640868085
# Calculating overlap for transition with energy 717.2853647349831
# Calculating overlap for transition with energy 813.4294072870614
# Calculating overlap for transition with energy 813.4294688824233
# Calculating overlap for transition with energy 911.0645260609169
# Calculating overlap for transition with energy 911.06452682783
# Calculating overlap for transition with energy 1009.9543138462354
# Calculating overlap for transition with energy 1009.9543725315625
# Calculating overlap for transition with energy 1109.9408581803368
# Calculating overlap for transition with energy 1109.9408615586306
# Calculating overlap for transition with energy 1210.830249386867
# Calculating overlap for transition with energy 1210.8303072989584
# Calculating overlap for transition with energy 1312.4843693823532
# Calculating overlap for transition with energy 1312.4843749827112
# Calculating overlap for transition with energy 1414.7470667121074
# Calculating overlap for transition with energy 1414.7471208936709
# Calculating overlap for transition with energy 1517.4798972517144
# Calculating overlap for transition with energy 1517.4799013563384
# Calculating overlap for transition with energy 1620.5559729943604
# Calculating overlap for transition with energy 1620.5560222764361
# Calculating overlap for transition with energy 1723.8427521629958
# Calculating overlap for transition with energy 1723.8427546787102
# Calculating overlap for transition with energy 1827.2413465536856
# Calculating overlap for transition with energy 1827.2413920999284
# Calculating overlap for transition with energy 1930.625353735398
# Calculating overlap for transition with energy 1930.6253561253463
# Calculating overlap for transition with energy 2033.9038807507857
# Calculating overlap for transition with energy 2033.903924235274
# Calculating overlap for transition with energy 2136.9563711282904
# Calculating overlap for transition with energy 2136.9563739892856
# Calculating overlap for transition with energy 2239.6872417125346
# Calculating overlap for transition with energy 2239.687284186001
# Calculating overlap for transition with energy 2341.989248545215
# Calculating overlap for transition with energy 2341.9892512017323
# Calculating overlap for transition with energy 2443.779825809395
# Calculating overlap for transition with energy 2443.779864935525
# Calculating overlap for transition with energy 2544.952837354945
# Calculating overlap for transition with energy 2544.9528388143676
# Calculating overlap for transition with energy 2645.433090702258
# Calculating overlap for transition with energy 2645.4331256657833
# Calculating overlap for transition with energy 2745.1150801837202
# Calculating overlap for transition with energy 2745.115081719956
# Calculating overlap for transition with energy 2843.93026714268
# Calculating overlap for transition with energy 2843.9302971638062
# Calculating overlap for transition with energy 2941.7855346891706
# Calculating overlap for transition with energy 2941.7855387245204
# Calculating overlap for transition with energy -1.1007302724189817e-07
# Calculating overlap for transition with energy 0.00017934811629777273
# Calculating overlap for transition with energy 58.515878266280374
# Calculating overlap for transition with energy 58.51588456839569
# Calculating overlap for transition with energy 121.70764847082273
# Calculating overlap for transition with energy 121.7077493949258
# Calculating overlap for transition with energy 193.2218534880821
# Calculating overlap for transition with energy 193.22185454817105
# Calculating overlap for transition with energy 271.2218977308617
# Calculating overlap for transition with energy 271.2219824133603
# Calculating overlap for transition with energy 354.2501415126452
# Calculating overlap for transition with energy 354.25014394054097
# Calculating overlap for transition with energy 440.883524488159
# Calculating overlap for transition with energy 440.8836033783915
# Calculating overlap for transition with energy 530.6944646528904
# Calculating overlap for transition with energy 530.6944680652816
# Calculating overlap for transition with energy 622.9148777498831
# Calculating overlap for transition with energy 622.9149471478019
# Calculating overlap for transition with energy 717.2853639767354
# Calculating overlap for transition with energy 717.28536462491
# Calculating overlap for transition with energy 813.4294071769883
# Calculating overlap for transition with energy 813.4294687723502
# Calculating overlap for transition with energy 911.064525950844
# Calculating overlap for transition with energy 911.0645267177571
# Calculating overlap for transition with energy 1009.9543137361625
# Calculating overlap for transition with energy 1009.9543724214896
# Calculating overlap for transition with energy 1109.9408580702639
# Calculating overlap for transition with energy 1109.9408614485576
# Calculating overlap for transition with energy 1210.830249276794
# Calculating overlap for transition with energy 1210.8303071888854
# Calculating overlap for transition with energy 1312.4843692722802
# Calculating overlap for transition with energy 1312.4843748726382
# Calculating overlap for transition with energy 1414.7470666020345
# Calculating overlap for transition with energy 1414.7471207835977
# Calculating overlap for transition with energy 1517.4798971416415
# Calculating overlap for transition with energy 1517.4799012462654
# Calculating overlap for transition with energy 1620.5559728842875
# Calculating overlap for transition with energy 1620.5560221663632
# Calculating overlap for transition with energy 1723.8427520529228
# Calculating overlap for transition with energy 1723.8427545686372
# Calculating overlap for transition with energy 1827.2413464436127
# Calculating overlap for transition with energy 1827.2413919898554
# Calculating overlap for transition with energy 1930.625353625325
# Calculating overlap for transition with energy 1930.6253560152734
# Calculating overlap for transition with energy 2033.9038806407127
# Calculating overlap for transition with energy 2033.903924125201
# Calculating overlap for transition with energy 2136.9563710182174
# Calculating overlap for transition with energy 2136.9563738792126
# Calculating overlap for transition with energy 2239.6872416024617
# Calculating overlap for transition with energy 2239.687284075928
# Calculating overlap for transition with energy 2341.989248435142
# Calculating overlap for transition with energy 2341.9892510916593
# Calculating overlap for transition with energy 2443.779825699322
# Calculating overlap for transition with energy 2443.779864825452
# Calculating overlap for transition with energy 2544.952837244872
# Calculating overlap for transition with energy 2544.9528387042947
# Calculating overlap for transition with energy 2645.433090592185
# Calculating overlap for transition with energy 2645.4331255557104
# Calculating overlap for transition with energy 2745.1150800736473
# Calculating overlap for transition with energy 2745.115081609883
# Calculating overlap for transition with energy 2843.930267032607
# Calculating overlap for transition with energy 2843.9302970537333
# Calculating overlap for transition with energy 2941.7855345790977
# Calculating overlap for transition with energy 2941.7855386144474
# Calculating overlap for transition with energy -0.09009557139868574
# Calculating overlap for transition with energy -0.08991611320936072
# Calculating overlap for transition with energy 58.4257828049547
# Calculating overlap for transition with energy 58.425789107070045
# Calculating overlap for transition with energy 121.61755300949706
# Calculating overlap for transition with energy 121.61765393360012
# Calculating overlap for transition with energy 193.13175802675642
# Calculating overlap for transition with energy 193.13175908684536
# Calculating overlap for transition with energy 271.1318022695361
# Calculating overlap for transition with energy 271.1318869520347
# Calculating overlap for transition with energy 354.16004605131957
# Calculating overlap for transition with energy 354.1600484792153
# Calculating overlap for transition with energy 440.79342902683345
# Calculating overlap for transition with energy 440.79350791706594
# Calculating overlap for transition with energy 530.6043691915647
# Calculating overlap for transition with energy 530.6043726039561
# Calculating overlap for transition with energy 622.8247822885575
# Calculating overlap for transition with energy 622.8248516864762
# Calculating overlap for transition with energy 717.1952685154099
# Calculating overlap for transition with energy 717.1952691635844
# Calculating overlap for transition with energy 813.3393117156627
# Calculating overlap for transition with energy 813.3393733110247
# Calculating overlap for transition with energy 910.9744304895181
# Calculating overlap for transition with energy 910.9744312564313
# Calculating overlap for transition with energy 1009.8642182748367
# Calculating overlap for transition with energy 1009.8642769601637
# Calculating overlap for transition with energy 1109.850762608938
# Calculating overlap for transition with energy 1109.8507659872319
# Calculating overlap for transition with energy 1210.7401538154681
# Calculating overlap for transition with energy 1210.7402117275594
# Calculating overlap for transition with energy 1312.3942738109545
# Calculating overlap for transition with energy 1312.3942794113125
# Calculating overlap for transition with energy 1414.6569711407087
# Calculating overlap for transition with energy 1414.657025322272
# Calculating overlap for transition with energy 1517.3898016803157
# Calculating overlap for transition with energy 1517.3898057849397
# Calculating overlap for transition with energy 1620.4658774229617
# Calculating overlap for transition with energy 1620.4659267050374
# Calculating overlap for transition with energy 1723.7526565915973
# Calculating overlap for transition with energy 1723.7526591073117
# Calculating overlap for transition with energy 1827.151250982287
# Calculating overlap for transition with energy 1827.1512965285299
# Calculating overlap for transition with energy 1930.5352581639995
# Calculating overlap for transition with energy 1930.5352605539476
# Calculating overlap for transition with energy 2033.813785179387
# Calculating overlap for transition with energy 2033.8138286638753
# Calculating overlap for transition with energy 2136.866275556892
# Calculating overlap for transition with energy 2136.866278417887
# Calculating overlap for transition with energy 2239.597146141136
# Calculating overlap for transition with energy 2239.5971886146026
# Calculating overlap for transition with energy 2341.899152973817
# Calculating overlap for transition with energy 2341.899155630334
# Calculating overlap for transition with energy 2443.689730237996
# Calculating overlap for transition with energy 2443.6897693641267
# Calculating overlap for transition with energy 2544.8627417835464
# Calculating overlap for transition with energy 2544.862743242969
# Calculating overlap for transition with energy 2645.3429951308594
# Calculating overlap for transition with energy 2645.3430300943846
# Calculating overlap for transition with energy 2745.024984612322
# Calculating overlap for transition with energy 2745.024986148557
# Calculating overlap for transition with energy 2843.8401715712816
# Calculating overlap for transition with energy 2843.8402015924075
# Calculating overlap for transition with energy 2941.695439117772
# Calculating overlap for transition with energy 2941.6954431531217
# Calculating overlap for transition with energy -0.09009588555656324
# Calculating overlap for transition with energy -0.08991642736723823
# Calculating overlap for transition with energy 58.425782490796834
# Calculating overlap for transition with energy 58.425788792912165
# Calculating overlap for transition with energy 121.61755269533919
# Calculating overlap for transition with energy 121.61765361944225
# Calculating overlap for transition with energy 193.13175771259856
# Calculating overlap for transition with energy 193.1317587726875
# Calculating overlap for transition with energy 271.1318019553782
# Calculating overlap for transition with energy 271.13188663787673
# Calculating overlap for transition with energy 354.1600457371617
# Calculating overlap for transition with energy 354.16004816505745
# Calculating overlap for transition with energy 440.7934287126755
# Calculating overlap for transition with energy 440.793507602908
# Calculating overlap for transition with energy 530.6043688774068
# Calculating overlap for transition with energy 530.6043722897982
# Calculating overlap for transition with energy 622.8247819743996
# Calculating overlap for transition with energy 622.8248513723183
# Calculating overlap for transition with energy 717.1952682012519
# Calculating overlap for transition with energy 717.1952688494265
# Calculating overlap for transition with energy 813.3393114015048
# Calculating overlap for transition with energy 813.3393729968667
# Calculating overlap for transition with energy 910.9744301753605
# Calculating overlap for transition with energy 910.9744309422736
# Calculating overlap for transition with energy 1009.864217960679
# Calculating overlap for transition with energy 1009.864276646006
# Calculating overlap for transition with energy 1109.8507622947802
# Calculating overlap for transition with energy 1109.8507656730742
# Calculating overlap for transition with energy 1210.7401535013105
# Calculating overlap for transition with energy 1210.7402114134018
# Calculating overlap for transition with energy 1312.3942734967966
# Calculating overlap for transition with energy 1312.3942790971548
# Calculating overlap for transition with energy 1414.6569708265508
# Calculating overlap for transition with energy 1414.6570250081143
# Calculating overlap for transition with energy 1517.389801366158
# Calculating overlap for transition with energy 1517.3898054707818
# Calculating overlap for transition with energy 1620.465877108804
# Calculating overlap for transition with energy 1620.4659263908795
# Calculating overlap for transition with energy 1723.7526562774392
# Calculating overlap for transition with energy 1723.7526587931538
# Calculating overlap for transition with energy 1827.151250668129
# Calculating overlap for transition with energy 1827.1512962143718
# Calculating overlap for transition with energy 1930.5352578498414
# Calculating overlap for transition with energy 1930.5352602397897
# Calculating overlap for transition with energy 2033.813784865229
# Calculating overlap for transition with energy 2033.8138283497174
# Calculating overlap for transition with energy 2136.866275242734
# Calculating overlap for transition with energy 2136.866278103729
# Calculating overlap for transition with energy 2239.5971458269782
# Calculating overlap for transition with energy 2239.5971883004445
# Calculating overlap for transition with energy 2341.8991526596587
# Calculating overlap for transition with energy 2341.899155316176
# Calculating overlap for transition with energy 2443.689729923838
# Calculating overlap for transition with energy 2443.6897690499686
# Calculating overlap for transition with energy 2544.8627414693883
# Calculating overlap for transition with energy 2544.862742928811
# Calculating overlap for transition with energy 2645.3429948167013
# Calculating overlap for transition with energy 2645.343029780227
# Calculating overlap for transition with energy 2745.024984298164
# Calculating overlap for transition with energy 2745.0249858343996
# Calculating overlap for transition with energy 2843.8401712571235
# Calculating overlap for transition with energy 2843.84020127825
# Calculating overlap for transition with energy 2941.6954388036143
# Calculating overlap for transition with energy 2941.695442838964

# %%
#This produces a list of dictionaries
# Showing example
wavefunction_overlaps[88]
# Out:
# {'energy': 0.006337089199325491,
#  'ground_state_id': 'gs_scan_no_h2o_0_vib_excited_0',
#  'excited_state_id': 'es_scan_no_h2o_29_vib_excited_0',
#  'overlap': 0.06922666574040871}

# %%
overlap_df = pd.DataFrame(wavefunction_overlaps)

# %%
# Initial spectral plots

# %%
# Now, convert from a.u. to cm^-1, plot stem plot and compare to the experimental spectrum

offset = 33380

kidwell_uv_spectrum_energy = np.loadtxt('2PhPy UV Spectrum.txt',usecols=1)
kidwell_uv_spectrum_intensity = np.loadtxt('2PhPy UV Spectrum.txt',usecols=0)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm^-1', fontsize = 12)
ax.set_ylabel('Intensity', fontsize = 12)
# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(33250,34500)
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity,label='Experiment', color='k',ls='-')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_0_state_for_plotting = list()
wavefunction_excited_vib_1_state_for_plotting = list()


# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited_0' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_0_for_plotting.append(wavefunction_overlap)
    elif 'vib_excited_1' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_1_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

# Might need to normalize

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)

#ax.stem(vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset, 
#        vibrational_state_overlaps_df['overlap'],linefmt='g-',markerfmt=' ',label='All',
#       basefmt=" ")

ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

#print(wavefunction_ground_vib_state_for_plotting_df)

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


#ax.stem(ground_vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset, 
#        ground_vibrational_state_overlaps_df['overlap'],linefmt='g-',markerfmt=' ',label='n=0 ground origin',
 #      basefmt=" ")

ax.legend()
plt.savefig('./theory_exp_spectrum_compare_mass_no_water_zpe_for_presentation.pdf')
plt.show()

# %%
# Plot now with linewidth
# Reads in a list of frequencies and intensities
# Then produces two text files that have the right spectrum
def calc_spectrum_plot(freq_list=None,int_list=None,
                       min_freq=0.0,max_freq=0.0,width=1,resolution=0.05):
    
    num_points = int((max_freq-min_freq)/(resolution))
    
    frequencies = list()
    intensities = list()
    
    for i in range(0,num_points):
        frequency = min_freq+i*resolution
        intensity = 0.0
        
        for j in range(0,len(freq_list)):
            peak_center = freq_list[j]
            peak_height = int_list[j]
           # print(peak_center)
           # print(peak_height)
            intensity = intensity + peak_height*np.exp(-(frequency - peak_center)**2/(2*width))
    
        frequencies.append(frequency)
        intensities.append(intensity)
    
    return frequencies,intensities

# %%
theory_frequencies,theory_intensities = calc_spectrum_plot(
                    freq_list=vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset,
                    int_list=vibrational_state_overlaps_df['overlap'],
                       min_freq=offset-100,max_freq=offset+2500,width=5.0,resolution=1.0)

# %%
# Plot with both spectra on each other
# Two versions, one narrow range, one wider range

# %%
# Wide range

# Set baseline to zero 

kidwell_uv_spectrum_energy = np.loadtxt('2PhPy UV Spectrum.txt',usecols=1)
kidwell_uv_spectrum_intensity = np.loadtxt('2PhPy UV Spectrum.txt',usecols=0)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm$^{-1}$', fontsize = 20)
ax.set_ylabel('Intensity', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=20)

# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(33250,34500)

max_freq = 38000
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity+0.8,label='Experiment', color='k',ls='-')


theory_plot_intensities = theory_intensities/max(theory_intensities)

# Plot the theory spectrum
ax.plot(theory_frequencies, theory_plot_intensities,label='Smoothed Model', color='k',ls='dashed')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)


ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


ax.legend()
plt.savefig('./theory_exp_spectrum_smooth_masses_no_water_zpe_for_presentation_wide_range.pdf',bbox_inches='tight')
plt.show()

# %%
# Narrow Range

# Set baseline to zero 

kidwell_uv_spectrum_energy = np.loadtxt('2PhPy UV Spectrum.txt',usecols=1)
kidwell_uv_spectrum_intensity = np.loadtxt('2PhPy UV Spectrum.txt',usecols=0)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm$^{-1}$', fontsize = 20)
ax.set_ylabel('Intensity', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=20)

# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(33250,34500)

max_freq = 36250
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity+0.8,label='Experiment', color='k',ls='-')


theory_plot_intensities = theory_intensities/max(theory_intensities)

# Plot the theory spectrum
ax.plot(theory_frequencies, theory_plot_intensities,label='Smoothed Model', color='k',ls='dashed')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)


ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


ax.legend()
plt.savefig('./theory_exp_spectrum_smooth_masses_no_water_zpe_for_presentation_narrow_range.pdf',bbox_inches='tight')
plt.show()

# %%
# Plot the lowest 4 ground state wavefunctions
ground_state_file_name_root='gs_scan_no_h2o'
excited_state_file_name_root='es_scan_no_h2o'
max_num_ground_state_wfs=4
max_num_excited_state_wfs=100

# %%
ground_state_dict = read_dvr_output(filename_root=ground_state_file_name_root,num_states=max_num_ground_state_wfs)
excited_state_dict = read_dvr_output(filename_root=excited_state_file_name_root,num_states=max_num_excited_state_wfs)

# %%
# plot the potential and square of the wavefunction 
# (avoids ambiguity on signs) of the ground state potential

wavefunction_counter = 0

max_wavefunctions = 4

for i in range(0,4):
    plot_wavefunction_squared(state_dict=ground_state_dict,
                        state_num=i,prefix="gs_scan_no_h2o_",
                      plotting_potential_name="gs_scan_no_water_fitted.dat",
                     potential="Ground State PES",mass=mass_ground)

# %%
plot_potential_and_energy_levels(state_dict=ground_state_dict,
                       prefix="gs_scan_no_h2o_",
                      plotting_potential_name="gs_scan_no_water_fitted.dat",
                     potential="Ground State PES",mass=mass_ground,max_energy=200)

# %%
plot_potential_and_energy_levels(state_dict=excited_state_dict,
                       prefix="es_scan_no_h2o",
                      plotting_potential_name="es_scan_no_water_fitted.dat",
                     potential="Excited State PES",mass=mass_ground,max_energy=1500)

# %%
# Get maximum overlaps so we can plot those excited state wavefunctions
overlap_df.sort_values(by=['overlap'],ascending=False).head(60)

# %%
# Export overlap to csv file

overlap_df.to_csv('./phpy_overlap_list_no_zpe.csv')
