# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import random
from scipy import interpolate

# %%
import scipy

# %%
import pandas as pd

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 8)

# %%
from scipy.interpolate import interp1d

# %%
from dvr_setup_and_plotting_utils import *

# %%
# Run and collect ground state

# Reduced mass of freqency calculation =  3.5708    AMU

mass_ground = 3.5708*1836*22
print(str(mass_ground/1836))

num_wavefunctions_ground = 5
grid_points = 500


fit_linear_potential_assume_periodic_write_to_file(raw_potential_filename='gs_scan_no_water_raw_pot_zpe.dat',num_grid_points=grid_points,
                                output_potential_filename='gs_scan_no_water_fitted_zpe.dat',shift_origin=0.0,scale_factor=1.00)


print('potential written')

setup_dvr(num_states=num_wavefunctions_ground,num_grid_points=grid_points,mass=mass_ground,
                         potential_energy_file_name='gs_scan_no_water_fitted_zpe.dat',
                        output_file_name='gs_scan_no_h2o_zpe')

print('dvr is set up')
# Now need to make the output potential the potential_file.dat and run 
# ./dvr_1d_periodic
# Out:
# 78.5576
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp gs_scan_no_water_fitted_zpe.dat  potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above
# User must supply their own matrix diagonalization subroutine

# %%
# run DVR
# Now run excited state

mass_excited =   3.5786*1836*22
num_wavefunctions_excited = 200
print(str(mass_excited/1836))

# Trying pure linear interpolation. The old cubic spline is below
#fit_potential_assume_periodic_write_to_file(raw_potential_filename='kidwell_es_scan_with_water_raw_pot_with_zpe.dat',num_grid_points=grid_points,
#                                output_potential_filename='es_scan_with_water_fitted_zpe.dat',shift_origin=0.0,scale_factor=1.0)

fit_linear_potential_assume_periodic_write_to_file(raw_potential_filename='es_scan_no_water_raw_pot_zpe.dat',num_grid_points=grid_points,
                                output_potential_filename='es_scan_no_water_fitted_zpe.dat',shift_origin=0.0,scale_factor=1.0)

print('potential written')

setup_dvr(num_states=num_wavefunctions_excited,num_grid_points=grid_points,mass=mass_excited,
                         potential_energy_file_name='es_scan_no_water_fitted_zpe.dat',
                        output_file_name='es_scan_no_h2o_zpe')

print('dvr is set up')
# Out:
# 78.72919999999999
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp es_scan_no_water_fitted_zpe.dat potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above

# %%
# Absolute value of overlaps is calculated here

# %%
wavefunction_overlaps = read_wavefunctions_calculate_overlaps_vib_shift(
                                         ground_state_file_name_root='gs_scan_no_h2o_zpe',
                                         excited_state_file_name_root='es_scan_no_h2o_zpe',
                                         max_num_ground_state_wfs=4,
                                         max_num_excited_state_wfs=100,
                                         ground_state_max_energy=300,
                                         excited_state_max_energy=3000,
                                         vib_shift=263.0,
                                        vib_scale=1.0)
# Out:
# Calculating overlap for transition with energy 0.0
# Calculating overlap for transition with energy 61.74351834588957
# Calculating overlap for transition with energy 118.47035352790348
# Calculating overlap for transition with energy 160.69732892114808
# Calculating overlap for transition with energy 218.2613685201483
# Calculating overlap for transition with energy 288.42676576536724
# Calculating overlap for transition with energy 319.40863115953425
# Calculating overlap for transition with energy 411.5490228943743
# Calculating overlap for transition with energy 440.15291729481993
# Calculating overlap for transition with energy 500.27168677517034
# Calculating overlap for transition with energy 502.05438114161905
# Calculating overlap for transition with energy 551.2930016058878
# Calculating overlap for transition with energy 564.6687192295223
# Calculating overlap for transition with energy 586.0003724016925
# Calculating overlap for transition with energy 592.3058912528645
# Calculating overlap for transition with energy 598.352481874906
# Calculating overlap for transition with energy 644.679077969083
# Calculating overlap for transition with energy 659.9041934972155
# Calculating overlap for transition with energy 669.7616943720004
# Calculating overlap for transition with energy 691.0059169773563
# Calculating overlap for transition with energy 737.6879509782983
# Calculating overlap for transition with energy 739.1793468050835
# Calculating overlap for transition with energy 749.0207140588038
# Calculating overlap for transition with energy 752.2143010569724
# Calculating overlap for transition with energy 784.4347005433186
# Calculating overlap for transition with energy 830.7516466562552
# Calculating overlap for transition with energy 830.8419642794497
# Calculating overlap for transition with energy 833.384823862846
# Calculating overlap for transition with energy 875.8496503709707
# Calculating overlap for transition with energy 886.3959994609147
# Calculating overlap for transition with energy 899.1842079272698
# Calculating overlap for transition with energy 907.251093743279
# Calculating overlap for transition with energy 919.312406288262
# Calculating overlap for transition with energy 960.0630124393535
# Calculating overlap for transition with energy 962.0915314020725
# Calculating overlap for transition with energy 972.9675172516634
# Calculating overlap for transition with energy 1005.3084841623854
# Calculating overlap for transition with energy 1014.1249559597046
# Calculating overlap for transition with energy 1028.98716711766
# Calculating overlap for transition with energy 1037.3913184648416
# Calculating overlap for transition with energy 1050.8331557721176
# Calculating overlap for transition with energy 1074.2505878065765
# Calculating overlap for transition with energy 1097.1420433978897
# Calculating overlap for transition with energy 1107.078062786167
# Calculating overlap for transition with energy 1143.0478425084236
# Calculating overlap for transition with energy 1145.5031644250805
# Calculating overlap for transition with energy 1169.5846429566498
# Calculating overlap for transition with energy 1181.03537547555
# Calculating overlap for transition with energy 1202.997229577473
# Calculating overlap for transition with energy 1221.3819280453538
# Calculating overlap for transition with energy 1250.8537193068005
# Calculating overlap for transition with energy 1259.980678537067
# Calculating overlap for transition with energy 1293.148495390161
# Calculating overlap for transition with energy 1301.0917811781185
# Calculating overlap for transition with energy 1327.7568414470159
# Calculating overlap for transition with energy 1340.998697697369
# Calculating overlap for transition with energy 1371.5516776261898
# Calculating overlap for transition with energy 1382.1805195852908
# Calculating overlap for transition with energy 1414.3881889887552
# Calculating overlap for transition with energy 1424.4330787734796
# Calculating overlap for transition with energy 1450.6539644418565
# Calculating overlap for transition with energy 1467.092363519496
# Calculating overlap for transition with energy 1489.1518502475105
# Calculating overlap for transition with energy 1511.4792934532845
# Calculating overlap for transition with energy 1528.9718658692223
# Calculating overlap for transition with energy 1558.4335775458287
# Calculating overlap for transition with energy 1569.6556371780514
# Calculating overlap for transition with energy 1605.0336848976324
# Calculating overlap for transition with energy 1615.7013635211306
# Calculating overlap for transition with energy 1654.889583254724
# Calculating overlap for transition with energy 1662.931030036567
# Calculating overlap for transition with energy 1707.031641393184
# Calculating overlap for transition with energy 1711.7316027780107
# Calculating overlap for transition with energy 1759.046185238627
# Calculating overlap for transition with energy 1764.7062063832675
# Calculating overlap for transition with energy 1814.1215066722882
# Calculating overlap for transition with energy 1818.3804180038535
# Calculating overlap for transition with energy 1871.412122065627
# Calculating overlap for transition with energy 1873.393896785324
# Calculating overlap for transition with energy 1928.8866609101567
# Calculating overlap for transition with energy 1931.7566667607075
# Calculating overlap for transition with energy 1988.9132642200036
# Calculating overlap for transition with energy 1990.9955153776466
# Calculating overlap for transition with energy 2051.0859433579417
# Calculating overlap for transition with energy 2051.4765796889096
# Calculating overlap for transition with energy 2113.276317673244
# Calculating overlap for transition with energy 2115.263966678613
# Calculating overlap for transition with energy 2178.0763115949007
# Calculating overlap for transition with energy 2179.7501251080735
# Calculating overlap for transition with energy 2244.970898152253
# Calculating overlap for transition with energy 2245.3854501311366
# Calculating overlap for transition with energy 2312.3323524240604
# Calculating overlap for transition with energy 2313.798984479855
# Calculating overlap for transition with energy 2381.737529753622
# Calculating overlap for transition with energy 2383.3899072714876
# Calculating overlap for transition with energy 2453.267004892698
# Calculating overlap for transition with energy 2454.0393322259724
# Calculating overlap for transition with energy 2525.8340497423214
# Calculating overlap for transition with energy 2526.827787412704
# Calculating overlap for transition with energy 2599.967671907284
# Calculating overlap for transition with energy -0.2164870912777642
# Calculating overlap for transition with energy 61.527031254611806
# Calculating overlap for transition with energy 118.25386643662573
# Calculating overlap for transition with energy 160.48084182987031
# Calculating overlap for transition with energy 218.04488142887053
# Calculating overlap for transition with energy 288.21027867408947
# Calculating overlap for transition with energy 319.1921440682565
# Calculating overlap for transition with energy 411.33253580309656
# Calculating overlap for transition with energy 439.93643020354216
# Calculating overlap for transition with energy 500.05519968389257
# Calculating overlap for transition with energy 501.83789405034133
# Calculating overlap for transition with energy 551.0765145146099
# Calculating overlap for transition with energy 564.4522321382445
# Calculating overlap for transition with energy 585.7838853104147
# Calculating overlap for transition with energy 592.0894041615868
# Calculating overlap for transition with energy 598.1359947836282
# Calculating overlap for transition with energy 644.4625908778053
# Calculating overlap for transition with energy 659.6877064059377
# Calculating overlap for transition with energy 669.5452072807227
# Calculating overlap for transition with energy 690.7894298860786
# Calculating overlap for transition with energy 737.4714638870206
# Calculating overlap for transition with energy 738.9628597138058
# Calculating overlap for transition with energy 748.8042269675261
# Calculating overlap for transition with energy 751.9978139656947
# Calculating overlap for transition with energy 784.2182134520409
# Calculating overlap for transition with energy 830.5351595649774
# Calculating overlap for transition with energy 830.6254771881719
# Calculating overlap for transition with energy 833.1683367715683
# Calculating overlap for transition with energy 875.6331632796929
# Calculating overlap for transition with energy 886.1795123696369
# Calculating overlap for transition with energy 898.967720835992
# Calculating overlap for transition with energy 907.0346066520012
# Calculating overlap for transition with energy 919.0959191969841
# Calculating overlap for transition with energy 959.8465253480757
# Calculating overlap for transition with energy 961.8750443107947
# Calculating overlap for transition with energy 972.7510301603857
# Calculating overlap for transition with energy 1005.0919970711076
# Calculating overlap for transition with energy 1013.9084688684268
# Calculating overlap for transition with energy 1028.770680026382
# Calculating overlap for transition with energy 1037.1748313735638
# Calculating overlap for transition with energy 1050.61666868084
# Calculating overlap for transition with energy 1074.0341007152988
# Calculating overlap for transition with energy 1096.925556306612
# Calculating overlap for transition with energy 1106.861575694889
# Calculating overlap for transition with energy 1142.831355417146
# Calculating overlap for transition with energy 1145.2866773338028
# Calculating overlap for transition with energy 1169.368155865372
# Calculating overlap for transition with energy 1180.8188883842722
# Calculating overlap for transition with energy 1202.7807424861953
# Calculating overlap for transition with energy 1221.1654409540758
# Calculating overlap for transition with energy 1250.6372322155225
# Calculating overlap for transition with energy 1259.7641914457893
# Calculating overlap for transition with energy 1292.9320082988831
# Calculating overlap for transition with energy 1300.8752940868408
# Calculating overlap for transition with energy 1327.5403543557381
# Calculating overlap for transition with energy 1340.782210606091
# Calculating overlap for transition with energy 1371.335190534912
# Calculating overlap for transition with energy 1381.964032494013
# Calculating overlap for transition with energy 1414.1717018974775
# Calculating overlap for transition with energy 1424.2165916822019
# Calculating overlap for transition with energy 1450.4374773505785
# Calculating overlap for transition with energy 1466.8758764282184
# Calculating overlap for transition with energy 1488.9353631562328
# Calculating overlap for transition with energy 1511.2628063620068
# Calculating overlap for transition with energy 1528.7553787779443
# Calculating overlap for transition with energy 1558.217090454551
# Calculating overlap for transition with energy 1569.4391500867737
# Calculating overlap for transition with energy 1604.8171978063547
# Calculating overlap for transition with energy 1615.4848764298529
# Calculating overlap for transition with energy 1654.6730961634462
# Calculating overlap for transition with energy 1662.7145429452894
# Calculating overlap for transition with energy 1706.8151543019062
# Calculating overlap for transition with energy 1711.515115686733
# Calculating overlap for transition with energy 1758.829698147349
# Calculating overlap for transition with energy 1764.4897192919896
# Calculating overlap for transition with energy 1813.9050195810103
# Calculating overlap for transition with energy 1818.1639309125756
# Calculating overlap for transition with energy 1871.195634974349
# Calculating overlap for transition with energy 1873.177409694046
# Calculating overlap for transition with energy 1928.6701738188788
# Calculating overlap for transition with energy 1931.5401796694296
# Calculating overlap for transition with energy 1988.6967771287257
# Calculating overlap for transition with energy 1990.7790282863687
# Calculating overlap for transition with energy 2050.8694562666637
# Calculating overlap for transition with energy 2051.2600925976317
# Calculating overlap for transition with energy 2113.0598305819663
# Calculating overlap for transition with energy 2115.047479587335
# Calculating overlap for transition with energy 2177.859824503623
# Calculating overlap for transition with energy 2179.5336380167955
# Calculating overlap for transition with energy 2244.754411060975
# Calculating overlap for transition with energy 2245.1689630398587
# Calculating overlap for transition with energy 2312.1158653327825
# Calculating overlap for transition with energy 2313.582497388577
# Calculating overlap for transition with energy 2381.521042662344
# Calculating overlap for transition with energy 2383.1734201802096
# Calculating overlap for transition with energy 2453.05051780142
# Calculating overlap for transition with energy 2453.8228451346945
# Calculating overlap for transition with energy 2525.6175626510435
# Calculating overlap for transition with energy 2526.611300321426
# Calculating overlap for transition with energy 2599.751184816006
# Calculating overlap for transition with energy -0.3810716704986324
# Calculating overlap for transition with energy 61.36244667539094
# Calculating overlap for transition with energy 118.08928185740486
# Calculating overlap for transition with energy 160.31625725064944
# Calculating overlap for transition with energy 217.88029684964968
# Calculating overlap for transition with energy 288.0456940948686
# Calculating overlap for transition with energy 319.02755948903564
# Calculating overlap for transition with energy 411.16795122387566
# Calculating overlap for transition with energy 439.77184562432126
# Calculating overlap for transition with energy 499.89061510467167
# Calculating overlap for transition with energy 501.6733094711204
# Calculating overlap for transition with energy 550.911929935389
# Calculating overlap for transition with energy 564.2876475590236
# Calculating overlap for transition with energy 585.6193007311938
# Calculating overlap for transition with energy 591.9248195823659
# Calculating overlap for transition with energy 597.9714102044073
# Calculating overlap for transition with energy 644.2980062985844
# Calculating overlap for transition with energy 659.5231218267168
# Calculating overlap for transition with energy 669.3806227015018
# Calculating overlap for transition with energy 690.6248453068577
# Calculating overlap for transition with energy 737.3068793077997
# Calculating overlap for transition with energy 738.7982751345847
# Calculating overlap for transition with energy 748.6396423883052
# Calculating overlap for transition with energy 751.8332293864738
# Calculating overlap for transition with energy 784.05362887282
# Calculating overlap for transition with energy 830.3705749857565
# Calculating overlap for transition with energy 830.460892608951
# Calculating overlap for transition with energy 833.0037521923474
# Calculating overlap for transition with energy 875.4685787004721
# Calculating overlap for transition with energy 886.0149277904161
# Calculating overlap for transition with energy 898.8031362567712
# Calculating overlap for transition with energy 906.8700220727803
# Calculating overlap for transition with energy 918.9313346177634
# Calculating overlap for transition with energy 959.6819407688549
# Calculating overlap for transition with energy 961.7104597315739
# Calculating overlap for transition with energy 972.5864455811649
# Calculating overlap for transition with energy 1004.9274124918868
# Calculating overlap for transition with energy 1013.743884289206
# Calculating overlap for transition with energy 1028.6060954471614
# Calculating overlap for transition with energy 1037.010246794343
# Calculating overlap for transition with energy 1050.452084101619
# Calculating overlap for transition with energy 1073.869516136078
# Calculating overlap for transition with energy 1096.7609717273913
# Calculating overlap for transition with energy 1106.6969911156684
# Calculating overlap for transition with energy 1142.666770837925
# Calculating overlap for transition with energy 1145.122092754582
# Calculating overlap for transition with energy 1169.2035712861511
# Calculating overlap for transition with energy 1180.6543038050513
# Calculating overlap for transition with energy 1202.6161579069746
# Calculating overlap for transition with energy 1221.0008563748552
# Calculating overlap for transition with energy 1250.4726476363019
# Calculating overlap for transition with energy 1259.5996068665684
# Calculating overlap for transition with energy 1292.7674237196625
# Calculating overlap for transition with energy 1300.71070950762
# Calculating overlap for transition with energy 1327.3757697765172
# Calculating overlap for transition with energy 1340.6176260268703
# Calculating overlap for transition with energy 1371.1706059556911
# Calculating overlap for transition with energy 1381.7994479147922
# Calculating overlap for transition with energy 1414.0071173182566
# Calculating overlap for transition with energy 1424.0520071029812
# Calculating overlap for transition with energy 1450.2728927713579
# Calculating overlap for transition with energy 1466.7112918489975
# Calculating overlap for transition with energy 1488.7707785770122
# Calculating overlap for transition with energy 1511.098221782786
# Calculating overlap for transition with energy 1528.5907941987236
# Calculating overlap for transition with energy 1558.05250587533
# Calculating overlap for transition with energy 1569.2745655075528
# Calculating overlap for transition with energy 1604.6526132271338
# Calculating overlap for transition with energy 1615.3202918506322
# Calculating overlap for transition with energy 1654.5085115842255
# Calculating overlap for transition with energy 1662.5499583660687
# Calculating overlap for transition with energy 1706.6505697226853
# Calculating overlap for transition with energy 1711.350531107512
# Calculating overlap for transition with energy 1758.6651135681284
# Calculating overlap for transition with energy 1764.3251347127689
# Calculating overlap for transition with energy 1813.7404350017894
# Calculating overlap for transition with energy 1817.9993463333547
# Calculating overlap for transition with energy 1871.0310503951282
# Calculating overlap for transition with energy 1873.012825114825
# Calculating overlap for transition with energy 1928.5055892396579
# Calculating overlap for transition with energy 1931.3755950902087
# Calculating overlap for transition with energy 1988.532192549505
# Calculating overlap for transition with energy 1990.614443707148
# Calculating overlap for transition with energy 2050.704871687443
# Calculating overlap for transition with energy 2051.095508018411
# Calculating overlap for transition with energy 2112.8952460027454
# Calculating overlap for transition with energy 2114.8828950081142
# Calculating overlap for transition with energy 2177.695239924402
# Calculating overlap for transition with energy 2179.3690534375746
# Calculating overlap for transition with energy 2244.5898264817542
# Calculating overlap for transition with energy 2245.0043784606382
# Calculating overlap for transition with energy 2311.9512807535616
# Calculating overlap for transition with energy 2313.417912809356
# Calculating overlap for transition with energy 2381.356458083123
# Calculating overlap for transition with energy 2383.0088356009887
# Calculating overlap for transition with energy 2452.885933222199
# Calculating overlap for transition with energy 2453.6582605554736
# Calculating overlap for transition with energy 2525.4529780718226
# Calculating overlap for transition with energy 2526.446715742205
# Calculating overlap for transition with energy 2599.586600236785
# Calculating overlap for transition with energy -0.6704956123031498
# Calculating overlap for transition with energy 61.07302273358641
# Calculating overlap for transition with energy 117.79985791560034
# Calculating overlap for transition with energy 160.0268333088449
# Calculating overlap for transition with energy 217.59087290784515
# Calculating overlap for transition with energy 287.7562701530641
# Calculating overlap for transition with energy 318.7381355472311
# Calculating overlap for transition with energy 410.87852728207116
# Calculating overlap for transition with energy 439.4824216825167
# Calculating overlap for transition with energy 499.60119116286717
# Calculating overlap for transition with energy 501.3838855293159
# Calculating overlap for transition with energy 550.6225059935845
# Calculating overlap for transition with energy 563.9982236172191
# Calculating overlap for transition with energy 585.3298767893893
# Calculating overlap for transition with energy 591.6353956405613
# Calculating overlap for transition with energy 597.6819862626028
# Calculating overlap for transition with energy 644.0085823567798
# Calculating overlap for transition with energy 659.2336978849122
# Calculating overlap for transition with energy 669.0911987596972
# Calculating overlap for transition with energy 690.3354213650531
# Calculating overlap for transition with energy 737.0174553659951
# Calculating overlap for transition with energy 738.5088511927803
# Calculating overlap for transition with energy 748.3502184465007
# Calculating overlap for transition with energy 751.5438054446693
# Calculating overlap for transition with energy 783.7642049310155
# Calculating overlap for transition with energy 830.081151043952
# Calculating overlap for transition with energy 830.1714686671465
# Calculating overlap for transition with energy 832.7143282505428
# Calculating overlap for transition with energy 875.1791547586676
# Calculating overlap for transition with energy 885.7255038486115
# Calculating overlap for transition with energy 898.5137123149666
# Calculating overlap for transition with energy 906.5805981309758
# Calculating overlap for transition with energy 918.6419106759587
# Calculating overlap for transition with energy 959.3925168270504
# Calculating overlap for transition with energy 961.4210357897692
# Calculating overlap for transition with energy 972.2970216393602
# Calculating overlap for transition with energy 1004.6379885500822
# Calculating overlap for transition with energy 1013.4544603474013
# Calculating overlap for transition with energy 1028.3166715053567
# Calculating overlap for transition with energy 1036.7208228525383
# Calculating overlap for transition with energy 1050.1626601598143
# Calculating overlap for transition with energy 1073.5800921942732
# Calculating overlap for transition with energy 1096.4715477855866
# Calculating overlap for transition with energy 1106.4075671738638
# Calculating overlap for transition with energy 1142.3773468961206
# Calculating overlap for transition with energy 1144.8326688127772
# Calculating overlap for transition with energy 1168.9141473443465
# Calculating overlap for transition with energy 1180.3648798632466
# Calculating overlap for transition with energy 1202.32673396517
# Calculating overlap for transition with energy 1220.7114324330505
# Calculating overlap for transition with energy 1250.1832236944972
# Calculating overlap for transition with energy 1259.3101829247637
# Calculating overlap for transition with energy 1292.4779997778578
# Calculating overlap for transition with energy 1300.4212855658154
# Calculating overlap for transition with energy 1327.0863458347126
# Calculating overlap for transition with energy 1340.3282020850656
# Calculating overlap for transition with energy 1370.8811820138865
# Calculating overlap for transition with energy 1381.5100239729875
# Calculating overlap for transition with energy 1413.717693376452
# Calculating overlap for transition with energy 1423.7625831611765
# Calculating overlap for transition with energy 1449.9834688295532
# Calculating overlap for transition with energy 1466.4218679071928
# Calculating overlap for transition with energy 1488.4813546352075
# Calculating overlap for transition with energy 1510.8087978409815
# Calculating overlap for transition with energy 1528.301370256919
# Calculating overlap for transition with energy 1557.7630819335257
# Calculating overlap for transition with energy 1568.985141565748
# Calculating overlap for transition with energy 1604.363189285329
# Calculating overlap for transition with energy 1615.0308679088275
# Calculating overlap for transition with energy 1654.2190876424208
# Calculating overlap for transition with energy 1662.260534424264
# Calculating overlap for transition with energy 1706.3611457808806
# Calculating overlap for transition with energy 1711.0611071657074
# Calculating overlap for transition with energy 1758.375689626324
# Calculating overlap for transition with energy 1764.0357107709644
# Calculating overlap for transition with energy 1813.451011059985
# Calculating overlap for transition with energy 1817.7099223915502
# Calculating overlap for transition with energy 1870.7416264533238
# Calculating overlap for transition with energy 1872.7234011730206
# Calculating overlap for transition with energy 1928.2161652978534
# Calculating overlap for transition with energy 1931.0861711484042
# Calculating overlap for transition with energy 1988.2427686077006
# Calculating overlap for transition with energy 1990.3250197653435
# Calculating overlap for transition with energy 2050.415447745638
# Calculating overlap for transition with energy 2050.8060840766066
# Calculating overlap for transition with energy 2112.605822060941
# Calculating overlap for transition with energy 2114.59347106631
# Calculating overlap for transition with energy 2177.4058159825972
# Calculating overlap for transition with energy 2179.0796294957704
# Calculating overlap for transition with energy 2244.30040253995
# Calculating overlap for transition with energy 2244.7149545188336
# Calculating overlap for transition with energy 2311.661856811757
# Calculating overlap for transition with energy 2313.1284888675514
# Calculating overlap for transition with energy 2381.067034141319
# Calculating overlap for transition with energy 2382.7194116591845
# Calculating overlap for transition with energy 2452.596509280395
# Calculating overlap for transition with energy 2453.3688366136694
# Calculating overlap for transition with energy 2525.163554130018
# Calculating overlap for transition with energy 2526.157291800401
# Calculating overlap for transition with energy 2599.2971762949805

# %%
#This produces a list of dictionaries
# Showing example
wavefunction_overlaps[0]
# Out:
# {'energy': 0.0,
#  'ground_state_id': 'gs_scan_no_h2o_zpe_0',
#  'excited_state_id': 'es_scan_no_h2o_zpe_0',
#  'overlap': 2.1103683188011623e-05}

# %%
overlap_df = pd.DataFrame(wavefunction_overlaps)

# %%
# Initial spectral plots

# %%
# Now, convert from a.u. to cm^-1, plot stem plot and compare to the experimental spectrum

offset = 35490

kidwell_uv_spectrum_energy = np.loadtxt('PhPy UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPy UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm^-1', fontsize = 12)
ax.set_ylabel('Intensity', fontsize = 12)
# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(35350,36400)
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity,label='Experiment', color='k',ls='-')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

# Might need to normalize

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)

#ax.stem(vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset, 
#        vibrational_state_overlaps_df['overlap'],linefmt='g-',markerfmt=' ',label='All',
#       basefmt=" ")

ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

#print(wavefunction_ground_vib_state_for_plotting_df)

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


#ax.stem(ground_vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset, 
#        ground_vibrational_state_overlaps_df['overlap'],linefmt='g-',markerfmt=' ',label='n=0 ground origin',
 #      basefmt=" ")

ax.legend()
plt.savefig('./theory_exp_spectrum_compare_mass_no_water_zpe_for_presentation.pdf')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:64: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Plot now with linewidth
# Reads in a list of frequencies and intensities
# Then produces two text files that have the right spectrum
def calc_spectrum_plot(freq_list=None,int_list=None,
                       min_freq=0.0,max_freq=0.0,width=1,resolution=0.05):
    
    num_points = int((max_freq-min_freq)/(resolution))
    
    frequencies = list()
    intensities = list()
    
    for i in range(0,num_points):
        frequency = min_freq+i*resolution
        intensity = 0.0
        
        for j in range(0,len(freq_list)):
            peak_center = freq_list[j]
            peak_height = int_list[j]
           # print(peak_center)
           # print(peak_height)
            intensity = intensity + peak_height*np.exp(-(frequency - peak_center)**2/(2*width))
    
        frequencies.append(frequency)
        intensities.append(intensity)
    
    return frequencies,intensities

# %%
theory_frequencies,theory_intensities = calc_spectrum_plot(
                    freq_list=vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset,
                    int_list=vibrational_state_overlaps_df['overlap'],
                       min_freq=offset-100,max_freq=offset+3000,width=10.0,resolution=1.0)

# %%
# Plot with both spectra on each other
# Two versions, one narrow range, one wider range

# %%
# Wide range

# Set baseline to zero 

kidwell_uv_spectrum_energy = np.loadtxt('PhPy UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPy UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm$^{-1}$', fontsize = 20)
ax.set_ylabel('Intensity', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=20)

# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(35350,38000)

max_freq = 38000
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity+0.8,label='Experiment', color='k',ls='-')


theory_plot_intensities = theory_intensities/max(theory_intensities)

# Plot the theory spectrum
ax.plot(theory_frequencies, theory_plot_intensities,label='Smoothed Model', color='k',ls='dashed')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)


ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


ax.legend()
plt.savefig('./theory_exp_spectrum_smooth_masses_no_water_zpe_for_presentation_wide_range.pdf',bbox_inches='tight')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:63: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:67: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Narrow Range

# Set baseline to zero 

kidwell_uv_spectrum_energy = np.loadtxt('PhPy UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPy UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm$^{-1}$', fontsize = 20)
ax.set_ylabel('Intensity', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=20)

# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(35350,36250)

max_freq = 36250
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity+0.8,label='Experiment', color='k',ls='-')


theory_plot_intensities = theory_intensities/max(theory_intensities)

# Plot the theory spectrum
ax.plot(theory_frequencies, theory_plot_intensities,label='Smoothed Model', color='k',ls='dashed')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)


ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


ax.legend()
plt.savefig('./theory_exp_spectrum_smooth_masses_no_water_zpe_for_presentation_narrow_range.pdf',bbox_inches='tight')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:63: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:67: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Plot the lowest 4 ground state wavefunctions
ground_state_file_name_root='gs_scan_no_h2o_zpe'
excited_state_file_name_root='es_scan_no_h2o_zpe'
max_num_ground_state_wfs=4
max_num_excited_state_wfs=100

# %%
ground_state_dict = read_dvr_output(filename_root=ground_state_file_name_root,num_states=max_num_ground_state_wfs)
excited_state_dict = read_dvr_output(filename_root=excited_state_file_name_root,num_states=max_num_excited_state_wfs)

# %%
# plot the potential and square of the wavefunction 
# (avoids ambiguity on signs) of the ground state potential

wavefunction_counter = 0

max_wavefunctions = 4

for i in range(0,4):
    plot_wavefunction_squared(state_dict=ground_state_dict,
                        state_num=i,prefix="gs_scan_no_h2o_zpe_",
                      plotting_potential_name="gs_scan_no_water_fitted_zpe.dat",
                     potential="Ground State PES",mass=mass_ground)
# Out:
# Examining state gs_scan_no_h2o_zpe_0
# Examining state gs_scan_no_h2o_zpe_1
# Examining state gs_scan_no_h2o_zpe_2
# Examining state gs_scan_no_h2o_zpe_3

# %%
plot_potential_and_energy_levels(state_dict=ground_state_dict,
                       prefix="kidwell_gs_scan_no_h2o_zpe_",
                      plotting_potential_name="gs_scan_no_water_fitted_zpe.dat",
                     potential="Ground State PES",mass=mass_ground,max_energy=200)

# %%
plot_potential_and_energy_levels(state_dict=excited_state_dict,
                       prefix="es_scan_no_h2o_zpe_",
                      plotting_potential_name="es_scan_no_water_fitted_zpe.dat",
                     potential="Excited State PES",mass=mass_ground,max_energy=1500)

# %%
# Get maximum overlaps so we can plot those excited state wavefunctions
overlap_df.sort_values(by=['overlap'],ascending=False).head(20)
# Out:
#        energy                   ground_state_id  \
# 223  0.003709  gs_scan_no_h2o_zpe_1_vib_excited
# 222  0.002511              gs_scan_no_h2o_zpe_1
# 75   0.005819  gs_scan_no_h2o_zpe_0_vib_excited
# 74   0.004621              gs_scan_no_h2o_zpe_0
# 231  0.003924  gs_scan_no_h2o_zpe_1_vib_excited
# 230  0.002725              gs_scan_no_h2o_zpe_1
# 66   0.004374              gs_scan_no_h2o_zpe_0
# 67   0.005573  gs_scan_no_h2o_zpe_0_vib_excited
# 220  0.002287              gs_scan_no_h2o_zpe_1
# 221  0.003485  gs_scan_no_h2o_zpe_1_vib_excited
# 658  0.004036              gs_scan_no_h2o_zpe_3
# 659  0.005234  gs_scan_no_h2o_zpe_3_vib_excited
# 643  0.004563  gs_scan_no_h2o_zpe_3_vib_excited
# 642  0.003365              gs_scan_no_h2o_zpe_3
# 677  0.005884  gs_scan_no_h2o_zpe_3_vib_excited
# 676  0.004685              gs_scan_no_h2o_zpe_3
# 629  0.003894  gs_scan_no_h2o_zpe_3_vib_excited
# 628  0.002696              gs_scan_no_h2o_zpe_3
# 232  0.002936              gs_scan_no_h2o_zpe_1
# 233  0.004135  gs_scan_no_h2o_zpe_1_vib_excited
#
#                       excited_state_id   overlap
# 223  es_scan_no_h2o_zpe_11_vib_excited  0.619294
# 222              es_scan_no_h2o_zpe_11  0.619294
# 75   es_scan_no_h2o_zpe_37_vib_excited  0.602808
# 74               es_scan_no_h2o_zpe_37  0.602808
# 231  es_scan_no_h2o_zpe_15_vib_excited  0.543701
# 230              es_scan_no_h2o_zpe_15  0.543701
# 66               es_scan_no_h2o_zpe_33  0.533406
# 67   es_scan_no_h2o_zpe_33_vib_excited  0.533406
# 220              es_scan_no_h2o_zpe_10  0.442496
# 221  es_scan_no_h2o_zpe_10_vib_excited  0.442496
# 658              es_scan_no_h2o_zpe_29  0.374164
# 659  es_scan_no_h2o_zpe_29_vib_excited  0.374164
# 643  es_scan_no_h2o_zpe_21_vib_excited  0.369010
# 642              es_scan_no_h2o_zpe_21  0.369010
# 677  es_scan_no_h2o_zpe_38_vib_excited  0.356461
# 676              es_scan_no_h2o_zpe_38  0.356461
# 629  es_scan_no_h2o_zpe_14_vib_excited  0.342725
# 628              es_scan_no_h2o_zpe_14  0.342725
# 232              es_scan_no_h2o_zpe_16  0.330905
# 233  es_scan_no_h2o_zpe_16_vib_excited  0.330905

# %%
# Export overlap to csv file

overlap_df.to_csv('./phpy_overlap_list.csv')
