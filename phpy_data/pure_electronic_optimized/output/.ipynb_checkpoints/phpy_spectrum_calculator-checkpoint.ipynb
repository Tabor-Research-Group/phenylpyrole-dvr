# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import random
from scipy import interpolate

# %%
import scipy

# %%
import pandas as pd

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 8)

# %%
from scipy.interpolate import interp1d

# %%
from dvr_setup_and_plotting_utils import *

# %%
# potential_tests

# Run and collect ground state

# Reduced mass of freqency calculation =  3.5708    AMU

mass_ground = 3.5708*1836*22
print(str(mass_ground/1836))

num_wavefunctions_ground = 5
grid_points = 500

fit_potential_spline_assume_periodic_write_to_file(raw_potential_filename='gs_scan_no_water_raw_pot.dat',num_grid_points=grid_points,
                                output_potential_filename='gs_scan_no_water_fitted.dat',shift_origin=0.0,scale_factor=1.00)
# Out:
# 78.5576

# %%
# potential_tests

# Run and collect ground state

# Reduced mass of freqency calculation =  3.5708    AMU

mass_ground = 3.5708*1836*22
print(str(mass_ground/1836))

num_wavefunctions_ground = 5
grid_points = 500

fit_potential_spline_assume_periodic_write_to_file(raw_potential_filename='es_scan_no_water_raw_pot.dat',num_grid_points=grid_points,
                                output_potential_filename='es_scan_no_water_fitted.dat',shift_origin=0.0,scale_factor=1.0)

# %%
# Run and collect ground state

# Reduced mass of freqency calculation =  3.5708    AMU

mass_ground = 3.5708*1836*22
print(str(mass_ground/1836))

num_wavefunctions_ground = 5
grid_points = 500


fit_linear_potential_assume_periodic_write_to_file(raw_potential_filename='gs_scan_no_water_raw_pot.dat',num_grid_points=grid_points,
                                output_potential_filename='gs_scan_no_water_fitted.dat',shift_origin=0.0,scale_factor=1.00)


print('potential written')

setup_dvr(num_states=num_wavefunctions_ground,num_grid_points=grid_points,mass=mass_ground,
                         potential_energy_file_name='gs_scan_no_water_fitted.dat',
                        output_file_name='gs_scan_no_h2o')

print('dvr is set up')
# Now need to make the output potential the potential_file.dat and run 
# ./dvr_1d_periodic
# Out:
# 78.5576
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp gs_scan_no_water_fitted.dat  potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above
# User must supply their own matrix diagonalization subroutine

# %%
# run DVR
# Now run excited state

mass_excited =   3.5786*1836*22
num_wavefunctions_excited = 200
print(str(mass_excited/1836))

# Trying pure linear interpolation. The old cubic spline is below
#fit_potential_assume_periodic_write_to_file(raw_potential_filename='kidwell_es_scan_with_water_raw_pot_with_zpe.dat',num_grid_points=grid_points,
#                                output_potential_filename='es_scan_with_water_fitted_zpe.dat',shift_origin=0.0,scale_factor=1.0)

fit_linear_potential_assume_periodic_write_to_file(raw_potential_filename='es_scan_no_water_raw_pot.dat',num_grid_points=grid_points,
                                output_potential_filename='es_scan_no_water_fitted.dat',shift_origin=0.0,scale_factor=1.0)

print('potential written')

setup_dvr(num_states=num_wavefunctions_excited,num_grid_points=grid_points,mass=mass_excited,
                         potential_energy_file_name='es_scan_no_water_fitted.dat',
                        output_file_name='es_scan_no_h2o')

print('dvr is set up')
# Out:
# 78.72919999999999
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp es_scan_no_water_fitted.dat potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above

# %%
# Absolute value of overlaps is calculated here

# %%
wavefunction_overlaps = read_wavefunctions_calculate_overlaps_vib_shift(
                                         ground_state_file_name_root='gs_scan_no_h2o',
                                         excited_state_file_name_root='es_scan_no_h2o',
                                         max_num_ground_state_wfs=4,
                                         max_num_excited_state_wfs=100,
                                         ground_state_max_energy=300,
                                         excited_state_max_energy=3000,
                                         vib_shift=263.0,
                                        vib_scale=1.0)
# Out:
# Calculating overlap for transition with energy 0.0
# Calculating overlap for transition with energy 4.837905750549311
# Calculating overlap for transition with energy 53.34522400349774
# Calculating overlap for transition with energy 64.10186550894461
# Calculating overlap for transition with energy 106.90673436706842
# Calculating overlap for transition with energy 121.79588845187683
# Calculating overlap for transition with energy 161.385456645134
# Calculating overlap for transition with energy 178.3738468242838
# Calculating overlap for transition with energy 217.08891407210848
# Calculating overlap for transition with energy 232.56613978000146
# Calculating overlap for transition with energy 277.52154661802444
# Calculating overlap for transition with energy 286.8191415769032
# Calculating overlap for transition with energy 338.59427896532895
# Calculating overlap for transition with energy 339.12444965601173
# Calculating overlap for transition with energy 390.8439485897092
# Calculating overlap for transition with energy 403.2917520748846
# Calculating overlap for transition with energy 413.27891190518733
# Calculating overlap for transition with energy 416.65736151691135
# Calculating overlap for transition with energy 441.8565612163436
# Calculating overlap for transition with energy 470.2480493164676
# Calculating overlap for transition with energy 492.1180452031612
# Calculating overlap for transition with energy 532.9764270092865
# Calculating overlap for transition with energy 538.0538198191421
# Calculating overlap for transition with energy 538.7952730021663
# Calculating overlap for transition with energy 542.0799748496393
# Calculating overlap for transition with energy 592.4105575825693
# Calculating overlap for transition with energy 607.6735272320434
# Calculating overlap for transition with energy 643.7736400805525
# Calculating overlap for transition with energy 654.4230638846971
# Calculating overlap for transition with energy 655.9360390856251
# Calculating overlap for transition with energy 678.2611844655673
# Calculating overlap for transition with energy 696.2523159963312
# Calculating overlap for transition with energy 747.8417433714452
# Calculating overlap for transition with energy 748.1882087215723
# Calculating overlap for transition with energy 751.8624355350001
# Calculating overlap for transition with energy 775.1455245245593
# Calculating overlap for transition with energy 803.0005775275855
# Calculating overlap for transition with energy 818.9002334765664
# Calculating overlap for transition with energy 839.0487357722259
# Calculating overlap for transition with energy 861.4663049642397
# Calculating overlap for transition with energy 875.2429828178175
# Calculating overlap for transition with energy 901.264927114298
# Calculating overlap for transition with energy 910.1655996698914
# Calculating overlap for transition with energy 940.6539442726712
# Calculating overlap for transition with energy 959.2846017808058
# Calculating overlap for transition with energy 979.6340127036291
# Calculating overlap for transition with energy 1000.0925610731388
# Calculating overlap for transition with energy 1024.0858575353643
# Calculating overlap for transition with energy 1051.0520774351112
# Calculating overlap for transition with energy 1060.1837111300044
# Calculating overlap for transition with energy 1102.1513219064254
# Calculating overlap for transition with energy 1105.2649108113674
# Calculating overlap for transition with energy 1147.786470533042
# Calculating overlap for transition with energy 1150.5040989797735
# Calculating overlap for transition with energy 1190.013710828141
# Calculating overlap for transition with energy 1205.2183260510512
# Calculating overlap for transition with energy 1237.5592534557961
# Calculating overlap for transition with energy 1254.7089500703755
# Calculating overlap for transition with energy 1281.639757346853
# Calculating overlap for transition with energy 1310.3456404987596
# Calculating overlap for transition with energy 1328.0236617403868
# Calculating overlap for transition with energy 1361.287725005815
# Calculating overlap for transition with energy 1376.3115454784615
# Calculating overlap for transition with energy 1414.22994710877
# Calculating overlap for transition with energy 1425.4287049666793
# Calculating overlap for transition with energy 1464.0208985961358
# Calculating overlap for transition with energy 1479.2588065774592
# Calculating overlap for transition with energy 1515.014847033543
# Calculating overlap for transition with energy 1535.2441057496214
# Calculating overlap for transition with energy 1566.8924889718874
# Calculating overlap for transition with energy 1592.1457153949996
# Calculating overlap for transition with energy 1621.615458480246
# Calculating overlap for transition with energy 1650.500142410811
# Calculating overlap for transition with energy 1677.6869015462112
# Calculating overlap for transition with energy 1709.3735269785923
# Calculating overlap for transition with energy 1736.9027293161407
# Calculating overlap for transition with energy 1769.4922313792933
# Calculating overlap for transition with energy 1797.0507652859499
# Calculating overlap for transition with energy 1830.2061829522065
# Calculating overlap for transition with energy 1859.854301543914
# Calculating overlap for transition with energy 1892.27755170488
# Calculating overlap for transition with energy 1922.9315775098632
# Calculating overlap for transition with energy 1955.0744348560413
# Calculating overlap for transition with energy 1988.3164509043925
# Calculating overlap for transition with energy 2019.9406944969035
# Calculating overlap for transition with energy 2053.3218458756146
# Calculating overlap for transition with energy 2085.5644135432294
# Calculating overlap for transition with energy 2120.291752801728
# Calculating overlap for transition with energy 2152.855169646254
# Calculating overlap for transition with energy 2186.743178572833
# Calculating overlap for transition with energy 2220.908263869805
# Calculating overlap for transition with energy 2255.7147196454066
# Calculating overlap for transition with energy 2290.130091380296
# Calculating overlap for transition with energy 2324.8130154221703
# Calculating overlap for transition with energy 2359.891074424575
# Calculating overlap for transition with energy 2396.343435859792
# Calculating overlap for transition with energy 2430.0476237624957
# Calculating overlap for transition with energy 2468.089550093714
# Calculating overlap for transition with energy 2500.8349287995948
# Calculating overlap for transition with energy 2541.7843048591963
# Calculating overlap for transition with energy -0.007461866543708629
# Calculating overlap for transition with energy 4.830443884005603
# Calculating overlap for transition with energy 53.337762136954034
# Calculating overlap for transition with energy 64.09440364240089
# Calculating overlap for transition with energy 106.89927250052473
# Calculating overlap for transition with energy 121.78842658533313
# Calculating overlap for transition with energy 161.3779947785903
# Calculating overlap for transition with energy 178.36638495774008
# Calculating overlap for transition with energy 217.08145220556477
# Calculating overlap for transition with energy 232.55867791345776
# Calculating overlap for transition with energy 277.5140847514807
# Calculating overlap for transition with energy 286.81167971035944
# Calculating overlap for transition with energy 338.5868170987853
# Calculating overlap for transition with energy 339.116987789468
# Calculating overlap for transition with energy 390.8364867231655
# Calculating overlap for transition with energy 403.2842902083409
# Calculating overlap for transition with energy 413.2714500386436
# Calculating overlap for transition with energy 416.6498996503676
# Calculating overlap for transition with energy 441.8490993497999
# Calculating overlap for transition with energy 470.2405874499239
# Calculating overlap for transition with energy 492.11058333661754
# Calculating overlap for transition with energy 532.9689651427428
# Calculating overlap for transition with energy 538.0463579525984
# Calculating overlap for transition with energy 538.7878111356225
# Calculating overlap for transition with energy 542.0725129830956
# Calculating overlap for transition with energy 592.4030957160255
# Calculating overlap for transition with energy 607.6660653654998
# Calculating overlap for transition with energy 643.7661782140087
# Calculating overlap for transition with energy 654.4156020181534
# Calculating overlap for transition with energy 655.9285772190815
# Calculating overlap for transition with energy 678.2537225990237
# Calculating overlap for transition with energy 696.2448541297875
# Calculating overlap for transition with energy 747.8342815049016
# Calculating overlap for transition with energy 748.1807468550286
# Calculating overlap for transition with energy 751.8549736684565
# Calculating overlap for transition with energy 775.1380626580155
# Calculating overlap for transition with energy 802.9931156610419
# Calculating overlap for transition with energy 818.8927716100228
# Calculating overlap for transition with energy 839.0412739056823
# Calculating overlap for transition with energy 861.458843097696
# Calculating overlap for transition with energy 875.2355209512738
# Calculating overlap for transition with energy 901.2574652477543
# Calculating overlap for transition with energy 910.1581378033477
# Calculating overlap for transition with energy 940.6464824061275
# Calculating overlap for transition with energy 959.2771399142622
# Calculating overlap for transition with energy 979.6265508370855
# Calculating overlap for transition with energy 1000.0850992065951
# Calculating overlap for transition with energy 1024.0783956688206
# Calculating overlap for transition with energy 1051.0446155685675
# Calculating overlap for transition with energy 1060.176249263461
# Calculating overlap for transition with energy 1102.143860039882
# Calculating overlap for transition with energy 1105.2574489448236
# Calculating overlap for transition with energy 1147.7790086664982
# Calculating overlap for transition with energy 1150.4966371132298
# Calculating overlap for transition with energy 1190.0062489615975
# Calculating overlap for transition with energy 1205.2108641845075
# Calculating overlap for transition with energy 1237.5517915892524
# Calculating overlap for transition with energy 1254.7014882038318
# Calculating overlap for transition with energy 1281.6322954803093
# Calculating overlap for transition with energy 1310.338178632216
# Calculating overlap for transition with energy 1328.016199873843
# Calculating overlap for transition with energy 1361.2802631392715
# Calculating overlap for transition with energy 1376.304083611918
# Calculating overlap for transition with energy 1414.2224852422264
# Calculating overlap for transition with energy 1425.4212431001358
# Calculating overlap for transition with energy 1464.013436729592
# Calculating overlap for transition with energy 1479.2513447109154
# Calculating overlap for transition with energy 1515.0073851669993
# Calculating overlap for transition with energy 1535.236643883078
# Calculating overlap for transition with energy 1566.8850271053436
# Calculating overlap for transition with energy 1592.1382535284558
# Calculating overlap for transition with energy 1621.6079966137022
# Calculating overlap for transition with energy 1650.4926805442672
# Calculating overlap for transition with energy 1677.6794396796677
# Calculating overlap for transition with energy 1709.3660651120485
# Calculating overlap for transition with energy 1736.8952674495968
# Calculating overlap for transition with energy 1769.4847695127494
# Calculating overlap for transition with energy 1797.043303419406
# Calculating overlap for transition with energy 1830.1987210856628
# Calculating overlap for transition with energy 1859.84683967737
# Calculating overlap for transition with energy 1892.2700898383362
# Calculating overlap for transition with energy 1922.9241156433193
# Calculating overlap for transition with energy 1955.0669729894973
# Calculating overlap for transition with energy 1988.3089890378487
# Calculating overlap for transition with energy 2019.9332326303595
# Calculating overlap for transition with energy 2053.3143840090706
# Calculating overlap for transition with energy 2085.5569516766855
# Calculating overlap for transition with energy 2120.284290935184
# Calculating overlap for transition with energy 2152.84770777971
# Calculating overlap for transition with energy 2186.735716706289
# Calculating overlap for transition with energy 2220.900802003261
# Calculating overlap for transition with energy 2255.7072577788626
# Calculating overlap for transition with energy 2290.122629513752
# Calculating overlap for transition with energy 2324.805553555627
# Calculating overlap for transition with energy 2359.883612558031
# Calculating overlap for transition with energy 2396.335973993248
# Calculating overlap for transition with energy 2430.0401618959518
# Calculating overlap for transition with energy 2468.08208822717
# Calculating overlap for transition with energy 2500.827466933051
# Calculating overlap for transition with energy 2541.7768429926523
# Calculating overlap for transition with energy -0.10887226896812376
# Calculating overlap for transition with energy 4.729033481581188
# Calculating overlap for transition with energy 53.23635173452962
# Calculating overlap for transition with energy 63.992993239976485
# Calculating overlap for transition with energy 106.79786209810031
# Calculating overlap for transition with energy 121.6870161829087
# Calculating overlap for transition with energy 161.27658437616589
# Calculating overlap for transition with energy 178.26497455531566
# Calculating overlap for transition with energy 216.98004180314038
# Calculating overlap for transition with energy 232.45726751103336
# Calculating overlap for transition with energy 277.4126743490563
# Calculating overlap for transition with energy 286.710269307935
# Calculating overlap for transition with energy 338.4854066963609
# Calculating overlap for transition with energy 339.0155773870436
# Calculating overlap for transition with energy 390.7350763207411
# Calculating overlap for transition with energy 403.18287980591646
# Calculating overlap for transition with energy 413.17003963621914
# Calculating overlap for transition with energy 416.54848924794317
# Calculating overlap for transition with energy 441.7476889473754
# Calculating overlap for transition with energy 470.1391770474994
# Calculating overlap for transition with energy 492.00917293419303
# Calculating overlap for transition with energy 532.8675547403184
# Calculating overlap for transition with energy 537.944947550174
# Calculating overlap for transition with energy 538.6864007331981
# Calculating overlap for transition with energy 541.9711025806712
# Calculating overlap for transition with energy 592.3016853136011
# Calculating overlap for transition with energy 607.5646549630752
# Calculating overlap for transition with energy 643.6647678115843
# Calculating overlap for transition with energy 654.3141916157289
# Calculating overlap for transition with energy 655.827166816657
# Calculating overlap for transition with energy 678.1523121965993
# Calculating overlap for transition with energy 696.1434437273631
# Calculating overlap for transition with energy 747.7328711024771
# Calculating overlap for transition with energy 748.0793364526041
# Calculating overlap for transition with energy 751.7535632660321
# Calculating overlap for transition with energy 775.0366522555911
# Calculating overlap for transition with energy 802.8917052586174
# Calculating overlap for transition with energy 818.7913612075982
# Calculating overlap for transition with energy 838.9398635032578
# Calculating overlap for transition with energy 861.3574326952715
# Calculating overlap for transition with energy 875.1341105488493
# Calculating overlap for transition with energy 901.1560548453298
# Calculating overlap for transition with energy 910.0567274009233
# Calculating overlap for transition with energy 940.545072003703
# Calculating overlap for transition with energy 959.1757295118376
# Calculating overlap for transition with energy 979.525140434661
# Calculating overlap for transition with energy 999.9836888041707
# Calculating overlap for transition with energy 1023.9769852663962
# Calculating overlap for transition with energy 1050.943205166143
# Calculating overlap for transition with energy 1060.0748388610364
# Calculating overlap for transition with energy 1102.0424496374574
# Calculating overlap for transition with energy 1105.1560385423993
# Calculating overlap for transition with energy 1147.6775982640738
# Calculating overlap for transition with energy 1150.3952267108052
# Calculating overlap for transition with energy 1189.904838559173
# Calculating overlap for transition with energy 1205.109453782083
# Calculating overlap for transition with energy 1237.4503811868278
# Calculating overlap for transition with energy 1254.6000778014075
# Calculating overlap for transition with energy 1281.5308850778847
# Calculating overlap for transition with energy 1310.2367682297916
# Calculating overlap for transition with energy 1327.9147894714188
# Calculating overlap for transition with energy 1361.178852736847
# Calculating overlap for transition with energy 1376.2026732094935
# Calculating overlap for transition with energy 1414.1210748398018
# Calculating overlap for transition with energy 1425.3198326977113
# Calculating overlap for transition with energy 1463.9120263271677
# Calculating overlap for transition with energy 1479.1499343084909
# Calculating overlap for transition with energy 1514.905974764575
# Calculating overlap for transition with energy 1535.1352334806534
# Calculating overlap for transition with energy 1566.783616702919
# Calculating overlap for transition with energy 1592.0368431260315
# Calculating overlap for transition with energy 1621.5065862112776
# Calculating overlap for transition with energy 1650.3912701418428
# Calculating overlap for transition with energy 1677.578029277243
# Calculating overlap for transition with energy 1709.2646547096242
# Calculating overlap for transition with energy 1736.7938570471727
# Calculating overlap for transition with energy 1769.3833591103255
# Calculating overlap for transition with energy 1796.9418930169818
# Calculating overlap for transition with energy 1830.0973106832387
# Calculating overlap for transition with energy 1859.745429274946
# Calculating overlap for transition with energy 1892.168679435912
# Calculating overlap for transition with energy 1922.8227052408952
# Calculating overlap for transition with energy 1954.9655625870732
# Calculating overlap for transition with energy 1988.2075786354246
# Calculating overlap for transition with energy 2019.8318222279354
# Calculating overlap for transition with energy 2053.2129736066463
# Calculating overlap for transition with energy 2085.455541274261
# Calculating overlap for transition with energy 2120.18288053276
# Calculating overlap for transition with energy 2152.7462973772863
# Calculating overlap for transition with energy 2186.634306303865
# Calculating overlap for transition with energy 2220.7993916008368
# Calculating overlap for transition with energy 2255.6058473764383
# Calculating overlap for transition with energy 2290.021219111328
# Calculating overlap for transition with energy 2324.7041431532025
# Calculating overlap for transition with energy 2359.7822021556067
# Calculating overlap for transition with energy 2396.234563590824
# Calculating overlap for transition with energy 2429.9387514935274
# Calculating overlap for transition with energy 2467.980677824746
# Calculating overlap for transition with energy 2500.7260565306265
# Calculating overlap for transition with energy 2541.6754325902284
# Calculating overlap for transition with energy -0.15637706732471823
# Calculating overlap for transition with energy 4.681528683224593
# Calculating overlap for transition with energy 53.18884693617302
# Calculating overlap for transition with energy 63.945488441619894
# Calculating overlap for transition with energy 106.75035729974371
# Calculating overlap for transition with energy 121.63951138455212
# Calculating overlap for transition with energy 161.22907957780933
# Calculating overlap for transition with energy 178.21746975695908
# Calculating overlap for transition with energy 216.93253700478377
# Calculating overlap for transition with energy 232.40976271267675
# Calculating overlap for transition with energy 277.36516955069976
# Calculating overlap for transition with energy 286.66276450957844
# Calculating overlap for transition with energy 338.43790189800427
# Calculating overlap for transition with energy 338.96807258868705
# Calculating overlap for transition with energy 390.6875715223845
# Calculating overlap for transition with energy 403.1353750075599
# Calculating overlap for transition with energy 413.1225348378626
# Calculating overlap for transition with energy 416.5009844495866
# Calculating overlap for transition with energy 441.70018414901887
# Calculating overlap for transition with energy 470.09167224914285
# Calculating overlap for transition with energy 491.9616681358364
# Calculating overlap for transition with energy 532.8200499419618
# Calculating overlap for transition with energy 537.8974427518174
# Calculating overlap for transition with energy 538.6388959348415
# Calculating overlap for transition with energy 541.9235977823146
# Calculating overlap for transition with energy 592.2541805152445
# Calculating overlap for transition with energy 607.5171501647187
# Calculating overlap for transition with energy 643.6172630132277
# Calculating overlap for transition with energy 654.2666868173723
# Calculating overlap for transition with energy 655.7796620183004
# Calculating overlap for transition with energy 678.1048073982427
# Calculating overlap for transition with energy 696.0959389290065
# Calculating overlap for transition with energy 747.6853663041205
# Calculating overlap for transition with energy 748.0318316542475
# Calculating overlap for transition with energy 751.7060584676755
# Calculating overlap for transition with energy 774.9891474572345
# Calculating overlap for transition with energy 802.8442004602608
# Calculating overlap for transition with energy 818.7438564092416
# Calculating overlap for transition with energy 838.8923587049012
# Calculating overlap for transition with energy 861.3099278969149
# Calculating overlap for transition with energy 875.0866057504927
# Calculating overlap for transition with energy 901.1085500469733
# Calculating overlap for transition with energy 910.0092226025666
# Calculating overlap for transition with energy 940.4975672053464
# Calculating overlap for transition with energy 959.1282247134811
# Calculating overlap for transition with energy 979.4776356363044
# Calculating overlap for transition with energy 999.9361840058141
# Calculating overlap for transition with energy 1023.9294804680396
# Calculating overlap for transition with energy 1050.8957003677863
# Calculating overlap for transition with energy 1060.0273340626798
# Calculating overlap for transition with energy 1101.9949448391008
# Calculating overlap for transition with energy 1105.1085337440427
# Calculating overlap for transition with energy 1147.6300934657172
# Calculating overlap for transition with energy 1150.3477219124486
# Calculating overlap for transition with energy 1189.8573337608163
# Calculating overlap for transition with energy 1205.0619489837263
# Calculating overlap for transition with energy 1237.4028763884712
# Calculating overlap for transition with energy 1254.5525730030508
# Calculating overlap for transition with energy 1281.483380279528
# Calculating overlap for transition with energy 1310.189263431435
# Calculating overlap for transition with energy 1327.8672846730622
# Calculating overlap for transition with energy 1361.1313479384903
# Calculating overlap for transition with energy 1376.1551684111369
# Calculating overlap for transition with energy 1414.0735700414452
# Calculating overlap for transition with energy 1425.2723278993547
# Calculating overlap for transition with energy 1463.864521528811
# Calculating overlap for transition with energy 1479.1024295101342
# Calculating overlap for transition with energy 1514.8584699662183
# Calculating overlap for transition with energy 1535.0877286822968
# Calculating overlap for transition with energy 1566.7361119045624
# Calculating overlap for transition with energy 1591.989338327675
# Calculating overlap for transition with energy 1621.459081412921
# Calculating overlap for transition with energy 1650.3437653434862
# Calculating overlap for transition with energy 1677.5305244788865
# Calculating overlap for transition with energy 1709.2171499112676
# Calculating overlap for transition with energy 1736.746352248816
# Calculating overlap for transition with energy 1769.335854311969
# Calculating overlap for transition with energy 1796.8943882186252
# Calculating overlap for transition with energy 1830.049805884882
# Calculating overlap for transition with energy 1859.6979244765894
# Calculating overlap for transition with energy 1892.1211746375554
# Calculating overlap for transition with energy 1922.7752004425386
# Calculating overlap for transition with energy 1954.9180577887166
# Calculating overlap for transition with energy 1988.160073837068
# Calculating overlap for transition with energy 2019.7843174295788
# Calculating overlap for transition with energy 2053.16546880829
# Calculating overlap for transition with energy 2085.4080364759047
# Calculating overlap for transition with energy 2120.135375734403
# Calculating overlap for transition with energy 2152.6987925789294
# Calculating overlap for transition with energy 2186.5868015055084
# Calculating overlap for transition with energy 2220.7518868024804
# Calculating overlap for transition with energy 2255.558342578082
# Calculating overlap for transition with energy 2289.9737143129714
# Calculating overlap for transition with energy 2324.656638354846
# Calculating overlap for transition with energy 2359.7346973572503
# Calculating overlap for transition with energy 2396.1870587924673
# Calculating overlap for transition with energy 2429.891246695171
# Calculating overlap for transition with energy 2467.9331730263893
# Calculating overlap for transition with energy 2500.67855173227
# Calculating overlap for transition with energy 2541.6279277918716

# %%
#This produces a list of dictionaries
# Showing example
wavefunction_overlaps[0]
# Out:
# {'energy': 0.0,
#  'ground_state_id': 'gs_scan_no_h2o_0',
#  'excited_state_id': 'es_scan_no_h2o_0',
#  'overlap': 2.188241375525391e-23}

# %%
overlap_df = pd.DataFrame(wavefunction_overlaps)

# %%
# Initial spectral plots

# %%
# Now, convert from a.u. to cm^-1, plot stem plot and compare to the experimental spectrum

offset = 35490

kidwell_uv_spectrum_energy = np.loadtxt('PhPy UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPy UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm^-1', fontsize = 12)
ax.set_ylabel('Intensity', fontsize = 12)
# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(35350,36400)
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity,label='Experiment', color='k',ls='-')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

# Might need to normalize

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)

#ax.stem(vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset, 
#        vibrational_state_overlaps_df['overlap'],linefmt='g-',markerfmt=' ',label='All',
#       basefmt=" ")

ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

#print(wavefunction_ground_vib_state_for_plotting_df)

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


#ax.stem(ground_vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset, 
#        ground_vibrational_state_overlaps_df['overlap'],linefmt='g-',markerfmt=' ',label='n=0 ground origin',
 #      basefmt=" ")

ax.legend()
plt.savefig('./theory_exp_spectrum_compare_mass_no_water_zpe_for_presentation.pdf')
plt.show()

# %%
# Plot now with linewidth
# Reads in a list of frequencies and intensities
# Then produces two text files that have the right spectrum
def calc_spectrum_plot(freq_list=None,int_list=None,
                       min_freq=0.0,max_freq=0.0,width=1,resolution=0.05):
    
    num_points = int((max_freq-min_freq)/(resolution))
    
    frequencies = list()
    intensities = list()
    
    for i in range(0,num_points):
        frequency = min_freq+i*resolution
        intensity = 0.0
        
        for j in range(0,len(freq_list)):
            peak_center = freq_list[j]
            peak_height = int_list[j]
           # print(peak_center)
           # print(peak_height)
            intensity = intensity + peak_height*np.exp(-(frequency - peak_center)**2/(2*width))
    
        frequencies.append(frequency)
        intensities.append(intensity)
    
    return frequencies,intensities

# %%
theory_frequencies,theory_intensities = calc_spectrum_plot(
                    freq_list=vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset,
                    int_list=vibrational_state_overlaps_df['overlap'],
                       min_freq=offset-100,max_freq=offset+3000,width=10.0,resolution=1.0)

# %%
# Plot with both spectra on each other
# Two versions, one narrow range, one wider range

# %%
# Wide range

# Set baseline to zero 

kidwell_uv_spectrum_energy = np.loadtxt('PhPy UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPy UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm$^{-1}$', fontsize = 20)
ax.set_ylabel('Intensity', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=20)

# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(35350,38000)

max_freq = 38000
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity+0.8,label='Experiment', color='k',ls='-')


theory_plot_intensities = theory_intensities/max(theory_intensities)

# Plot the theory spectrum
ax.plot(theory_frequencies, theory_plot_intensities,label='Smoothed Model', color='k',ls='dashed')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)


ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


ax.legend()
plt.savefig('./theory_exp_spectrum_smooth_masses_no_water_zpe_for_presentation_wide_range.pdf',bbox_inches='tight')
plt.show()

# %%
# Narrow Range

# Set baseline to zero 

kidwell_uv_spectrum_energy = np.loadtxt('PhPy UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPy UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm$^{-1}$', fontsize = 20)
ax.set_ylabel('Intensity', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=20)

# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(35350,36250)

max_freq = 36250
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity+0.8,label='Experiment', color='k',ls='-')


theory_plot_intensities = theory_intensities/max(theory_intensities)

# Plot the theory spectrum
ax.plot(theory_frequencies, theory_plot_intensities,label='Smoothed Model', color='k',ls='dashed')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)


ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


ax.legend()
plt.savefig('./theory_exp_spectrum_smooth_masses_no_water_zpe_for_presentation_narrow_range.pdf',bbox_inches='tight')
plt.show()

# %%
# Plot the lowest 4 ground state wavefunctions
ground_state_file_name_root='gs_scan_no_h2o'
excited_state_file_name_root='es_scan_no_h2o'
max_num_ground_state_wfs=4
max_num_excited_state_wfs=100

# %%
ground_state_dict = read_dvr_output(filename_root=ground_state_file_name_root,num_states=max_num_ground_state_wfs)
excited_state_dict = read_dvr_output(filename_root=excited_state_file_name_root,num_states=max_num_excited_state_wfs)

# %%
# plot the potential and square of the wavefunction 
# (avoids ambiguity on signs) of the ground state potential

wavefunction_counter = 0

max_wavefunctions = 4

for i in range(0,4):
    plot_wavefunction_squared(state_dict=ground_state_dict,
                        state_num=i,prefix="gs_scan_no_h2o_",
                      plotting_potential_name="gs_scan_no_water_fitted.dat",
                     potential="Ground State PES",mass=mass_ground)
# Out:
# Examining state gs_scan_no_h2o_0
# Examining state gs_scan_no_h2o_1
# Examining state gs_scan_no_h2o_2
# Examining state gs_scan_no_h2o_3

# %%
plot_potential_and_energy_levels(state_dict=ground_state_dict,
                       prefix="gs_scan_no_h2o_",
                      plotting_potential_name="gs_scan_no_water_fitted.dat",
                     potential="Ground State PES",mass=mass_ground,max_energy=200)

# %%
plot_potential_and_energy_levels(state_dict=excited_state_dict,
                       prefix="es_scan_no_h2o",
                      plotting_potential_name="es_scan_no_water_fitted.dat",
                     potential="Excited State PES",mass=mass_ground,max_energy=1500)

# %%
# Get maximum overlaps so we can plot those excited state wavefunctions
overlap_df.sort_values(by=['overlap'],ascending=False).head(60)
# Out:
#        energy               ground_state_id               excited_state_id  \
# 617  0.002187  gs_scan_no_h2o_3_vib_excited   es_scan_no_h2o_8_vib_excited
# 616  0.000988              gs_scan_no_h2o_3               es_scan_no_h2o_8
# 19   0.002258  gs_scan_no_h2o_0_vib_excited   es_scan_no_h2o_9_vib_excited
# 18   0.001060              gs_scan_no_h2o_0               es_scan_no_h2o_9
# 613  0.001933  gs_scan_no_h2o_3_vib_excited   es_scan_no_h2o_6_vib_excited
# 612  0.000735              gs_scan_no_h2o_3               es_scan_no_h2o_6
# 621  0.002462  gs_scan_no_h2o_3_vib_excited  es_scan_no_h2o_10_vib_excited
# 620  0.001264              gs_scan_no_h2o_3              es_scan_no_h2o_10
# 23   0.002505  gs_scan_no_h2o_0_vib_excited  es_scan_no_h2o_11_vib_excited
# 22   0.001307              gs_scan_no_h2o_0              es_scan_no_h2o_11
# 15   0.002011  gs_scan_no_h2o_0_vib_excited   es_scan_no_h2o_7_vib_excited
# 14   0.000813              gs_scan_no_h2o_0               es_scan_no_h2o_7
# 27   0.002743  gs_scan_no_h2o_0_vib_excited  es_scan_no_h2o_13_vib_excited
# 26   0.001545              gs_scan_no_h2o_0              es_scan_no_h2o_13
# 276  0.003823              gs_scan_no_h2o_1              es_scan_no_h2o_38
# 277  0.005021  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_38_vib_excited
# 500  0.005021              gs_scan_no_h2o_2              es_scan_no_h2o_50
# 501  0.006220  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_50_vib_excited
# 608  0.000486              gs_scan_no_h2o_3               es_scan_no_h2o_4
# 609  0.001685  gs_scan_no_h2o_3_vib_excited   es_scan_no_h2o_4_vib_excited
# 286  0.004286              gs_scan_no_h2o_1              es_scan_no_h2o_43
# 287  0.005484  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_43_vib_excited
# 510  0.005491              gs_scan_no_h2o_2              es_scan_no_h2o_55
# 511  0.006689  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_55_vib_excited
# 624  0.001542              gs_scan_no_h2o_3              es_scan_no_h2o_12
# 625  0.002740  gs_scan_no_h2o_3_vib_excited  es_scan_no_h2o_12_vib_excited
# 492  0.004556              gs_scan_no_h2o_2              es_scan_no_h2o_46
# 493  0.005755  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_46_vib_excited
# 11   0.001753  gs_scan_no_h2o_0_vib_excited   es_scan_no_h2o_5_vib_excited
# 10   0.000555              gs_scan_no_h2o_0               es_scan_no_h2o_5
# 507  0.006440  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_53_vib_excited
# 506  0.005242              gs_scan_no_h2o_2              es_scan_no_h2o_53
# 514  0.005716              gs_scan_no_h2o_2              es_scan_no_h2o_57
# 515  0.006915  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_57_vib_excited
# 294  0.004666              gs_scan_no_h2o_1              es_scan_no_h2o_47
# 295  0.005864  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_47_vib_excited
# 298  0.004831              gs_scan_no_h2o_1              es_scan_no_h2o_49
# 299  0.006029  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_49_vib_excited
# 28   0.001781              gs_scan_no_h2o_0              es_scan_no_h2o_14
# 29   0.002979  gs_scan_no_h2o_0_vib_excited  es_scan_no_h2o_14_vib_excited
# 497  0.005987  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_48_vib_excited
# 496  0.004788              gs_scan_no_h2o_2              es_scan_no_h2o_48
# 269  0.004624  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_34_vib_excited
# 268  0.003426              gs_scan_no_h2o_1              es_scan_no_h2o_34
# 518  0.005970              gs_scan_no_h2o_2              es_scan_no_h2o_59
# 519  0.007168  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_59_vib_excited
# 305  0.006428  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_52_vib_excited
# 304  0.005230              gs_scan_no_h2o_1              es_scan_no_h2o_52
# 302  0.005036              gs_scan_no_h2o_1              es_scan_no_h2o_51
# 303  0.006234  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_51_vib_excited
# 291  0.005662  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_45_vib_excited
# 290  0.004464              gs_scan_no_h2o_1              es_scan_no_h2o_45
# 605  0.001441  gs_scan_no_h2o_3_vib_excited   es_scan_no_h2o_2_vib_excited
# 604  0.000242              gs_scan_no_h2o_3               es_scan_no_h2o_2
# 522  0.006202              gs_scan_no_h2o_2              es_scan_no_h2o_61
# 523  0.007400  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_61_vib_excited
# 265  0.004606  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_32_vib_excited
# 264  0.003407              gs_scan_no_h2o_1              es_scan_no_h2o_32
# 488  0.004370              gs_scan_no_h2o_2              es_scan_no_h2o_44
# 489  0.005569  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_44_vib_excited
#
#       overlap
# 617  0.249780
# 616  0.249780
# 19   0.223592
# 18   0.223592
# 613  0.210888
# 612  0.210888
# 621  0.198315
# 620  0.198315
# 23   0.190519
# 22   0.190519
# 15   0.174167
# 14   0.174167
# 27   0.142575
# 26   0.142575
# 276  0.137215
# 277  0.137215
# 500  0.129535
# 501  0.129535
# 608  0.128288
# 609  0.128288
# 286  0.116232
# 287  0.116232
# 510  0.111322
# 511  0.111322
# 624  0.109981
# 625  0.109981
# 492  0.107216
# 493  0.107216
# 11   0.104229
# 10   0.104229
# 507  0.101171
# 506  0.101171
# 514  0.089744
# 515  0.089744
# 294  0.081810
# 295  0.081810
# 298  0.078374
# 299  0.078374
# 28   0.076284
# 29   0.076284
# 497  0.076138
# 496  0.076138
# 269  0.074644
# 268  0.074644
# 518  0.069691
# 519  0.069691
# 305  0.061508
# 304  0.061508
# 302  0.053783
# 303  0.053783
# 291  0.053271
# 290  0.053271
# 605  0.051080
# 604  0.051080
# 522  0.050256
# 523  0.050256
# 265  0.048170
# 264  0.048170
# 488  0.047840
# 489  0.047840

# %%
# Export overlap to csv file

overlap_df.to_csv('./phpy_overlap_list_no_zpe.csv')
