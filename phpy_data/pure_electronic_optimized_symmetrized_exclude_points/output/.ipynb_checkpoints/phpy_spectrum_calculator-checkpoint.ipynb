# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import random
from scipy import interpolate

# %%
import scipy

# %%
import pandas as pd

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 8)

# %%
from scipy.interpolate import interp1d

# %%
from dvr_setup_and_plotting_utils import *

# %%
# Run and collect ground state

# Reduced mass of freqency calculation =  3.5708    AMU

mass_ground = 3.5708*1836*24
print(str(mass_ground/1836))

num_wavefunctions_ground = 5
grid_points = 500


fit_potential_spline_assume_periodic_write_to_file(raw_potential_filename='gs_scan_no_water_raw_pot_optimized.dat',num_grid_points=grid_points,
                                output_potential_filename='gs_scan_no_water_fitted.dat',shift_origin=0.0,scale_factor=1.00)

print('potential written')

setup_dvr(num_states=num_wavefunctions_ground,num_grid_points=grid_points,mass=mass_ground,
                         potential_energy_file_name='gs_scan_no_water_fitted.dat',
                        output_file_name='gs_scan_no_h2o')

print('dvr is set up')
# Now need to make the output potential the potential_file.dat and run 
# ./dvr_1d_periodic
# Out:
# 85.6992
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp gs_scan_no_water_fitted.dat  potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above
# User must supply their own matrix diagonalization subroutine

# %%
# run DVR
# Now run excited state

mass_excited =   3.5786*1836*22
num_wavefunctions_excited = 200
print(str(mass_excited/1836))

fit_potential_spline_assume_periodic_write_to_file(raw_potential_filename='es_scan_no_water_raw_pot_optimized.dat',num_grid_points=grid_points,
                                output_potential_filename='es_scan_no_water_fitted.dat',shift_origin=0.0,scale_factor=1.0)

print('potential written')

setup_dvr(num_states=num_wavefunctions_excited,num_grid_points=grid_points,mass=mass_excited,
                         potential_energy_file_name='es_scan_no_water_fitted.dat',
                        output_file_name='es_scan_no_h2o')

print('dvr is set up')
# Out:
# 78.72919999999999
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp es_scan_no_water_fitted.dat potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above

# %%
# Absolute value of overlaps is calculated here

# %%
wavefunction_overlaps = read_wavefunctions_calculate_overlaps_vib_shift(
                                         ground_state_file_name_root='gs_scan_no_h2o',
                                         excited_state_file_name_root='es_scan_no_h2o',
                                         max_num_ground_state_wfs=4,
                                         max_num_excited_state_wfs=100,
                                         ground_state_max_energy=300,
                                         excited_state_max_energy=3000,
                                         vib_shift=263.0,
                                        vib_scale=1.0)
# Out:
# Calculating overlap for transition with energy 0.0
# Calculating overlap for transition with energy 1.46500602037513e-06
# Calculating overlap for transition with energy 61.791307794535456
# Calculating overlap for transition with energy 61.791308384962036
# Calculating overlap for transition with energy 122.83114316174638
# Calculating overlap for transition with energy 122.8311437400438
# Calculating overlap for transition with energy 181.2798686560484
# Calculating overlap for transition with energy 181.27986911375802
# Calculating overlap for transition with energy 238.0187228768423
# Calculating overlap for transition with energy 238.0187229426492
# Calculating overlap for transition with energy 295.57363290173674
# Calculating overlap for transition with energy 295.5736330737934
# Calculating overlap for transition with energy 354.7100073320443
# Calculating overlap for transition with energy 354.71000821290926
# Calculating overlap for transition with energy 389.72888234182903
# Calculating overlap for transition with energy 389.72888245845877
# Calculating overlap for transition with energy 414.62602836351726
# Calculating overlap for transition with energy 414.62602893258094
# Calculating overlap for transition with energy 474.57978520376633
# Calculating overlap for transition with energy 474.5797862651056
# Calculating overlap for transition with energy 482.39388922407375
# Calculating overlap for transition with energy 482.39388946419933
# Calculating overlap for transition with energy 534.2495537002623
# Calculating overlap for transition with energy 534.2495540770253
# Calculating overlap for transition with energy 571.0433616319306
# Calculating overlap for transition with energy 571.043361921363
# Calculating overlap for transition with energy 593.5471886887541
# Calculating overlap for transition with energy 593.5471896835365
# Calculating overlap for transition with energy 652.1590538410395
# Calculating overlap for transition with energy 652.1592821748728
# Calculating overlap for transition with energy 654.6925540199727
# Calculating overlap for transition with energy 654.6928175889707
# Calculating overlap for transition with energy 708.8950910710593
# Calculating overlap for transition with energy 708.8956996566293
# Calculating overlap for transition with energy 729.8949502599728
# Calculating overlap for transition with energy 729.8968536184375
# Calculating overlap for transition with energy 761.7637079788656
# Calculating overlap for transition with energy 761.7691358613398
# Calculating overlap for transition with energy 792.8612772562061
# Calculating overlap for transition with energy 792.876391628476
# Calculating overlap for transition with energy 822.7934213558225
# Calculating overlap for transition with energy 822.8248589422517
# Calculating overlap for transition with energy 858.8933290533525
# Calculating overlap for transition with energy 858.9589033751292
# Calculating overlap for transition with energy 894.7263764982894
# Calculating overlap for transition with energy 894.8638117257497
# Calculating overlap for transition with energy 932.7686731617664
# Calculating overlap for transition with energy 933.0559962840618
# Calculating overlap for transition with energy 971.4687367378378
# Calculating overlap for transition with energy 972.0713818028341
# Calculating overlap for transition with energy 1010.8949928987944
# Calculating overlap for transition with energy 1012.1533184693718
# Calculating overlap for transition with energy 1050.3728110890568
# Calculating overlap for transition with energy 1052.9689565121557
# Calculating overlap for transition with energy 1089.3173648383581
# Calculating overlap for transition with energy 1094.5395605820145
# Calculating overlap for transition with energy 1126.8198871307382
# Calculating overlap for transition with energy 1136.7718031323377
# Calculating overlap for transition with energy 1162.5830883364465
# Calculating overlap for transition with energy 1179.8144278847503
# Calculating overlap for transition with energy 1197.679877510396
# Calculating overlap for transition with energy 1223.7956592681662
# Calculating overlap for transition with energy 1234.4617523146956
# Calculating overlap for transition with energy 1268.9686946658867
# Calculating overlap for transition with energy 1274.5895209407026
# Calculating overlap for transition with energy 1315.5453742037344
# Calculating overlap for transition with energy 1318.2505640215772
# Calculating overlap for transition with energy 1363.6929255089874
# Calculating overlap for transition with energy 1364.9116652993844
# Calculating overlap for transition with energy 1413.5324068992122
# Calculating overlap for transition with energy 1414.0291346637457
# Calculating overlap for transition with energy 1465.091838229126
# Calculating overlap for transition with energy 1465.2796698296531
# Calculating overlap for transition with energy 1518.398802786736
# Calculating overlap for transition with energy 1518.445394765256
# Calculating overlap for transition with energy 1573.4237055413491
# Calculating overlap for transition with energy 1573.4287559977615
# Calculating overlap for transition with energy 1630.141779104466
# Calculating overlap for transition with energy 1630.1648792040687
# Calculating overlap for transition with energy 1688.552977633982
# Calculating overlap for transition with energy 1688.5873658546836
# Calculating overlap for transition with energy 1748.634894667339
# Calculating overlap for transition with energy 1748.6675172114617
# Calculating overlap for transition with energy 1810.3618294663218
# Calculating overlap for transition with energy 1810.3906177343622
# Calculating overlap for transition with energy 1873.7154303289553
# Calculating overlap for transition with energy 1873.74237439003
# Calculating overlap for transition with energy 1938.6822897433572
# Calculating overlap for transition with energy 1938.709374364276
# Calculating overlap for transition with energy 2005.2533209002368
# Calculating overlap for transition with energy 2005.2783604296524
# Calculating overlap for transition with energy 2073.4188062632275
# Calculating overlap for transition with energy 2073.4402189879806
# Calculating overlap for transition with energy 2143.1704563595863
# Calculating overlap for transition with energy 2143.1872131739547
# Calculating overlap for transition with energy 2214.4983888294846
# Calculating overlap for transition with energy 2214.5154705221457
# Calculating overlap for transition with energy 2287.39958097224
# Calculating overlap for transition with energy 2287.416119494068
# Calculating overlap for transition with energy 2361.870626390828
# Calculating overlap for transition with energy -4.682847154277494e-08
# Calculating overlap for transition with energy 1.4181775488323548e-06
# Calculating overlap for transition with energy 61.79130774770698
# Calculating overlap for transition with energy 61.79130833813357
# Calculating overlap for transition with energy 122.83114311491791
# Calculating overlap for transition with energy 122.83114369321532
# Calculating overlap for transition with energy 181.2798686092199
# Calculating overlap for transition with energy 181.27986906692956
# Calculating overlap for transition with energy 238.01872283001384
# Calculating overlap for transition with energy 238.01872289582073
# Calculating overlap for transition with energy 295.5736328549083
# Calculating overlap for transition with energy 295.57363302696496
# Calculating overlap for transition with energy 354.71000728521585
# Calculating overlap for transition with energy 354.7100081660808
# Calculating overlap for transition with energy 389.7288822950006
# Calculating overlap for transition with energy 389.7288824116303
# Calculating overlap for transition with energy 414.6260283166888
# Calculating overlap for transition with energy 414.6260288857524
# Calculating overlap for transition with energy 474.5797851569379
# Calculating overlap for transition with energy 474.57978621827715
# Calculating overlap for transition with energy 482.3938891772453
# Calculating overlap for transition with energy 482.3938894173709
# Calculating overlap for transition with energy 534.2495536534337
# Calculating overlap for transition with energy 534.2495540301969
# Calculating overlap for transition with energy 571.0433615851022
# Calculating overlap for transition with energy 571.0433618745346
# Calculating overlap for transition with energy 593.5471886419257
# Calculating overlap for transition with energy 593.547189636708
# Calculating overlap for transition with energy 652.159053794211
# Calculating overlap for transition with energy 652.1592821280443
# Calculating overlap for transition with energy 654.6925539731442
# Calculating overlap for transition with energy 654.6928175421423
# Calculating overlap for transition with energy 708.8950910242307
# Calculating overlap for transition with energy 708.8956996098008
# Calculating overlap for transition with energy 729.8949502131443
# Calculating overlap for transition with energy 729.896853571609
# Calculating overlap for transition with energy 761.763707932037
# Calculating overlap for transition with energy 761.7691358145113
# Calculating overlap for transition with energy 792.8612772093777
# Calculating overlap for transition with energy 792.8763915816476
# Calculating overlap for transition with energy 822.793421308994
# Calculating overlap for transition with energy 822.8248588954232
# Calculating overlap for transition with energy 858.8933290065241
# Calculating overlap for transition with energy 858.9589033283006
# Calculating overlap for transition with energy 894.726376451461
# Calculating overlap for transition with energy 894.8638116789213
# Calculating overlap for transition with energy 932.7686731149381
# Calculating overlap for transition with energy 933.0559962372332
# Calculating overlap for transition with energy 971.4687366910093
# Calculating overlap for transition with energy 972.0713817560057
# Calculating overlap for transition with energy 1010.894992851966
# Calculating overlap for transition with energy 1012.1533184225433
# Calculating overlap for transition with energy 1050.3728110422282
# Calculating overlap for transition with energy 1052.9689564653272
# Calculating overlap for transition with energy 1089.3173647915296
# Calculating overlap for transition with energy 1094.539560535186
# Calculating overlap for transition with energy 1126.8198870839094
# Calculating overlap for transition with energy 1136.7718030855092
# Calculating overlap for transition with energy 1162.583088289618
# Calculating overlap for transition with energy 1179.8144278379218
# Calculating overlap for transition with energy 1197.6798774635674
# Calculating overlap for transition with energy 1223.795659221338
# Calculating overlap for transition with energy 1234.461752267867
# Calculating overlap for transition with energy 1268.9686946190584
# Calculating overlap for transition with energy 1274.5895208938741
# Calculating overlap for transition with energy 1315.5453741569058
# Calculating overlap for transition with energy 1318.2505639747487
# Calculating overlap for transition with energy 1363.6929254621589
# Calculating overlap for transition with energy 1364.9116652525558
# Calculating overlap for transition with energy 1413.532406852384
# Calculating overlap for transition with energy 1414.0291346169172
# Calculating overlap for transition with energy 1465.0918381822974
# Calculating overlap for transition with energy 1465.2796697828246
# Calculating overlap for transition with energy 1518.3988027399078
# Calculating overlap for transition with energy 1518.4453947184277
# Calculating overlap for transition with energy 1573.4237054945208
# Calculating overlap for transition with energy 1573.428755950933
# Calculating overlap for transition with energy 1630.1417790576375
# Calculating overlap for transition with energy 1630.1648791572402
# Calculating overlap for transition with energy 1688.5529775871535
# Calculating overlap for transition with energy 1688.5873658078551
# Calculating overlap for transition with energy 1748.6348946205105
# Calculating overlap for transition with energy 1748.6675171646334
# Calculating overlap for transition with energy 1810.3618294194932
# Calculating overlap for transition with energy 1810.390617687534
# Calculating overlap for transition with energy 1873.715430282127
# Calculating overlap for transition with energy 1873.7423743432014
# Calculating overlap for transition with energy 1938.6822896965289
# Calculating overlap for transition with energy 1938.7093743174478
# Calculating overlap for transition with energy 2005.2533208534082
# Calculating overlap for transition with energy 2005.278360382824
# Calculating overlap for transition with energy 2073.418806216399
# Calculating overlap for transition with energy 2073.4402189411526
# Calculating overlap for transition with energy 2143.170456312758
# Calculating overlap for transition with energy 2143.187213127126
# Calculating overlap for transition with energy 2214.498388782656
# Calculating overlap for transition with energy 2214.515470475317
# Calculating overlap for transition with energy 2287.3995809254116
# Calculating overlap for transition with energy 2287.4161194472395
# Calculating overlap for transition with energy 2361.870626344
# Calculating overlap for transition with energy -2.6554378573525588
# Calculating overlap for transition with energy -2.6554363923465383
# Calculating overlap for transition with energy 59.135869937182896
# Calculating overlap for transition with energy 59.13587052760948
# Calculating overlap for transition with energy 120.17570530439384
# Calculating overlap for transition with energy 120.17570588269123
# Calculating overlap for transition with energy 178.62443079869584
# Calculating overlap for transition with energy 178.62443125640547
# Calculating overlap for transition with energy 235.36328501948975
# Calculating overlap for transition with energy 235.36328508529664
# Calculating overlap for transition with energy 292.91819504438416
# Calculating overlap for transition with energy 292.9181952164409
# Calculating overlap for transition with energy 352.0545694746918
# Calculating overlap for transition with energy 352.05457035555673
# Calculating overlap for transition with energy 387.07344448447645
# Calculating overlap for transition with energy 387.07344460110625
# Calculating overlap for transition with energy 411.97059050616474
# Calculating overlap for transition with energy 411.97059107522836
# Calculating overlap for transition with energy 471.9243473464138
# Calculating overlap for transition with energy 471.92434840775303
# Calculating overlap for transition with energy 479.7384513667212
# Calculating overlap for transition with energy 479.7384516068468
# Calculating overlap for transition with energy 531.5941158429097
# Calculating overlap for transition with energy 531.5941162196729
# Calculating overlap for transition with energy 568.3879237745781
# Calculating overlap for transition with energy 568.3879240640106
# Calculating overlap for transition with energy 590.8917508314015
# Calculating overlap for transition with energy 590.891751826184
# Calculating overlap for transition with energy 649.5036159836869
# Calculating overlap for transition with energy 649.5038443175202
# Calculating overlap for transition with energy 652.0371161626201
# Calculating overlap for transition with energy 652.0373797316182
# Calculating overlap for transition with energy 706.2396532137067
# Calculating overlap for transition with energy 706.2402617992767
# Calculating overlap for transition with energy 727.2395124026202
# Calculating overlap for transition with energy 727.2414157610849
# Calculating overlap for transition with energy 759.108270121513
# Calculating overlap for transition with energy 759.1136980039872
# Calculating overlap for transition with energy 790.2058393988536
# Calculating overlap for transition with energy 790.2209537711235
# Calculating overlap for transition with energy 820.1379834984699
# Calculating overlap for transition with energy 820.1694210848991
# Calculating overlap for transition with energy 856.237891196
# Calculating overlap for transition with energy 856.3034655177767
# Calculating overlap for transition with energy 892.0709386409367
# Calculating overlap for transition with energy 892.208373868397
# Calculating overlap for transition with energy 930.1132353044138
# Calculating overlap for transition with energy 930.4005584267092
# Calculating overlap for transition with energy 968.8132988804851
# Calculating overlap for transition with energy 969.4159439454814
# Calculating overlap for transition with energy 1008.2395550414418
# Calculating overlap for transition with energy 1009.4978806120192
# Calculating overlap for transition with energy 1047.7173732317042
# Calculating overlap for transition with energy 1050.3135186548031
# Calculating overlap for transition with energy 1086.6619269810055
# Calculating overlap for transition with energy 1091.884122724662
# Calculating overlap for transition with energy 1124.1644492733853
# Calculating overlap for transition with energy 1134.1163652749851
# Calculating overlap for transition with energy 1159.9276504790937
# Calculating overlap for transition with energy 1177.1589900273977
# Calculating overlap for transition with energy 1195.0244396530434
# Calculating overlap for transition with energy 1221.1402214108136
# Calculating overlap for transition with energy 1231.806314457343
# Calculating overlap for transition with energy 1266.313256808534
# Calculating overlap for transition with energy 1271.93408308335
# Calculating overlap for transition with energy 1312.8899363463815
# Calculating overlap for transition with energy 1315.5951261642247
# Calculating overlap for transition with energy 1361.0374876516346
# Calculating overlap for transition with energy 1362.2562274420316
# Calculating overlap for transition with energy 1410.8769690418596
# Calculating overlap for transition with energy 1411.3736968063931
# Calculating overlap for transition with energy 1462.4364003717733
# Calculating overlap for transition with energy 1462.6242319723005
# Calculating overlap for transition with energy 1515.7433649293835
# Calculating overlap for transition with energy 1515.7899569079034
# Calculating overlap for transition with energy 1570.7682676839966
# Calculating overlap for transition with energy 1570.7733181404087
# Calculating overlap for transition with energy 1627.4863412471134
# Calculating overlap for transition with energy 1627.5094413467161
# Calculating overlap for transition with energy 1685.8975397766294
# Calculating overlap for transition with energy 1685.931927997331
# Calculating overlap for transition with energy 1745.9794568099865
# Calculating overlap for transition with energy 1746.0120793541093
# Calculating overlap for transition with energy 1807.7063916089692
# Calculating overlap for transition with energy 1807.7351798770098
# Calculating overlap for transition with energy 1871.0599924716028
# Calculating overlap for transition with energy 1871.0869365326773
# Calculating overlap for transition with energy 1936.0268518860048
# Calculating overlap for transition with energy 1936.0539365069235
# Calculating overlap for transition with energy 2002.5978830428842
# Calculating overlap for transition with energy 2002.6229225723
# Calculating overlap for transition with energy 2070.763368405875
# Calculating overlap for transition with energy 2070.7847811306283
# Calculating overlap for transition with energy 2140.5150185022335
# Calculating overlap for transition with energy 2140.531775316602
# Calculating overlap for transition with energy 2211.8429509721323
# Calculating overlap for transition with energy 2211.8600326647934
# Calculating overlap for transition with energy 2284.7441431148877
# Calculating overlap for transition with energy 2284.7606816367156
# Calculating overlap for transition with energy 2359.2151885334756
# Calculating overlap for transition with energy -2.6554381475969953
# Calculating overlap for transition with energy -2.6554366825909748
# Calculating overlap for transition with energy 59.13586964693847
# Calculating overlap for transition with energy 59.13587023736503
# Calculating overlap for transition with energy 120.17570501414939
# Calculating overlap for transition with energy 120.1757055924468
# Calculating overlap for transition with energy 178.62443050845138
# Calculating overlap for transition with energy 178.62443096616104
# Calculating overlap for transition with energy 235.3632847292453
# Calculating overlap for transition with energy 235.3632847950522
# Calculating overlap for transition with energy 292.91819475413973
# Calculating overlap for transition with energy 292.9181949261964
# Calculating overlap for transition with energy 352.0545691844473
# Calculating overlap for transition with energy 352.0545700653123
# Calculating overlap for transition with energy 387.073444194232
# Calculating overlap for transition with energy 387.0734443108618
# Calculating overlap for transition with energy 411.97059021592025
# Calculating overlap for transition with energy 411.9705907849839
# Calculating overlap for transition with energy 471.9243470561694
# Calculating overlap for transition with energy 471.92434811750866
# Calculating overlap for transition with energy 479.7384510764768
# Calculating overlap for transition with energy 479.7384513166024
# Calculating overlap for transition with energy 531.5941155526654
# Calculating overlap for transition with energy 531.5941159294284
# Calculating overlap for transition with energy 568.3879234843337
# Calculating overlap for transition with energy 568.3879237737661
# Calculating overlap for transition with energy 590.8917505411572
# Calculating overlap for transition with energy 590.8917515359395
# Calculating overlap for transition with energy 649.5036156934425
# Calculating overlap for transition with energy 649.5038440272759
# Calculating overlap for transition with energy 652.0371158723757
# Calculating overlap for transition with energy 652.0373794413738
# Calculating overlap for transition with energy 706.2396529234622
# Calculating overlap for transition with energy 706.2402615090324
# Calculating overlap for transition with energy 727.2395121123758
# Calculating overlap for transition with energy 727.2414154708405
# Calculating overlap for transition with energy 759.1082698312687
# Calculating overlap for transition with energy 759.1136977137429
# Calculating overlap for transition with energy 790.2058391086092
# Calculating overlap for transition with energy 790.2209534808791
# Calculating overlap for transition with energy 820.1379832082255
# Calculating overlap for transition with energy 820.1694207946547
# Calculating overlap for transition with energy 856.2378909057555
# Calculating overlap for transition with energy 856.3034652275322
# Calculating overlap for transition with energy 892.0709383506922
# Calculating overlap for transition with energy 892.2083735781525
# Calculating overlap for transition with energy 930.1132350141694
# Calculating overlap for transition with energy 930.4005581364648
# Calculating overlap for transition with energy 968.8132985902408
# Calculating overlap for transition with energy 969.415943655237
# Calculating overlap for transition with energy 1008.2395547511974
# Calculating overlap for transition with energy 1009.4978803217748
# Calculating overlap for transition with energy 1047.7173729414596
# Calculating overlap for transition with energy 1050.3135183645586
# Calculating overlap for transition with energy 1086.661926690761
# Calculating overlap for transition with energy 1091.8841224344173
# Calculating overlap for transition with energy 1124.164448983141
# Calculating overlap for transition with energy 1134.1163649847406
# Calculating overlap for transition with energy 1159.9276501888494
# Calculating overlap for transition with energy 1177.1589897371534
# Calculating overlap for transition with energy 1195.0244393627988
# Calculating overlap for transition with energy 1221.140221120569
# Calculating overlap for transition with energy 1231.8063141670984
# Calculating overlap for transition with energy 1266.3132565182896
# Calculating overlap for transition with energy 1271.9340827931057
# Calculating overlap for transition with energy 1312.8899360561372
# Calculating overlap for transition with energy 1315.5951258739801
# Calculating overlap for transition with energy 1361.0374873613903
# Calculating overlap for transition with energy 1362.2562271517872
# Calculating overlap for transition with energy 1410.8769687516153
# Calculating overlap for transition with energy 1411.3736965161486
# Calculating overlap for transition with energy 1462.436400081529
# Calculating overlap for transition with energy 1462.624231682056
# Calculating overlap for transition with energy 1515.7433646391391
# Calculating overlap for transition with energy 1515.7899566176588
# Calculating overlap for transition with energy 1570.768267393752
# Calculating overlap for transition with energy 1570.7733178501644
# Calculating overlap for transition with energy 1627.4863409568688
# Calculating overlap for transition with energy 1627.5094410564718
# Calculating overlap for transition with energy 1685.8975394863849
# Calculating overlap for transition with energy 1685.9319277070865
# Calculating overlap for transition with energy 1745.9794565197421
# Calculating overlap for transition with energy 1746.0120790638648
# Calculating overlap for transition with energy 1807.7063913187249
# Calculating overlap for transition with energy 1807.7351795867653
# Calculating overlap for transition with energy 1871.0599921813584
# Calculating overlap for transition with energy 1871.086936242433
# Calculating overlap for transition with energy 1936.0268515957605
# Calculating overlap for transition with energy 1936.0539362166792
# Calculating overlap for transition with energy 2002.5978827526399
# Calculating overlap for transition with energy 2002.6229222820555
# Calculating overlap for transition with energy 2070.763368115631
# Calculating overlap for transition with energy 2070.784780840384
# Calculating overlap for transition with energy 2140.515018211989
# Calculating overlap for transition with energy 2140.5317750263575
# Calculating overlap for transition with energy 2211.8429506818875
# Calculating overlap for transition with energy 2211.860032374549
# Calculating overlap for transition with energy 2284.7441428246434
# Calculating overlap for transition with energy 2284.7606813464713
# Calculating overlap for transition with energy 2359.2151882432313

# %%
#This produces a list of dictionaries
# Showing example
wavefunction_overlaps[0]
# Out:
# {'energy': 0.0,
#  'ground_state_id': 'gs_scan_no_h2o_0',
#  'excited_state_id': 'es_scan_no_h2o_0',
#  'overlap': 3.072325047651587e-08}

# %%
overlap_df = pd.DataFrame(wavefunction_overlaps)

# %%
# Initial spectral plots

# %%
# Now, convert from a.u. to cm^-1, plot stem plot and compare to the experimental spectrum

offset = 35285

kidwell_uv_spectrum_energy = np.loadtxt('PhPy UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPy UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm^-1', fontsize = 12)
ax.set_ylabel('Intensity', fontsize = 12)
# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(35350,36400)
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity,label='Experiment', color='k',ls='-')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

# Might need to normalize

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)

#ax.stem(vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset, 
#        vibrational_state_overlaps_df['overlap'],linefmt='g-',markerfmt=' ',label='All',
#       basefmt=" ")

ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

#print(wavefunction_ground_vib_state_for_plotting_df)

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


#ax.stem(ground_vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset, 
#        ground_vibrational_state_overlaps_df['overlap'],linefmt='g-',markerfmt=' ',label='n=0 ground origin',
 #      basefmt=" ")

ax.legend()
plt.savefig('./theory_exp_spectrum_compare_mass_no_water_zpe_for_presentation.pdf')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:64: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Plot now with linewidth
# Reads in a list of frequencies and intensities
# Then produces two text files that have the right spectrum
def calc_spectrum_plot(freq_list=None,int_list=None,
                       min_freq=0.0,max_freq=0.0,width=1,resolution=0.05):
    
    num_points = int((max_freq-min_freq)/(resolution))
    
    frequencies = list()
    intensities = list()
    
    for i in range(0,num_points):
        frequency = min_freq+i*resolution
        intensity = 0.0
        
        for j in range(0,len(freq_list)):
            peak_center = freq_list[j]
            peak_height = int_list[j]
           # print(peak_center)
           # print(peak_height)
            intensity = intensity + peak_height*np.exp(-(frequency - peak_center)**2/(2*width))
    
        frequencies.append(frequency)
        intensities.append(intensity)
    
    return frequencies,intensities

# %%
theory_frequencies,theory_intensities = calc_spectrum_plot(
                    freq_list=vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset,
                    int_list=vibrational_state_overlaps_df['overlap'],
                       min_freq=offset-100,max_freq=offset+3000,width=10.0,resolution=1.0)

# %%
# Plot with both spectra on each other
# Two versions, one narrow range, one wider range

# %%
# Wide range

# Set baseline to zero 

kidwell_uv_spectrum_energy = np.loadtxt('PhPy UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPy UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm$^{-1}$', fontsize = 20)
ax.set_ylabel('Intensity', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=20)

# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(35350,38000)

max_freq = 38000
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity+0.8,label='Experiment', color='k',ls='-')


theory_plot_intensities = theory_intensities/max(theory_intensities)

# Plot the theory spectrum
ax.plot(theory_frequencies, theory_plot_intensities,label='Smoothed Model', color='k',ls='dashed')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)


ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


ax.legend()
plt.savefig('./theory_exp_spectrum_smooth_masses_no_water_zpe_for_presentation_wide_range.pdf',bbox_inches='tight')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:63: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:67: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Narrow Range

# Set baseline to zero 

kidwell_uv_spectrum_energy = np.loadtxt('PhPy UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPy UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm$^{-1}$', fontsize = 20)
ax.set_ylabel('Intensity', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=20)

# ax.set_title('Masses set to '+str(mass_ground)+' , '+str(mass_excited) + ' atomic units', fontsize = 12)
ax.set_xlim(35350,36250)

max_freq = 36250
 
#ax.plot(angles, kidwell_gs_with_h2o_interpolate_values*AU_TO_WAVENUMBER,label='Kidwell GS Potential with Water', color='r',ls='-')
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity+0.8,label='Experiment', color='k',ls='-')


theory_plot_intensities = theory_intensities/max(theory_intensities)

# Plot the theory spectrum
ax.plot(theory_frequencies, theory_plot_intensities,label='Smoothed Model', color='k',ls='dashed')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)


ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")

ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


ax.legend()
plt.savefig('./theory_exp_spectrum_smooth_masses_no_water_zpe_for_presentation_narrow_range.pdf',bbox_inches='tight')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:63: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:67: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Plot the lowest 4 ground state wavefunctions
ground_state_file_name_root='gs_scan_no_h2o'
excited_state_file_name_root='es_scan_no_h2o'
max_num_ground_state_wfs=4
max_num_excited_state_wfs=100

# %%
ground_state_dict = read_dvr_output(filename_root=ground_state_file_name_root,num_states=max_num_ground_state_wfs)
excited_state_dict = read_dvr_output(filename_root=excited_state_file_name_root,num_states=max_num_excited_state_wfs)

# %%
# plot the potential and square of the wavefunction 
# (avoids ambiguity on signs) of the ground state potential

wavefunction_counter = 0

max_wavefunctions = 4

for i in range(0,4):
    plot_wavefunction_squared(state_dict=ground_state_dict,
                        state_num=i,prefix="gs_scan_no_h2o_",
                      plotting_potential_name="gs_scan_no_water_fitted.dat",
                     potential="Ground State PES",mass=mass_ground)
# Out:
# Examining state gs_scan_no_h2o_0
# Examining state gs_scan_no_h2o_1
# Examining state gs_scan_no_h2o_2
# Examining state gs_scan_no_h2o_3

# %%
plot_potential_and_energy_levels(state_dict=ground_state_dict,
                       prefix="gs_scan_no_h2o_",
                      plotting_potential_name="gs_scan_no_water_fitted.dat",
                     potential="Ground State PES",mass=mass_ground,max_energy=200)

# %%
plot_potential_and_energy_levels(state_dict=excited_state_dict,
                       prefix="es_scan_no_h2o",
                      plotting_potential_name="es_scan_no_water_fitted.dat",
                     potential="Excited State PES",mass=mass_ground,max_energy=1500)

# %%
# Get maximum overlaps so we can plot those excited state wavefunctions
overlap_df.sort_values(by=['overlap'],ascending=False).head(60)
# Out:
#        energy               ground_state_id               excited_state_id  \
# 416  0.000966              gs_scan_no_h2o_2               es_scan_no_h2o_8
# 417  0.002165  gs_scan_no_h2o_2_vib_excited   es_scan_no_h2o_8_vib_excited
# 18   0.000967              gs_scan_no_h2o_0               es_scan_no_h2o_9
# 19   0.002165  gs_scan_no_h2o_0_vib_excited   es_scan_no_h2o_9_vib_excited
# 413  0.001925  gs_scan_no_h2o_2_vib_excited   es_scan_no_h2o_6_vib_excited
# 412  0.000727              gs_scan_no_h2o_2               es_scan_no_h2o_6
# 14   0.000728              gs_scan_no_h2o_0               es_scan_no_h2o_7
# 15   0.001926  gs_scan_no_h2o_0_vib_excited   es_scan_no_h2o_7_vib_excited
# 22   0.001203              gs_scan_no_h2o_0              es_scan_no_h2o_11
# 23   0.002401  gs_scan_no_h2o_0_vib_excited  es_scan_no_h2o_11_vib_excited
# 421  0.002401  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_10_vib_excited
# 420  0.001202              gs_scan_no_h2o_2              es_scan_no_h2o_10
# 24   0.001437              gs_scan_no_h2o_0              es_scan_no_h2o_12
# 25   0.002635  gs_scan_no_h2o_0_vib_excited  es_scan_no_h2o_12_vib_excited
# 426  0.001436              gs_scan_no_h2o_2              es_scan_no_h2o_13
# 427  0.002635  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_13_vib_excited
# 410  0.000486              gs_scan_no_h2o_2               es_scan_no_h2o_5
# 411  0.001684  gs_scan_no_h2o_2_vib_excited   es_scan_no_h2o_5_vib_excited
# 8    0.000486              gs_scan_no_h2o_0               es_scan_no_h2o_4
# 9    0.001684  gs_scan_no_h2o_0_vib_excited   es_scan_no_h2o_4_vib_excited
# 717  0.006607  gs_scan_no_h2o_3_vib_excited  es_scan_no_h2o_58_vib_excited
# 716  0.005409              gs_scan_no_h2o_3              es_scan_no_h2o_58
# 317  0.006608  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_58_vib_excited
# 316  0.005410              gs_scan_no_h2o_1              es_scan_no_h2o_58
# 709  0.006172  gs_scan_no_h2o_3_vib_excited  es_scan_no_h2o_54_vib_excited
# 708  0.004974              gs_scan_no_h2o_3              es_scan_no_h2o_54
# 309  0.006173  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_54_vib_excited
# 308  0.004974              gs_scan_no_h2o_1              es_scan_no_h2o_54
# 720  0.005595              gs_scan_no_h2o_3              es_scan_no_h2o_60
# 721  0.006794  gs_scan_no_h2o_3_vib_excited  es_scan_no_h2o_60_vib_excited
# 321  0.006794  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_60_vib_excited
# 320  0.005596              gs_scan_no_h2o_1              es_scan_no_h2o_60
# 28   0.001669              gs_scan_no_h2o_0              es_scan_no_h2o_14
# 29   0.002868  gs_scan_no_h2o_0_vib_excited  es_scan_no_h2o_14_vib_excited
# 431  0.002867  gs_scan_no_h2o_2_vib_excited  es_scan_no_h2o_15_vib_excited
# 430  0.001669              gs_scan_no_h2o_2              es_scan_no_h2o_15
# 725  0.007019  gs_scan_no_h2o_3_vib_excited  es_scan_no_h2o_62_vib_excited
# 724  0.005820              gs_scan_no_h2o_3              es_scan_no_h2o_62
# 324  0.005821              gs_scan_no_h2o_1              es_scan_no_h2o_62
# 325  0.007019  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_62_vib_excited
# 696  0.004389              gs_scan_no_h2o_3              es_scan_no_h2o_48
# 697  0.005588  gs_scan_no_h2o_3_vib_excited  es_scan_no_h2o_48_vib_excited
# 729  0.007215  gs_scan_no_h2o_3_vib_excited  es_scan_no_h2o_64_vib_excited
# 728  0.006017              gs_scan_no_h2o_3              es_scan_no_h2o_64
# 329  0.007216  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_64_vib_excited
# 328  0.006017              gs_scan_no_h2o_1              es_scan_no_h2o_64
# 296  0.004390              gs_scan_no_h2o_1              es_scan_no_h2o_48
# 297  0.005588  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_48_vib_excited
# 405  0.001441  gs_scan_no_h2o_2_vib_excited   es_scan_no_h2o_2_vib_excited
# 404  0.000242              gs_scan_no_h2o_2               es_scan_no_h2o_2
# 7    0.001441  gs_scan_no_h2o_0_vib_excited   es_scan_no_h2o_3_vib_excited
# 6    0.000243              gs_scan_no_h2o_0               es_scan_no_h2o_3
# 311  0.006174  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_55_vib_excited
# 310  0.004975              gs_scan_no_h2o_1              es_scan_no_h2o_55
# 685  0.005037  gs_scan_no_h2o_3_vib_excited  es_scan_no_h2o_42_vib_excited
# 684  0.003839              gs_scan_no_h2o_3              es_scan_no_h2o_42
# 711  0.006173  gs_scan_no_h2o_3_vib_excited  es_scan_no_h2o_55_vib_excited
# 710  0.004975              gs_scan_no_h2o_3              es_scan_no_h2o_55
# 319  0.006612  gs_scan_no_h2o_1_vib_excited  es_scan_no_h2o_59_vib_excited
# 318  0.005414              gs_scan_no_h2o_1              es_scan_no_h2o_59
#
#       overlap
# 416  0.224191
# 417  0.224191
# 18   0.223868
# 19   0.223868
# 413  0.195245
# 412  0.195245
# 14   0.194238
# 15   0.194238
# 22   0.190843
# 23   0.190843
# 421  0.190363
# 420  0.190363
# 24   0.123121
# 25   0.123121
# 426  0.122213
# 427  0.122213
# 410  0.121960
# 411  0.121960
# 8    0.120868
# 9    0.120868
# 717  0.068297
# 716  0.068297
# 317  0.067956
# 316  0.067956
# 709  0.064442
# 708  0.064442
# 309  0.063937
# 308  0.063937
# 720  0.061768
# 721  0.061768
# 321  0.061437
# 320  0.061437
# 28   0.060694
# 29   0.060694
# 431  0.059823
# 430  0.059823
# 725  0.054130
# 724  0.054130
# 324  0.053795
# 325  0.053795
# 696  0.052884
# 697  0.052884
# 729  0.052883
# 728  0.052883
# 329  0.052517
# 328  0.052517
# 296  0.048844
# 297  0.048844
# 405  0.048462
# 404  0.048462
# 7    0.047830
# 6    0.047830
# 311  0.047338
# 310  0.047338
# 685  0.047228
# 684  0.047228
# 711  0.046773
# 710  0.046773
# 319  0.045933
# 318  0.045933

# %%
# Export overlap to csv file

overlap_df.to_csv('./phpy_overlap_list_no_zpe.csv')
