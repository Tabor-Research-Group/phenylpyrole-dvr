# %%
# Notebook for calculating the 
# vibronic spectra
# This program fits potential energy surfaces
# and sets up the necessary DVR calculations
# Notebook is annotated where the DVR calculation must
# be executed before continuing

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import random
from scipy import interpolate

# %%
import scipy

# %%
import pandas as pd

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 8)

# %%
from scipy.interpolate import interp1d

# %%
from dvr_setup_and_plotting_utils import *

# %%
# Run and collect ground state information
# Reduced mass of freqency calculation =  4.0054 AMU

# Final fitted result worked best with the following fitted mass

mass_ground = 4.0054*1836*18
print(str(mass_ground/1836))

num_wavefunctions_ground = 5
grid_points = 500 # This number is N, number of points in DVR is 2N+1

# Linear fit used in production 
# Cubic fit also written 

fit_linear_potential_assume_periodic_write_to_file(raw_potential_filename='ground_state_scan_with_water_raw_pot_no_zpe.dat',num_grid_points=grid_points,
                                output_potential_filename='gs_scan_with_water_fitted.dat',shift_origin=0.0,scale_factor=1.00)


print('potential written')

setup_dvr(num_states=num_wavefunctions_ground,num_grid_points=grid_points,mass=mass_ground,
                         potential_energy_file_name='gs_scan_with_water_fitted.dat',
                        output_file_name='gs_scan_with_h2o')

print('dvr is set up')
# Out:
# 72.09719999999999
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp gs_scan_with_water_fitted_zpe.dat potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above
# User must supply their own matrix diagonalization subroutine

# %%
# Now setup and run the excited state excited state
# Reduced mass from excited state vibrational frequency calculation is 3.8404 

mass_excited =  3.8404*1836*18
num_wavefunctions_excited = 200
print(str(mass_excited/1836))

fit_linear_potential_assume_periodic_write_to_file(raw_potential_filename='excited_state_scan_with_water_raw_pot_with_zpe.dat',num_grid_points=grid_points,
                                output_potential_filename='es_scan_with_water_fitted_zpe.dat',shift_origin=0.0,scale_factor=1.0)

print('potential written')

setup_dvr(num_states=num_wavefunctions_excited,num_grid_points=grid_points,mass=mass_excited,
                         potential_energy_file_name='es_scan_with_water_fitted_zpe.dat',
                        output_file_name='es_scan_with_h2o_zpe')

print('dvr is set up')
# Out:
# 69.1272
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp es_scan_with_water_fitted_zpe.dat potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above

# %%
# Absolute value of overlaps is calculated here

# %%
wavefunction_overlaps = read_wavefunctions_calculate_overlaps_vib_shift(
                                         ground_state_file_name_root='gs_scan_with_h2o_zpe',
                                         excited_state_file_name_root='es_scan_with_h2o_zpe',
                                         max_num_ground_state_wfs=4,
                                         max_num_excited_state_wfs=100,
                                         ground_state_max_energy=300,
                                         excited_state_max_energy=2000,
                                         vib_shift=195.0,
                                        vib_scale=1.0)
# Out:
# Calculating overlap for transition with energy 0.0
# Calculating overlap for transition with energy 12.053122652901234
# Calculating overlap for transition with energy 59.77608942807017
# Calculating overlap for transition with energy 73.35997373219716
# Calculating overlap for transition with energy 138.8120164310121
# Calculating overlap for transition with energy 148.36980922346547
# Calculating overlap for transition with energy 220.43028400912812
# Calculating overlap for transition with energy 223.31233602654984
# Calculating overlap for transition with energy 296.3323628451856
# Calculating overlap for transition with energy 300.2400959525502
# Calculating overlap for transition with energy 373.66059097048384
# Calculating overlap for transition with energy 375.43699613552536
# Calculating overlap for transition with energy 444.8121827903379
# Calculating overlap for transition with energy 449.2691066499241
# Calculating overlap for transition with energy 508.6288737999274
# Calculating overlap for transition with energy 524.274633105933
# Calculating overlap for transition with energy 570.4005845999727
# Calculating overlap for transition with energy 599.2512430951863
# Calculating overlap for transition with energy 631.8117653344477
# Calculating overlap for transition with energy 672.7409839156624
# Calculating overlap for transition with energy 696.6931788500581
# Calculating overlap for transition with energy 743.9060566212391
# Calculating overlap for transition with energy 764.7758113502957
# Calculating overlap for transition with energy 812.7257322974635
# Calculating overlap for transition with energy 834.1767003194348
# Calculating overlap for transition with energy 880.5133143576821
# Calculating overlap for transition with energy 906.0219952654775
# Calculating overlap for transition with energy 946.3479823080278
# Calculating overlap for transition with energy 977.9217450310316
# Calculating overlap for transition with energy 1010.0915298044813
# Calculating overlap for transition with energy 1047.3312839310431
# Calculating overlap for transition with energy 1072.997888996389
# Calculating overlap for transition with energy 1115.1822585345658
# Calculating overlap for transition with energy 1135.2949587049263
# Calculating overlap for transition with energy 1180.493503982662
# Calculating overlap for transition with energy 1196.5086816147834
# Calculating overlap for transition with energy 1242.0626901937874
# Calculating overlap for transition with energy 1258.3800983451777
# Calculating overlap for transition with energy 1299.6190802351946
# Calculating overlap for transition with energy 1319.9682989966811
# Calculating overlap for transition with energy 1353.9569812192547
# Calculating overlap for transition with energy 1381.8920965680547
# Calculating overlap for transition with energy 1405.6218445311856
# Calculating overlap for transition with energy 1444.2699053028373
# Calculating overlap for transition with energy 1455.308678943642
# Calculating overlap for transition with energy 1505.3725705690722
# Calculating overlap for transition with energy 1506.0452787693262
# Calculating overlap for transition with energy 1555.5758474642623
# Calculating overlap for transition with energy 1567.431898503414
# Calculating overlap for transition with energy 1606.3940708572168
# Calculating overlap for transition with energy 1627.3845388264008
# Calculating overlap for transition with energy 1657.7754268517172
# Calculating overlap for transition with energy 1684.015312306735
# Calculating overlap for transition with energy 1708.7115220248843
# Calculating overlap for transition with energy 1731.6439079960621
# Calculating overlap for transition with energy 1757.125576408695
# Calculating overlap for transition with energy 1772.5291432424608
# Calculating overlap for transition with energy 1800.7315967519742
# Calculating overlap for transition with energy 1821.510638900654
# Calculating overlap for transition with energy 1842.2677081091897
# Calculating overlap for transition with energy 1874.519921359541
# Calculating overlap for transition with energy 1888.7978216383865
# Calculating overlap for transition with energy 1926.5154215815187
# Calculating overlap for transition with energy 1938.3208747340832
# Calculating overlap for transition with energy -3.8963145598422555
# Calculating overlap for transition with energy 8.156808093058977
# Calculating overlap for transition with energy 55.87977486822791
# Calculating overlap for transition with energy 69.46365917235491
# Calculating overlap for transition with energy 134.91570187116986
# Calculating overlap for transition with energy 144.4734946636232
# Calculating overlap for transition with energy 216.53396944928588
# Calculating overlap for transition with energy 219.4160214667076
# Calculating overlap for transition with energy 292.43604828534336
# Calculating overlap for transition with energy 296.3437813927079
# Calculating overlap for transition with energy 369.76427641064157
# Calculating overlap for transition with energy 371.5406815756831
# Calculating overlap for transition with energy 440.9158682304956
# Calculating overlap for transition with energy 445.3727920900818
# Calculating overlap for transition with energy 504.73255924008515
# Calculating overlap for transition with energy 520.3783185460908
# Calculating overlap for transition with energy 566.5042700401305
# Calculating overlap for transition with energy 595.354928535344
# Calculating overlap for transition with energy 627.9154507746055
# Calculating overlap for transition with energy 668.84466935582
# Calculating overlap for transition with energy 692.7968642902158
# Calculating overlap for transition with energy 740.0097420613969
# Calculating overlap for transition with energy 760.8794967904535
# Calculating overlap for transition with energy 808.8294177376213
# Calculating overlap for transition with energy 830.2803857595925
# Calculating overlap for transition with energy 876.6169997978399
# Calculating overlap for transition with energy 902.1256807056352
# Calculating overlap for transition with energy 942.4516677481856
# Calculating overlap for transition with energy 974.0254304711895
# Calculating overlap for transition with energy 1006.1952152446391
# Calculating overlap for transition with energy 1043.434969371201
# Calculating overlap for transition with energy 1069.1015744365468
# Calculating overlap for transition with energy 1111.2859439747238
# Calculating overlap for transition with energy 1131.3986441450843
# Calculating overlap for transition with energy 1176.5971894228198
# Calculating overlap for transition with energy 1192.6123670549412
# Calculating overlap for transition with energy 1238.166375633945
# Calculating overlap for transition with energy 1254.4837837853354
# Calculating overlap for transition with energy 1295.7227656753523
# Calculating overlap for transition with energy 1316.0719844368389
# Calculating overlap for transition with energy 1350.0606666594126
# Calculating overlap for transition with energy 1377.9957820082127
# Calculating overlap for transition with energy 1401.7255299713436
# Calculating overlap for transition with energy 1440.3735907429952
# Calculating overlap for transition with energy 1451.4123643837997
# Calculating overlap for transition with energy 1501.47625600923
# Calculating overlap for transition with energy 1502.148964209484
# Calculating overlap for transition with energy 1551.6795329044203
# Calculating overlap for transition with energy 1563.535583943572
# Calculating overlap for transition with energy 1602.4977562973745
# Calculating overlap for transition with energy 1623.4882242665585
# Calculating overlap for transition with energy 1653.879112291875
# Calculating overlap for transition with energy 1680.118997746893
# Calculating overlap for transition with energy 1704.8152074650422
# Calculating overlap for transition with energy 1727.7475934362199
# Calculating overlap for transition with energy 1753.2292618488527
# Calculating overlap for transition with energy 1768.6328286826188
# Calculating overlap for transition with energy 1796.8352821921321
# Calculating overlap for transition with energy 1817.614324340812
# Calculating overlap for transition with energy 1838.3713935493474
# Calculating overlap for transition with energy 1870.6236067996988
# Calculating overlap for transition with energy 1884.9015070785442
# Calculating overlap for transition with energy 1922.6191070216764
# Calculating overlap for transition with energy 1934.424560174241
# Calculating overlap for transition with energy -15.590578660197975
# Calculating overlap for transition with energy -3.537456007296742
# Calculating overlap for transition with energy 44.185510767872195
# Calculating overlap for transition with energy 57.769395071999185
# Calculating overlap for transition with energy 123.22143777081413
# Calculating overlap for transition with energy 132.77923056326748
# Calculating overlap for transition with energy 204.83970534893012
# Calculating overlap for transition with energy 207.72175736635188
# Calculating overlap for transition with energy 280.74178418498764
# Calculating overlap for transition with energy 284.6495172923522
# Calculating overlap for transition with energy 358.07001231028585
# Calculating overlap for transition with energy 359.8464174753274
# Calculating overlap for transition with energy 429.2216041301399
# Calculating overlap for transition with energy 433.67852798972604
# Calculating overlap for transition with energy 493.03829513972954
# Calculating overlap for transition with energy 508.68405444573506
# Calculating overlap for transition with energy 554.8100059397748
# Calculating overlap for transition with energy 583.6606644349882
# Calculating overlap for transition with energy 616.2211866742498
# Calculating overlap for transition with energy 657.1504052554643
# Calculating overlap for transition with energy 681.10260018986
# Calculating overlap for transition with energy 728.3154779610413
# Calculating overlap for transition with energy 749.1852326900978
# Calculating overlap for transition with energy 797.1351536372656
# Calculating overlap for transition with energy 818.5861216592367
# Calculating overlap for transition with energy 864.9227356974842
# Calculating overlap for transition with energy 890.4314166052795
# Calculating overlap for transition with energy 930.7574036478298
# Calculating overlap for transition with energy 962.3311663708337
# Calculating overlap for transition with energy 994.5009511442834
# Calculating overlap for transition with energy 1031.7407052708452
# Calculating overlap for transition with energy 1057.4073103361911
# Calculating overlap for transition with energy 1099.5916798743679
# Calculating overlap for transition with energy 1119.7043800447284
# Calculating overlap for transition with energy 1164.9029253224642
# Calculating overlap for transition with energy 1180.9181029545855
# Calculating overlap for transition with energy 1226.4721115335894
# Calculating overlap for transition with energy 1242.7895196849797
# Calculating overlap for transition with energy 1284.0285015749967
# Calculating overlap for transition with energy 1304.3777203364832
# Calculating overlap for transition with energy 1338.366402559057
# Calculating overlap for transition with energy 1366.3015179078568
# Calculating overlap for transition with energy 1390.0312658709877
# Calculating overlap for transition with energy 1428.6793266426394
# Calculating overlap for transition with energy 1439.718100283444
# Calculating overlap for transition with energy 1489.7819919088743
# Calculating overlap for transition with energy 1490.4547001091282
# Calculating overlap for transition with energy 1539.9852688040644
# Calculating overlap for transition with energy 1551.841319843216
# Calculating overlap for transition with energy 1590.8034921970188
# Calculating overlap for transition with energy 1611.7939601662029
# Calculating overlap for transition with energy 1642.1848481915192
# Calculating overlap for transition with energy 1668.424733646537
# Calculating overlap for transition with energy 1693.1209433646864
# Calculating overlap for transition with energy 1716.053329335864
# Calculating overlap for transition with energy 1741.5349977484968
# Calculating overlap for transition with energy 1756.9385645822626
# Calculating overlap for transition with energy 1785.141018091776
# Calculating overlap for transition with energy 1805.9200602404558
# Calculating overlap for transition with energy 1826.6771294489915
# Calculating overlap for transition with energy 1858.929342699343
# Calculating overlap for transition with energy 1873.2072429781883
# Calculating overlap for transition with energy 1910.9248429213205
# Calculating overlap for transition with energy 1922.730296073885
# Calculating overlap for transition with energy -16.275782276342724
# Calculating overlap for transition with energy -4.222659623441491
# Calculating overlap for transition with energy 43.50030715172745
# Calculating overlap for transition with energy 57.08419145585444
# Calculating overlap for transition with energy 122.53623415466939
# Calculating overlap for transition with energy 132.09402694712273
# Calculating overlap for transition with energy 204.15450173278538
# Calculating overlap for transition with energy 207.03655375020713
# Calculating overlap for transition with energy 280.0565805688429
# Calculating overlap for transition with energy 283.96431367620744
# Calculating overlap for transition with energy 357.3848086941411
# Calculating overlap for transition with energy 359.1612138591827
# Calculating overlap for transition with energy 428.5364005139952
# Calculating overlap for transition with energy 432.99332437358134
# Calculating overlap for transition with energy 492.35309152358474
# Calculating overlap for transition with energy 507.99885082959037
# Calculating overlap for transition with energy 554.12480232363
# Calculating overlap for transition with energy 582.9754608188435
# Calculating overlap for transition with energy 615.535983058105
# Calculating overlap for transition with energy 656.4652016393196
# Calculating overlap for transition with energy 680.4173965737153
# Calculating overlap for transition with energy 727.6302743448965
# Calculating overlap for transition with energy 748.500029073953
# Calculating overlap for transition with energy 796.4499500211208
# Calculating overlap for transition with energy 817.900918043092
# Calculating overlap for transition with energy 864.2375320813394
# Calculating overlap for transition with energy 889.7462129891347
# Calculating overlap for transition with energy 930.072200031685
# Calculating overlap for transition with energy 961.6459627546889
# Calculating overlap for transition with energy 993.8157475281386
# Calculating overlap for transition with energy 1031.0555016547005
# Calculating overlap for transition with energy 1056.7221067200462
# Calculating overlap for transition with energy 1098.9064762582232
# Calculating overlap for transition with energy 1119.0191764285837
# Calculating overlap for transition with energy 1164.2177217063193
# Calculating overlap for transition with energy 1180.2328993384408
# Calculating overlap for transition with energy 1225.7869079174445
# Calculating overlap for transition with energy 1242.1043160688348
# Calculating overlap for transition with energy 1283.3432979588517
# Calculating overlap for transition with energy 1303.6925167203383
# Calculating overlap for transition with energy 1337.681198942912
# Calculating overlap for transition with energy 1365.6163142917121
# Calculating overlap for transition with energy 1389.346062254843
# Calculating overlap for transition with energy 1427.9941230264947
# Calculating overlap for transition with energy 1439.0328966672994
# Calculating overlap for transition with energy 1489.0967882927293
# Calculating overlap for transition with energy 1489.7694964929833
# Calculating overlap for transition with energy 1539.3000651879197
# Calculating overlap for transition with energy 1551.1561162270714
# Calculating overlap for transition with energy 1590.1182885808742
# Calculating overlap for transition with energy 1611.108756550058
# Calculating overlap for transition with energy 1641.4996445753745
# Calculating overlap for transition with energy 1667.7395300303924
# Calculating overlap for transition with energy 1692.4357397485417
# Calculating overlap for transition with energy 1715.3681257197195
# Calculating overlap for transition with energy 1740.8497941323526
# Calculating overlap for transition with energy 1756.2533609661184
# Calculating overlap for transition with energy 1784.4558144756313
# Calculating overlap for transition with energy 1805.2348566243115
# Calculating overlap for transition with energy 1825.9919258328466
# Calculating overlap for transition with energy 1858.2441390831987
# Calculating overlap for transition with energy 1872.5220393620436
# Calculating overlap for transition with energy 1910.2396393051756
# Calculating overlap for transition with energy 1922.04509245774

# %%
#This produces a list of dictionaries
# Showing example
wavefunction_overlaps[0]
# Out:
# {'energy': 0.0,
#  'ground_state_id': 'gs_scan_with_h2o_zpe_0',
#  'excited_state_id': 'es_scan_with_h2o_zpe_0',
#  'overlap': 6.028572892571118e-14}

# %%
# Turn list of dictionaries into a dataframe
overlap_df = pd.DataFrame(wavefunction_overlaps)

# %%
# Now, convert from a.u. to cm^-1, plot stem plot and compare to the experimental spectrum
# Use same color scheme as experimental section

# Exp files: PhPyH2O UV Spectrum.txt
# Exp file 2: PhPyH2O UV Spectrum.txt 

offset = 35240

kidwell_uv_spectrum_energy = np.loadtxt('PhPyH2O UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPyH2O UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 


ax.set_xlabel('Energy cm^-1', fontsize = 12)
ax.set_ylabel('Intensity', fontsize = 12)
ax.set_xlim(35100,35700)
 
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity,label='Experiment', color='k',ls='-')

# In principle can 
# scale the overlaps that involve the second vibrationale xcited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)



wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)



ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion only',
       basefmt=" ")


ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")

ax.legend()
plt.savefig('./theory_exp_spectrum_compare_mass_with_water_zpe_for_presentation.pdf')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:63: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Plot now with linewidth
# Reads in a list of frequencies and intensities
# Then produces two text files that have the right spectrum
def calc_spectrum_plot(freq_list=None,int_list=None,
                       min_freq=0.0,max_freq=0.0,width=1,resolution=0.05):
    
    num_points = int((max_freq-min_freq)/(resolution))
    
    frequencies = list()
    intensities = list()
    
    for i in range(0,num_points):
        frequency = min_freq+i*resolution
        intensity = 0.0
        
        for j in range(0,len(freq_list)):
            peak_center = freq_list[j]
            peak_height = int_list[j]
           # print(peak_center)
           # print(peak_height)
            intensity = intensity + peak_height*np.exp(-(frequency - peak_center)**2/(2*width))
    
        frequencies.append(frequency)
        intensities.append(intensity)
    
    return frequencies,intensities

# %%
theory_frequencies,theory_intensities = calc_spectrum_plot(
                    freq_list=vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset,
                    int_list=vibrational_state_overlaps_df['overlap'],
                       min_freq=offset-50,max_freq=offset+1000,width=10.0,resolution=0.5)

# %%
# Plot with both spectra on each other

# Set baseline to zero 

kidwell_uv_spectrum_energy = np.loadtxt('PhPyH2O UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPyH2O UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm$^{-1}$', fontsize = 20)
ax.set_ylabel('Intensity', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=20)


ax.set_xlim(35150,35600)

max_freq = 38000
 
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity+0.8,label='Experiment', color='k',ls='-')


theory_plot_intensities = theory_intensities/max(theory_intensities)

# Plot the theory spectrum
ax.plot(theory_frequencies, theory_plot_intensities,label='Smoothed Model', color='k',ls='dashed')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

# Might need to normalize

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)



ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")


ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


ax.legend()
plt.savefig('./theory_exp_spectrum_smooth_with_water_zpe_for_presentation.pdf',bbox_inches='tight')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:65: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:70: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Generate plots of the wavefunctions
# or squares of the wavefunctions
ground_state_file_name_root='gs_scan_with_h2o_zpe'
excited_state_file_name_root='es_scan_with_h2o_zpe'
max_num_ground_state_wfs=4
max_num_excited_state_wfs=100

# %%
ground_state_dict = read_dvr_output(filename_root=ground_state_file_name_root,num_states=max_num_ground_state_wfs)
excited_state_dict = read_dvr_output(filename_root=excited_state_file_name_root,num_states=max_num_excited_state_wfs)

# %%
# plot the potential and square of the wavefunction 
# (avoids ambiguity on signs) of the ground state potential


wavefunction_counter = 0

max_wavefunctions = 4

prefix = "kidwell_gs_scan_with_h2o_zpe"

for i in range(0,4):
    plot_wavefunction_squared(state_dict=ground_state_dict,
                        state_num=i,prefix="gs_scan_with_h2o_zpe_",
                      plotting_potential_name="gs_scan_with_water_fitted_zpe.dat",
                     potential="Ground State PES",mass=mass_ground)
# Out:
# Examining state gs_scan_with_h2o_zpe_0
# Examining state gs_scan_with_h2o_zpe_1
# Examining state gs_scan_with_h2o_zpe_2
# Examining state gs_scan_with_h2o_zpe_3

# %%
# Plot potential with energy levels

plot_potential_and_energy_levels(state_dict=ground_state_dict,
                       prefix="gs_scan_with_h2o_zpe_",
                      plotting_potential_name="gs_scan_with_water_fitted_zpe.dat",
                     potential="Ground State PES",mass=mass_ground,max_energy=70)

# %%
plot_potential_and_energy_levels(state_dict=excited_state_dict,
                       prefix="es_scan_with_h2o_zpe_",
                      plotting_potential_name="es_scan_with_water_fitted_zpe.dat",
                     potential="Excited State PES",mass=mass_ground,max_energy=450)

# %%
# Get maximum overlaps to plot those excited state wavefunctions
overlap_df.sort_values(by=['overlap'],ascending=False).head(20)
# Out:
#        energy                     ground_state_id  \
# 245  0.000872  gs_scan_with_h2o_zpe_2_vib_excited
# 244 -0.000016              gs_scan_with_h2o_zpe_2
# 249  0.001152  gs_scan_with_h2o_zpe_2_vib_excited
# 248  0.000263              gs_scan_with_h2o_zpe_2
# 368  0.001087  gs_scan_with_h2o_zpe_3_vib_excited
# 367  0.000198              gs_scan_with_h2o_zpe_3
# 364  0.000814  gs_scan_with_h2o_zpe_3_vib_excited
# 363 -0.000074              gs_scan_with_h2o_zpe_3
# 372  0.001447  gs_scan_with_h2o_zpe_3_vib_excited
# 371  0.000558              gs_scan_with_h2o_zpe_3
# 193  0.005642              gs_scan_with_h2o_zpe_1
# 194  0.006530  gs_scan_with_h2o_zpe_1_vib_excited
# 197  0.005904              gs_scan_with_h2o_zpe_1
# 198  0.006792  gs_scan_with_h2o_zpe_1_vib_excited
# 252  0.000605              gs_scan_with_h2o_zpe_2
# 253  0.001493  gs_scan_with_h2o_zpe_2_vib_excited
# 71   0.006340  gs_scan_with_h2o_zpe_0_vib_excited
# 70   0.005452              gs_scan_with_h2o_zpe_0
# 381  0.001294              gs_scan_with_h2o_zpe_3
# 382  0.002182  gs_scan_with_h2o_zpe_3_vib_excited
#
#                         excited_state_id   overlap
# 245   es_scan_with_h2o_zpe_1_vib_excited  0.584903
# 244               es_scan_with_h2o_zpe_1  0.584903
# 249   es_scan_with_h2o_zpe_3_vib_excited  0.530666
# 248               es_scan_with_h2o_zpe_3  0.530666
# 368   es_scan_with_h2o_zpe_2_vib_excited  0.493389
# 367               es_scan_with_h2o_zpe_2  0.493389
# 364   es_scan_with_h2o_zpe_0_vib_excited  0.414518
# 363               es_scan_with_h2o_zpe_0  0.414518
# 372   es_scan_with_h2o_zpe_4_vib_excited  0.401425
# 371               es_scan_with_h2o_zpe_4  0.401425
# 193              es_scan_with_h2o_zpe_36  0.396957
# 194  es_scan_with_h2o_zpe_36_vib_excited  0.396957
# 197              es_scan_with_h2o_zpe_38  0.389191
# 198  es_scan_with_h2o_zpe_38_vib_excited  0.389191
# 252               es_scan_with_h2o_zpe_5  0.381400
# 253   es_scan_with_h2o_zpe_5_vib_excited  0.381400
# 71   es_scan_with_h2o_zpe_35_vib_excited  0.376972
# 70               es_scan_with_h2o_zpe_35  0.376972
# 381               es_scan_with_h2o_zpe_9  0.375037
# 382   es_scan_with_h2o_zpe_9_vib_excited  0.375037

# %%
# Export overlap to csv file

overlap_df.to_csv('./phpy_h2o_overlap_list.csv')

# %%
# Excited State Square Plot

excited_state_plot_list = [1,3,2,0,4,36]

for state in excited_state_plot_list:
    plot_wavefunction_squared(state_dict=excited_state_dict,
                        state_num=state,prefix="es_scan_with_h2o_zpe_",
                      plotting_potential_name="es_scan_with_water_fitted_zpe.dat",
                     potential="Excited State PES",mass=mass_ground)
# Out:
# Examining state es_scan_with_h2o_zpe_1
# Examining state es_scan_with_h2o_zpe_3
# Examining state es_scan_with_h2o_zpe_2
# Examining state es_scan_with_h2o_zpe_0
# Examining state es_scan_with_h2o_zpe_4
# Examining state es_scan_with_h2o_zpe_36
