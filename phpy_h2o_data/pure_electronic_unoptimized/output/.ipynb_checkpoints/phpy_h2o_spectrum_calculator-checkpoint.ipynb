# %%
# Notebook for calculating the 
# vibronic spectra
# This program fits potential energy surfaces
# and sets up the necessary DVR calculations
# Notebook is annotated where the DVR calculation must
# be executed before continuing

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import random
from scipy import interpolate

# %%
import scipy

# %%
import pandas as pd

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 8)

# %%
from scipy.interpolate import interp1d

# %%
from dvr_setup_and_plotting_utils import *

# %%
# Run and collect ground state information
# Reduced mass of freqency calculation =  4.0054 AMU

# Final fitted result worked best with the following fitted mass

mass_ground = 4.0054*1836*22
print(str(mass_ground/1836))

num_wavefunctions_ground = 5
grid_points = 500 # This number is N, number of points in DVR is 2N+1

# Linear fit used in production 
# Cubic fit also written 

fit_potential_spline_assume_periodic_write_to_file(raw_potential_filename='gs_scan_with_water_no_opt.dat',num_grid_points=grid_points,
                                output_potential_filename='gs_scan_with_water_fitted.dat',shift_origin=0.0,scale_factor=1.00)


print('potential written')

setup_dvr(num_states=num_wavefunctions_ground,num_grid_points=grid_points,mass=mass_ground,
                         potential_energy_file_name='gs_scan_with_water_fitted.dat',
                        output_file_name='gs_scan_with_h2o')

print('dvr is set up')
# Out:
# 88.1188
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp gs_scan_with_water_fitted.dat potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above
# User must supply their own matrix diagonalization subroutine

# %%
# Now setup and run the excited state excited state
# Reduced mass from excited state vibrational frequency calculation is 3.8404 

mass_excited =  3.8404*1836*22
num_wavefunctions_excited = 200
print(str(mass_excited/1836))

fit_potential_spline_assume_periodic_write_to_file(raw_potential_filename='es_scan_with_water_no_opt.dat',num_grid_points=grid_points,
                                output_potential_filename='es_scan_with_water_fitted.dat',shift_origin=0.0,scale_factor=1.0)

print('potential written')

setup_dvr(num_states=num_wavefunctions_excited,num_grid_points=grid_points,mass=mass_excited,
                         potential_energy_file_name='es_scan_with_water_fitted.dat',
                        output_file_name='es_scan_with_h2o')

print('dvr is set up')
# Out:
# 84.4888
# potential written
# dvr is set up

# %%
# At this point in the directory where the files are made
# ! cp es_scan_with_water_fitted.dat potential_file.dat
# ! ./dvr_1d_periodic

# This will run the DVR calculation and calculate the wavefunctions
# They are stored with the output name specified above

# %%
# Square overlaps calculated here

# %%
wavefunction_overlaps = read_wavefunctions_calculate_overlaps_vib_shift(
                                         ground_state_file_name_root='gs_scan_with_h2o',
                                         excited_state_file_name_root='es_scan_with_h2o',
                                         max_num_ground_state_wfs=4,
                                         max_num_excited_state_wfs=100,
                                         ground_state_max_energy=300,
                                         excited_state_max_energy=2000,
                                         vib_shift=195.0,
                                        vib_scale=2.0)
# Out:
# Calculating overlap for transition with energy 0.0
# Calculating overlap for transition with energy 3.669784782486618
# Calculating overlap for transition with energy 78.30988692180301
# Calculating overlap for transition with energy 85.77836493655377
# Calculating overlap for transition with energy 155.64414879473637
# Calculating overlap for transition with energy 165.57418663638805
# Calculating overlap for transition with energy 235.79522816985215
# Calculating overlap for transition with energy 247.93030274679907
# Calculating overlap for transition with energy 317.70126105839336
# Calculating overlap for transition with energy 331.6974904295337
# Calculating overlap for transition with energy 401.119683502772
# Calculating overlap for transition with energy 416.6008602095075
# Calculating overlap for transition with energy 485.88282425993236
# Calculating overlap for transition with energy 502.5177476717978
# Calculating overlap for transition with energy 571.8456793226572
# Calculating overlap for transition with energy 589.3976095974377
# Calculating overlap for transition with energy 658.9615672418334
# Calculating overlap for transition with energy 677.2644907101676
# Calculating overlap for transition with energy 747.1760846003865
# Calculating overlap for transition with energy 766.1195860017519
# Calculating overlap for transition with energy 836.5334302823064
# Calculating overlap for transition with energy 856.0667464767985
# Calculating overlap for transition with energy 927.0711395428011
# Calculating overlap for transition with energy 947.1940994011474
# Calculating overlap for transition with energy 1018.8164946128265
# Calculating overlap for transition with energy 1039.5585492553298
# Calculating overlap for transition with energy 1111.753832128557
# Calculating overlap for transition with energy 1133.160236927766
# Calculating overlap for transition with energy 1205.834169103219
# Calculating overlap for transition with energy 1227.9546453682456
# Calculating overlap for transition with energy 1300.9982146088337
# Calculating overlap for transition with energy 1323.8803682708278
# Calculating overlap for transition with energy 1397.1590318085975
# Calculating overlap for transition with energy 1420.8438266981295
# Calculating overlap for transition with energy 1494.2259631128672
# Calculating overlap for transition with energy 1518.74588575107
# Calculating overlap for transition with energy 1592.128164122197
# Calculating overlap for transition with energy 1617.5139358154945
# Calculating overlap for transition with energy 1690.8012453101721
# Calculating overlap for transition with energy 1717.0797664520699
# Calculating overlap for transition with energy 1790.1885622323025
# Calculating overlap for transition with energy 1817.3834577716977
# Calculating overlap for transition with energy 1890.2318801857816
# Calculating overlap for transition with energy 1918.363485031784
# Calculating overlap for transition with energy -1.999301534648251
# Calculating overlap for transition with energy 1.6704832478383673
# Calculating overlap for transition with energy 76.31058538715476
# Calculating overlap for transition with energy 83.77906340190552
# Calculating overlap for transition with energy 153.6448472600881
# Calculating overlap for transition with energy 163.5748851017398
# Calculating overlap for transition with energy 233.79592663520387
# Calculating overlap for transition with energy 245.9310012121508
# Calculating overlap for transition with energy 315.7019595237451
# Calculating overlap for transition with energy 329.6981888948854
# Calculating overlap for transition with energy 399.12038196812375
# Calculating overlap for transition with energy 414.6015586748593
# Calculating overlap for transition with energy 483.8835227252841
# Calculating overlap for transition with energy 500.5184461371495
# Calculating overlap for transition with energy 569.846377788009
# Calculating overlap for transition with energy 587.3983080627894
# Calculating overlap for transition with energy 656.9622657071852
# Calculating overlap for transition with energy 675.2651891755194
# Calculating overlap for transition with energy 745.1767830657383
# Calculating overlap for transition with energy 764.1202844671037
# Calculating overlap for transition with energy 834.5341287476581
# Calculating overlap for transition with energy 854.0674449421502
# Calculating overlap for transition with energy 925.0718380081529
# Calculating overlap for transition with energy 945.1947978664991
# Calculating overlap for transition with energy 1016.8171930781784
# Calculating overlap for transition with energy 1037.5592477206815
# Calculating overlap for transition with energy 1109.7545305939088
# Calculating overlap for transition with energy 1131.1609353931178
# Calculating overlap for transition with energy 1203.8348675685709
# Calculating overlap for transition with energy 1225.9553438335975
# Calculating overlap for transition with energy 1298.9989130741853
# Calculating overlap for transition with energy 1321.8810667361795
# Calculating overlap for transition with energy 1395.1597302739494
# Calculating overlap for transition with energy 1418.8445251634814
# Calculating overlap for transition with energy 1492.2266615782191
# Calculating overlap for transition with energy 1516.7465842164218
# Calculating overlap for transition with energy 1590.1288625875488
# Calculating overlap for transition with energy 1615.5146342808464
# Calculating overlap for transition with energy 1688.801943775524
# Calculating overlap for transition with energy 1715.0804649174215
# Calculating overlap for transition with energy 1788.1892606976542
# Calculating overlap for transition with energy 1815.3841562370494
# Calculating overlap for transition with energy 1888.2325786511333
# Calculating overlap for transition with energy 1916.3641834971356
# Calculating overlap for transition with energy -90.93948715908385
# Calculating overlap for transition with energy -87.26970237659722
# Calculating overlap for transition with energy -12.62960023728083
# Calculating overlap for transition with energy -5.161122222530069
# Calculating overlap for transition with energy 64.70466163565251
# Calculating overlap for transition with energy 74.6346994773042
# Calculating overlap for transition with energy 144.8557410107683
# Calculating overlap for transition with energy 156.99081558771522
# Calculating overlap for transition with energy 226.76177389930947
# Calculating overlap for transition with energy 240.75800327044982
# Calculating overlap for transition with energy 310.1801963436881
# Calculating overlap for transition with energy 325.66137305042366
# Calculating overlap for transition with energy 394.9433371008485
# Calculating overlap for transition with energy 411.578260512714
# Calculating overlap for transition with energy 480.90619216357345
# Calculating overlap for transition with energy 498.4581224383539
# Calculating overlap for transition with energy 568.0220800827497
# Calculating overlap for transition with energy 586.3250035510838
# Calculating overlap for transition with energy 656.2365974413027
# Calculating overlap for transition with energy 675.1800988426681
# Calculating overlap for transition with energy 745.5939431232225
# Calculating overlap for transition with energy 765.1272593177147
# Calculating overlap for transition with energy 836.1316523837173
# Calculating overlap for transition with energy 856.2546122420636
# Calculating overlap for transition with energy 927.8770074537426
# Calculating overlap for transition with energy 948.6190620962458
# Calculating overlap for transition with energy 1020.8143449694732
# Calculating overlap for transition with energy 1042.220749768682
# Calculating overlap for transition with energy 1114.894681944135
# Calculating overlap for transition with energy 1137.0151582091617
# Calculating overlap for transition with energy 1210.0587274497495
# Calculating overlap for transition with energy 1232.940881111744
# Calculating overlap for transition with energy 1306.2195446495136
# Calculating overlap for transition with energy 1329.9043395390456
# Calculating overlap for transition with energy 1403.2864759537833
# Calculating overlap for transition with energy 1427.8063985919862
# Calculating overlap for transition with energy 1501.188676963113
# Calculating overlap for transition with energy 1526.5744486564106
# Calculating overlap for transition with energy 1599.8617581510882
# Calculating overlap for transition with energy 1626.140279292986
# Calculating overlap for transition with energy 1699.2490750732186
# Calculating overlap for transition with energy 1726.443970612614
# Calculating overlap for transition with energy 1799.2923930266977
# Calculating overlap for transition with energy 1827.4239978727003
# Calculating overlap for transition with energy -92.35477829015284
# Calculating overlap for transition with energy -88.68499350766622
# Calculating overlap for transition with energy -14.044891368349822
# Calculating overlap for transition with energy -6.5764133535990625
# Calculating overlap for transition with energy 63.289370504583516
# Calculating overlap for transition with energy 73.2194083462352
# Calculating overlap for transition with energy 143.44044987969932
# Calculating overlap for transition with energy 155.57552445664624
# Calculating overlap for transition with energy 225.34648276824052
# Calculating overlap for transition with energy 239.34271213938084
# Calculating overlap for transition with energy 308.76490521261917
# Calculating overlap for transition with energy 324.2460819193547
# Calculating overlap for transition with energy 393.5280459697795
# Calculating overlap for transition with energy 410.1629693816449
# Calculating overlap for transition with energy 479.4909010325045
# Calculating overlap for transition with energy 497.0428313072848
# Calculating overlap for transition with energy 566.6067889516805
# Calculating overlap for transition with energy 584.9097124200148
# Calculating overlap for transition with energy 654.8213063102336
# Calculating overlap for transition with energy 673.7648077115991
# Calculating overlap for transition with energy 744.1786519921535
# Calculating overlap for transition with energy 763.7119681866455
# Calculating overlap for transition with energy 834.7163612526483
# Calculating overlap for transition with energy 854.8393211109945
# Calculating overlap for transition with energy 926.4617163226737
# Calculating overlap for transition with energy 947.203770965177
# Calculating overlap for transition with energy 1019.3990538384043
# Calculating overlap for transition with energy 1040.8054586376131
# Calculating overlap for transition with energy 1113.4793908130662
# Calculating overlap for transition with energy 1135.5998670780928
# Calculating overlap for transition with energy 1208.6434363186809
# Calculating overlap for transition with energy 1231.525589980675
# Calculating overlap for transition with energy 1304.8042535184447
# Calculating overlap for transition with energy 1328.4890484079767
# Calculating overlap for transition with energy 1401.8711848227144
# Calculating overlap for transition with energy 1426.3911074609173
# Calculating overlap for transition with energy 1499.7733858320441
# Calculating overlap for transition with energy 1525.1591575253417
# Calculating overlap for transition with energy 1598.4464670200193
# Calculating overlap for transition with energy 1624.724988161917
# Calculating overlap for transition with energy 1697.8337839421497
# Calculating overlap for transition with energy 1725.0286794815447
# Calculating overlap for transition with energy 1797.8771018956286
# Calculating overlap for transition with energy 1826.008706741631

# %%
#This produces a list of dictionaries
# Showing example
wavefunction_overlaps[0]
# Out:
# {'energy': 0.0,
#  'ground_state_id': 'gs_scan_with_h2o_0',
#  'excited_state_id': 'es_scan_with_h2o_0',
#  'overlap': 1.3517619401582298e-30}

# %%
# Turn list of dictionaries into a dataframe
overlap_df = pd.DataFrame(wavefunction_overlaps)

# %%
# Now, convert from a.u. to cm^-1, plot stem plot and compare to the experimental spectrum
# Use same color scheme as experimental section

# Exp files: PhPyH2O UV Spectrum.txt
# Exp file 2: PhPyH2O UV Spectrum.txt 

# Offset slightly different if ZPE effects included or not 

offset = 35075

kidwell_uv_spectrum_energy = np.loadtxt('PhPyH2O UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPyH2O UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 


ax.set_xlabel('Energy cm^-1', fontsize = 12)
ax.set_ylabel('Intensity', fontsize = 12)
ax.set_xlim(35100,35700)
 
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity,label='Experiment', color='k',ls='-')

# In principle can 
# scale the overlaps that involve the second vibrationale xcited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)



wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)



ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion only',
       basefmt=" ")


ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")

ax.legend()
plt.savefig('./theory_exp_spectrum_compare_mass_with_water_for_presentation.pdf')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:60: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:65: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Plot now with linewidth
# Reads in a list of frequencies and intensities
# Then produces two text files that have the right spectrum
def calc_spectrum_plot(freq_list=None,int_list=None,
                       min_freq=0.0,max_freq=0.0,width=1,resolution=0.05):
    
    num_points = int((max_freq-min_freq)/(resolution))
    
    frequencies = list()
    intensities = list()
    
    for i in range(0,num_points):
        frequency = min_freq+i*resolution
        intensity = 0.0
        
        for j in range(0,len(freq_list)):
            peak_center = freq_list[j]
            peak_height = int_list[j]
           # print(peak_center)
           # print(peak_height)
            intensity = intensity + peak_height*np.exp(-(frequency - peak_center)**2/(2*width))
    
        frequencies.append(frequency)
        intensities.append(intensity)
    
    return frequencies,intensities

# %%
theory_frequencies,theory_intensities = calc_spectrum_plot(
                    freq_list=vibrational_state_overlaps_df['energy']*AU_TO_WAVENUMBER+offset,
                    int_list=vibrational_state_overlaps_df['overlap'],
                       min_freq=offset-50,max_freq=offset+1000,width=10.0,resolution=0.5)

# %%
# Plot with both spectra on each other

# Set baseline to zero 

kidwell_uv_spectrum_energy = np.loadtxt('PhPyH2O UV Spectrum.txt',usecols=0)
kidwell_uv_spectrum_intensity = np.loadtxt('PhPyH2O UV Spectrum.txt',usecols=1)

# Set baseline to zero 

kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity-min(kidwell_uv_spectrum_intensity)

# Normalize
kidwell_uv_spectrum_intensity = kidwell_uv_spectrum_intensity/max(kidwell_uv_spectrum_intensity)

fig = plt.figure(figsize = (7.5,5))
ax = fig.add_subplot(1,1,1) 

#ax.set_xlim(min(kidwell_uv_spectrum_energy)-200,max(kidwell_uv_spectrum_energy)+400)

ax.set_xlabel('Energy cm$^{-1}$', fontsize = 20)
ax.set_ylabel('Intensity', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=20)


ax.set_xlim(35150,35600)

max_freq = 38000
 
ax.plot(kidwell_uv_spectrum_energy, kidwell_uv_spectrum_intensity+0.8,label='Experiment', color='k',ls='-')


theory_plot_intensities = theory_intensities/max(theory_intensities)

# Plot the theory spectrum
ax.plot(theory_frequencies, theory_plot_intensities,label='Smoothed Model', color='k',ls='dashed')

# Scale the overlaps that come from the excited state

wavefunction_overlaps_for_plotting = wavefunction_overlaps.copy()

wavefunction_ground_vib_state_for_plotting = list()
wavefunction_excited_vib_state_for_plotting = list()

# Want to have different colors depending on if the origin is 
for wavefunction_overlap in wavefunction_overlaps_for_plotting:
    if 'vib_excited' in wavefunction_overlap['excited_state_id']:
        wavefunction_excited_vib_state_for_plotting.append(wavefunction_overlap)
    else:
        wavefunction_ground_vib_state_for_plotting.append(wavefunction_overlap)

# Now add in the stem plot

vibrational_state_overlaps_df = pd.DataFrame(wavefunction_overlaps_for_plotting)

# Might need to normalize

wavefunction_ground_vib_state_for_plotting_df = pd.DataFrame(wavefunction_ground_vib_state_for_plotting)

wavefunction_excited_vib_state_for_plotting_df = pd.DataFrame(wavefunction_excited_vib_state_for_plotting)



ax.stem(wavefunction_ground_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
        wavefunction_ground_vib_state_for_plotting_df['overlap'],linefmt='b-',markerfmt=' ',label='Torsion Only',
       basefmt=" ")


ax.stem(wavefunction_excited_vib_state_for_plotting_df['energy']*AU_TO_WAVENUMBER+offset, 
      wavefunction_excited_vib_state_for_plotting_df['overlap'],linefmt='r-',markerfmt=' ',label='Torsion + Vibration',
       basefmt=" ")


ax.legend()
plt.savefig('./theory_exp_spectrum_smooth_with_water_for_presentation.pdf',bbox_inches='tight')
plt.show()
# Out:
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:65: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /Users/danieltabor/miniconda3/envs/ahtvs/lib/python3.6/site-packages/ipykernel_launcher.py:70: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Generate plots of the wavefunctions
# or squares of the wavefunctions
ground_state_file_name_root='gs_scan_with_h2o'
excited_state_file_name_root='es_scan_with_h2o'
max_num_ground_state_wfs=4
max_num_excited_state_wfs=100

# %%
ground_state_dict = read_dvr_output(filename_root=ground_state_file_name_root,num_states=max_num_ground_state_wfs)
excited_state_dict = read_dvr_output(filename_root=excited_state_file_name_root,num_states=max_num_excited_state_wfs)

# %%
# plot the potential and square of the wavefunction 
# (avoids ambiguity on signs) of the ground state potential


wavefunction_counter = 0

max_wavefunctions = 4

prefix = "kidwell_gs_scan_with_h2o"

for i in range(0,4):
    plot_wavefunction_squared(state_dict=ground_state_dict,
                        state_num=i,prefix="gs_scan_with_h2o_",
                      plotting_potential_name="gs_scan_with_water_fitted.dat",
                     potential="Ground State PES",mass=mass_ground)
# Out:
# Examining state gs_scan_with_h2o_0
# Examining state gs_scan_with_h2o_1
# Examining state gs_scan_with_h2o_2
# Examining state gs_scan_with_h2o_3

# %%
# Excited state square plot

excited_state_plot_list = [1,3,2,0,4,36]

for state in excited_state_plot_list:
    plot_wavefunction_squared(state_dict=excited_state_dict,
                        state_num=state,prefix="es_scan_with_h2o_",
                      plotting_potential_name="es_scan_with_water_fitted.dat",
                     potential="Excited State PES",mass=mass_ground)
# Out:
# Examining state es_scan_with_h2o_1
# Examining state es_scan_with_h2o_3
# Examining state es_scan_with_h2o_2
# Examining state es_scan_with_h2o_0
# Examining state es_scan_with_h2o_4
# Examining state es_scan_with_h2o_36

# %%
# Get maximum overlaps to plot those excited state wavefunctions
overlap_df.sort_values(by=['overlap'],ascending=False).head(20)
# Out:
#        energy                 ground_state_id  \
# 47   0.005204  gs_scan_with_h2o_0_vib_excited
# 129  0.005103  gs_scan_with_h2o_1_vib_excited
# 43   0.004789  gs_scan_with_h2o_0_vib_excited
# 51   0.005625  gs_scan_with_h2o_0_vib_excited
# 133  0.005521  gs_scan_with_h2o_1_vib_excited
# 125  0.004691  gs_scan_with_h2o_1_vib_excited
# 39   0.004379  gs_scan_with_h2o_0_vib_excited
# 203  0.003560  gs_scan_with_h2o_2_vib_excited
# 137  0.005945  gs_scan_with_h2o_1_vib_excited
# 199  0.003160  gs_scan_with_h2o_2_vib_excited
# 285  0.003470  gs_scan_with_h2o_3_vib_excited
# 55   0.006052  gs_scan_with_h2o_0_vib_excited
# 121  0.004284  gs_scan_with_h2o_1_vib_excited
# 281  0.003073  gs_scan_with_h2o_3_vib_excited
# 231  0.006506  gs_scan_with_h2o_2_vib_excited
# 313  0.006395  gs_scan_with_h2o_3_vib_excited
# 317  0.006834  gs_scan_with_h2o_3_vib_excited
# 235  0.006948  gs_scan_with_h2o_2_vib_excited
# 227  0.006069  gs_scan_with_h2o_2_vib_excited
# 141  0.006374  gs_scan_with_h2o_1_vib_excited
#
#                     excited_state_id   overlap
# 47   es_scan_with_h2o_23_vib_excited  0.303355
# 129  es_scan_with_h2o_22_vib_excited  0.294262
# 43   es_scan_with_h2o_21_vib_excited  0.290161
# 51   es_scan_with_h2o_25_vib_excited  0.277802
# 133  es_scan_with_h2o_24_vib_excited  0.275657
# 125  es_scan_with_h2o_20_vib_excited  0.273505
# 39   es_scan_with_h2o_19_vib_excited  0.233290
# 203  es_scan_with_h2o_17_vib_excited  0.229449
# 137  es_scan_with_h2o_26_vib_excited  0.228003
# 199  es_scan_with_h2o_15_vib_excited  0.223995
# 285  es_scan_with_h2o_16_vib_excited  0.223070
# 55   es_scan_with_h2o_27_vib_excited  0.221024
# 121  es_scan_with_h2o_18_vib_excited  0.218019
# 281  es_scan_with_h2o_14_vib_excited  0.213764
# 231  es_scan_with_h2o_31_vib_excited  0.204573
# 313  es_scan_with_h2o_30_vib_excited  0.195566
# 317  es_scan_with_h2o_32_vib_excited  0.192243
# 235  es_scan_with_h2o_33_vib_excited  0.187933
# 227  es_scan_with_h2o_29_vib_excited  0.174642
# 141  es_scan_with_h2o_28_vib_excited  0.168583

# %%
# Export overlap to csv file

overlap_df.to_csv('./phpy_h2o_overlap_list_no_optimization.csv')

# %%
# plot potentials with energy levels

# %%
plot_potential_and_energy_levels(state_dict=ground_state_dict,
                       prefix="kidwell_gs_scan_with_h2o",
                      plotting_potential_name="gs_scan_with_water_fitted.dat",
                     potential="Ground State PES",mass=mass_ground,max_energy=70)

# %%
plot_potential_and_energy_levels(state_dict=excited_state_dict,
                       prefix="kidwell_es_scan_with_h2o",
                      plotting_potential_name="es_scan_with_water_fitted.dat",
                     potential="Excited State PES",mass=mass_ground,max_energy=450)
